# %% [markdown]
# ## Part of Speech Tagging is Weird
#
# NLTK shows us some weird part of speech tagging. We might decide that it's just a bit unreliable here. In this notebook, we're going to compare the part of speech tagging from NLTK with a newer library called spaCy that's used widely in industry for natural language processing (NLP). We'll also practice preparing some simple files for output.
#
# ### Installs
# For the code in this notebook, you'll need to do a couple of new pip installs in your activated virtual environment (.venv) in your shell:
#
# * `pip install spacy`
# * `pip install pygal`
#
# ### Language Models
# Like NLTK's collections that we downloaded, [spaCy has trained language models](https://spacy.io/usage/models) to download. You download these in your Python script after you import spacy, and after you download once, you don't need to do it again (so you can comment out the download line). We're going to try the medium and large models in English. (It's good to know that both spaCy and NLTK have resources for NLP on other languages, too!)

# %%
import spacy

# %% [markdown]
# ### Downloading language models
# To work with spaCy's pre-trained language models, you need to download them to you virtual environment. There are:
# * en_core_web_sm (smallest--not as much info as the others)
# * **en_core_web_md** (Pretty good date here, size: 34 MB )
# * **en_core_web_lg** (Lots of data here, size: 400 MB.)
# Note that the LARGEST  one will have the most data and probably be the most reliable.

# %%
# CAN YOU SKIP THIS???
# After you download a model into your virtual environment for the first time, you can comment out the download line.
# spaCy's medium and large models will give us the best results for NLP tagging.
# nlp = spacy.cli.download("en_core_web_sm")
# nlp = spacy.cli.download("en_core_web_md")
nlp = spacy.cli.download("en_core_web_lg")

# %% [markdown]
# ### Load the model
# Now we redefine the nlp variable to LOAD the model you downloaded.

# %%
nlp = spacy.load("en_core_web_lg")

# %%
filepath = 'ATE1.txt'
f = open(filepath, 'r', encoding='utf8').read()

# %% [markdown]
# ## spaCy Part of Speech Tagging
# spaCy needs to read the str() of our text to generate a dictionary of information on each word.
# So we go back to our opened file!

# %% [markdown]
# I got it to run ATE1.txt from our adventure time repo.

# %%
# We used nlp as our variable for the spaCy operations. 
# f is our variable for the source file. spaCy doesn't tell you how it tokenizes or what it's doing (sigh). 
spacyRead = nlp(f)
for token in spacyRead:
    print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# [ ----> X ::::: [
# The ----> DET ::::: the
# episode ----> NOUN ::::: episode
# begins ----> VERB ::::: begin
# in ----> ADP ::::: in
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# Kingdom ----> PROPN ::::: Kingdom
# , ----> PUNCT ::::: ,
# Jake ----> PROPN ::::: Jake
# is ----> AUX ::::: be
# playfully ----> ADV ::::: playfully
# chasing ----> VERB ::::: chase
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# think ----> VERB ::::: think
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# pretty ----> ADJ ::::: pretty
# way ----> ADV ::::: way
# up ----> ADV ::::: up
# there ----> ADV ::::: there
# but ----> CCONJ ::::: but
# I ----> PRON ::::: I
# can ----> AUX ::::: can
# get ----> VERB ::::: get
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# he ----> PRON ::::: he
# stretches ----> VERB ::::: stretch
# to ----> PART ::::: to
# be ----> AUX ::::: be
# on ----> ADP ::::: on
# Lady ----> PROPN ::::: Lady
# 's ----> PART ::::: 's
# level ----> NOUN ::::: level
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# : ----> PUNCT ::::: :
# 나 ----> X ::::: 나
# 잡아봐봐~ ----> PROPN ::::: 잡아봐봐~
# ( ----> PUNCT ::::: (
# " ----> PUNCT ::::: "
# Catch ----> VERB ::::: catch
# me ----> PRON ::::: I
# if ----> SCONJ ::::: if
# you ----> PRON ::::: you
# can ----> AUX ::::: can
# . ----> PUNCT ::::: .
# " ----> PUNCT ::::: "
# ) ----> PUNCT ::::: )
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# are ----> AUX ::::: be
# in ----> ADP ::::: in
# a ----> DET ::::: a
# cemetery ----> NOUN ::::: cemetery
# with ----> ADP ::::: with
# a ----> DET ::::: a
# table ----> NOUN ::::: table
# full ----> ADJ ::::: full
# of ----> ADP ::::: of
# different ----> ADJ ::::: different
# chemicals ----> NOUN ::::: chemical
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Alright ----> INTJ ::::: alright
# . ----> PUNCT ::::: .
# Let ----> VERB ::::: let
# me ----> PRON ::::: I
# just ----> ADV ::::: just
# add ----> VERB ::::: add
# three ----> NUM ::::: three
# more ----> ADJ ::::: more
# drops ----> NOUN ::::: drop
# of ----> ADP ::::: of
# explosive ----> ADJ ::::: explosive
# diarrhea ----> NOUN ::::: diarrhea
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# She ----> PRON ::::: she
# adds ----> VERB ::::: add
# the ----> DET ::::: the
# explosive ----> ADJ ::::: explosive
# diarrhea ----> NOUN ::::: diarrhea
# and ----> CCONJ ::::: and
# a ----> DET ::::: a
# giant ----> ADJ ::::: giant
# cloud ----> NOUN ::::: cloud
# shaped ----> VERB ::::: shape
# like ----> ADP ::::: like
# a ----> DET ::::: a
# skull ----> NOUN ::::: skull
# puffs ----> VERB ::::: puff
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
# Not ----> PART ::::: not
# a ----> DET ::::: a
# good ----> ADJ ::::: good
# omen ----> NOUN ::::: omen
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Oooo ----> PROPN ::::: Oooo
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# , ----> PUNCT ::::: ,
# when ----> SCONJ ::::: when
# we ----> PRON ::::: we
# bring ----> VERB ::::: bring
# the ----> DET ::::: the
# dead ----> NOUN ::::: dead
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# life ----> NOUN ::::: life
# , ----> PUNCT ::::: ,
# will ----> AUX ::::: will
# it ----> PRON ::::: it
# be ----> AUX ::::: be
# filled ----> VERB ::::: fill
# with ----> ADP ::::: with
# worms ----> NOUN ::::: worm
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# . ----> PUNCT ::::: .
# If ----> SCONJ ::::: if
# my ----> PRON ::::: my
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# works ----> NOUN ::::: work
# , ----> PUNCT ::::: ,
# all ----> DET ::::: all
# the ----> DET ::::: the
# dead ----> ADJ ::::: dead
# Candy ----> PROPN ::::: Candy
# People ----> NOUN ::::: People
# will ----> AUX ::::: will
# look ----> VERB ::::: look
# as ----> ADV ::::: as
# young ----> ADJ ::::: young
# and ----> CCONJ ::::: and
# healthy ----> ADJ ::::: healthy
# as ----> SCONJ ::::: as
# you ----> PRON ::::: you
# do ----> VERB ::::: do
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# does ----> VERB ::::: do
# a ----> DET ::::: a
# " ----> PUNCT ::::: "
# Tarzan ----> NOUN ::::: tarzan
# - ----> PUNCT ::::: -
# yell ----> NOUN ::::: yell
# " ----> PUNCT ::::: "
# while ----> SCONJ ::::: while
# hitting ----> VERB ::::: hit
# his ----> PRON ::::: his
# hands ----> NOUN ::::: hand
# against ----> ADP ::::: against
# his ----> PRON ::::: his
# chest ----> NOUN ::::: chest
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Pick ----> VERB ::::: pick
# up ----> ADP ::::: up
# that ----> DET ::::: that
# platter ----> NOUN ::::: platter
# , ----> PUNCT ::::: ,
# tough ----> ADJ ::::: tough
# guy ----> NOUN ::::: guy
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# picks ----> VERB ::::: pick
# up ----> ADP ::::: up
# a ----> DET ::::: a
# serving ----> VERB ::::: serve
# platter ----> NOUN ::::: platter
# and ----> CCONJ ::::: and
# open ----> VERB ::::: open
# the ----> DET ::::: the
# lid ----> NOUN ::::: lid
# , ----> PUNCT ::::: ,
# revealing ----> VERB ::::: reveal
# a ----> DET ::::: a
# Candy ----> PROPN ::::: Candy
# Person ----> PROPN ::::: Person
# corpse ----> NOUN ::::: corpse
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Old ----> PROPN ::::: Old
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Giggles ----> X ::::: giggles
# ] ----> X ::::: ]
# We ----> PRON ::::: we
# used ----> VERB ::::: use
# to ----> ADP ::::: to
# date ----> NOUN ::::: date
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Applies ----> VERB ::::: apply
# the ----> DET ::::: the
# serum ----> NOUN ::::: serum
# . ----> PUNCT ::::: .
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# 's ----> PART ::::: 's
# corpse ----> NOUN ::::: corpse
# starts ----> VERB ::::: start
# to ----> PART ::::: to
# glow ----> VERB ::::: glow
# and ----> CCONJ ::::: and
# overflow ----> NOUN ::::: overflow
# with ----> ADP ::::: with
# the ----> DET ::::: the
# fizzing ----> VERB ::::: fizz
# serum ----> NOUN ::::: serum
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Something ----> PRON ::::: something
# 's ----> AUX ::::: be
# happening ----> VERB ::::: happen
# ! ----> PUNCT ::::: !
# Come ----> VERB ::::: come
# on ----> ADP ::::: on
# , ----> PUNCT ::::: ,
# come ----> VERB ::::: come
# on ----> ADP ::::: on
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Work ----> NOUN ::::: work
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# A ----> DET ::::: a
# zombie ----> NOUN ::::: zombie
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# arises ----> VERB ::::: arise
# and ----> CCONJ ::::: and
# moans ----> VERB ::::: moan
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Algebraic ----> PROPN ::::: Algebraic
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Wait ----> VERB ::::: wait
# , ----> PUNCT ::::: ,
# something ----> PRON ::::: something
# 's ----> AUX ::::: be
# wrong ----> ADJ ::::: wrong
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Zombie ----> PROPN ::::: Zombie
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# : ----> PUNCT ::::: :
# Sugar ----> PROPN ::::: Sugar
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Squirts ----> NOUN ::::: squirt
# serum ----> NOUN ::::: serum
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# his ----> PRON ::::: his
# eyes ----> NOUN ::::: eye
# and ----> CCONJ ::::: and
# mouth ----> NOUN ::::: mouth
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Ew ----> PROPN ::::: Ew
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Zombie ----> PROPN ::::: Zombie
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# leaps ----> VERB ::::: leap
# into ----> ADP ::::: into
# a ----> DET ::::: a
# giant ----> ADJ ::::: giant
# test ----> NOUN ::::: test
# tube ----> NOUN ::::: tube
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# test ----> NOUN ::::: test
# tube ----> NOUN ::::: tube
# falls ----> VERB ::::: fall
# and ----> CCONJ ::::: and
# infects ----> VERB ::::: infect
# the ----> DET ::::: the
# whole ----> ADJ ::::: whole
# cemetery ----> NOUN ::::: cemetery
# . ----> PUNCT ::::: .
# Zombie ----> PROPN ::::: Zombie
# Candy ----> PROPN ::::: Candy
# People ----> NOUN ::::: People
# begin ----> VERB ::::: begin
# to ----> PART ::::: to
# arise ----> VERB ::::: arise
# from ----> ADP ::::: from
# their ----> PRON ::::: their
# graves ----> NOUN ::::: graf
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# look ----> VERB ::::: look
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# is ----> AUX ::::: be
# working ----> VERB ::::: work
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# this ----> PRON ::::: this
# is ----> AUX ::::: be
# wrong ----> ADJ ::::: wrong
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# coming ----> VERB ::::: come
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# life ----> NOUN ::::: life
# -- ----> PUNCT ::::: --
# they're ----> VERB ::::: they're
# still ----> ADV ::::: still
# dead ----> ADJ ::::: dead
# ! ----> PUNCT ::::: !
# The ----> DET ::::: the
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# -- ----> PUNCT ::::: --
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# incomplete ----> ADJ ::::: incomplete
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# she ----> PRON ::::: she
# rubs ----> VERB ::::: rub
# the ----> DET ::::: the
# head ----> NOUN ::::: head
# of ----> ADP ::::: of
# a ----> DET ::::: a
# candy ----> NOUN ::::: candy
# person ----> NOUN ::::: person
# that ----> PRON ::::: that
# looks ----> VERB ::::: look
# like ----> ADP ::::: like
# a ----> DET ::::: a
# love ----> NOUN ::::: love
# heart ----> NOUN ::::: heart
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Zombie ----> PROPN ::::: Zombie
# Love ----> PROPN ::::: Love
# Heart ----> PROPN ::::: Heart
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# lashing ----> VERB ::::: lash
# out ----> ADP ::::: out
# at ----> ADP ::::: at
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# ] ----> X ::::: ]
# Rah ----> PROPN ::::: Rah
# . ----> PUNCT ::::: .
# Must ----> AUX ::::: must
# eat ----> VERB ::::: eat
# sugar ----> NOUN ::::: sugar
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Pushes ----> VERB ::::: push
# him ----> PRON ::::: he
# back ----> ADV ::::: back
# down ----> ADV ::::: down
# ] ----> PUNCT ::::: ]
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# grounded ----> VERB ::::: ground
# , ----> PUNCT ::::: ,
# Mister ----> PROPN ::::: Mister
# . ----> PROPN ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# this ----> PRON ::::: this
# is ----> AUX ::::: be
# really ----> ADV ::::: really
# bad ----> ADJ ::::: bad
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# be ----> AUX ::::: be
# attracted ----> VERB ::::: attract
# to ----> ADP ::::: to
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# Kingdom ----> PROPN ::::: Kingdom
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Why ----> SCONJ ::::: why
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Because ----> SCONJ ::::: because
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# People ----> NOUN ::::: People
# are ----> AUX ::::: be
# made ----> VERB ::::: make
# of ----> ADP ::::: of
# sugar ----> NOUN ::::: sugar
# , ----> PUNCT ::::: ,
# ya ----> PROPN ::::: ya
# ding ----> PROPN ::::: ding
# dong ----> PROPN ::::: dong
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Zombie ----> PROPN ::::: Zombie
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# On ----> ADP ::::: on
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# ] ----> PUNCT ::::: ]
# Gimme ----> PROPN ::::: Gimme
# some ----> DET ::::: some
# sugar ----> NOUN ::::: sugar
# , ----> PUNCT ::::: ,
# baby ----> NOUN ::::: baby
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Chew ----> VERB ::::: chew
# on ----> ADP ::::: on
# this ----> PRON ::::: this
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Kicks ----> VERB ::::: kick
# him ----> PRON ::::: he
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Giggles ----> X ::::: giggles
# ] ----> X ::::: ]
# Good ----> ADJ ::::: good
# one ----> NOUN ::::: one
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# . ----> PUNCT ::::: .
# Quickly ----> ADV ::::: quickly
# , ----> PUNCT ::::: ,
# to ----> ADP ::::: to
# the ----> DET ::::: the
# kingdom ----> NOUN ::::: kingdom
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# They ----> PRON ::::: they
# run ----> VERB ::::: run
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# the ----> DET ::::: the
# cemetery ----> NOUN ::::: cemetery
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Kicks ----> VERB ::::: kick
# another ----> DET ::::: another
# zombie ----> NOUN ::::: zombie
# ] ----> PUNCT ::::: ]
# Get ----> VERB ::::: get
# a ----> DET ::::: a
# life ----> NOUN ::::: life
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# is ----> AUX ::::: be
# at ----> ADP ::::: at
# the ----> DET ::::: the
# top ----> NOUN ::::: top
# of ----> ADP ::::: of
# her ----> PRON ::::: her
# castle ----> NOUN ::::: castle
# , ----> PUNCT ::::: ,
# ringing ----> VERB ::::: ring
# a ----> DET ::::: a
# large ----> ADJ ::::: large
# bell ----> NOUN ::::: bell
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# All ----> DET ::::: all
# citizens ----> NOUN ::::: citizen
# of ----> ADP ::::: of
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# Kingdom ----> PROPN ::::: Kingdom
# ! ----> PUNCT ::::: !
# Report ----> NOUN ::::: report
# to ----> ADP ::::: to
# the ----> DET ::::: the
# palace ----> NOUN ::::: palace
# , ----> PUNCT ::::: ,
# immediately ----> ADV ::::: immediately
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Candy ----> NOUN ::::: candy
# People ----> NOUN ::::: People
# mumble ----> VERB ::::: mumble
# in ----> ADP ::::: in
# confusion ----> NOUN ::::: confusion
# and ----> CCONJ ::::: and
# walk ----> VERB ::::: walk
# to ----> ADP ::::: to
# the ----> DET ::::: the
# palace ----> NOUN ::::: palace
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoa ----> INTJ ::::: whoa
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Jake ----> PROPN ::::: Jake
# and ----> CCONJ ::::: and
# Lady ----> PROPN ::::: Lady
# go ----> VERB ::::: go
# off ----> ADP ::::: off
# to ----> ADP ::::: to
# the ----> DET ::::: the
# palace ----> NOUN ::::: palace
# . ----> PUNCT ::::: .
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# notices ----> VERB ::::: notice
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# slowly ----> ADV ::::: slowly
# leaving ----> VERB ::::: leave
# the ----> DET ::::: the
# cemetery ----> NOUN ::::: cemetery
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# worried ----> VERB ::::: worry
# ] ----> PUNCT ::::: ]
# Hurry ----> VERB ::::: hurry
# , ----> PUNCT ::::: ,
# sweet ----> ADJ ::::: sweet
# citizens ----> NOUN ::::: citizen
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Alright ----> INTJ ::::: alright
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# heard ----> VERB ::::: hear
# the ----> DET ::::: the
# princess ----> NOUN ::::: princess
# , ----> PUNCT ::::: ,
# everyone ----> PRON ::::: everyone
# in ----> ADP ::::: in
# ! ----> PUNCT ::::: !
# Alright ----> INTJ ::::: alright
# , ----> PUNCT ::::: ,
# no ----> DET ::::: no
# pushing ----> NOUN ::::: pushing
# , ----> PUNCT ::::: ,
# come ----> VERB ::::: come
# on ----> ADP ::::: on
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Dude ----> NOUN ::::: dude
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# up ----> ADP ::::: up
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# princess ----> NOUN ::::: princess
# will ----> AUX ::::: will
# explain ----> VERB ::::: explain
# everything ----> PRON ::::: everything
# . ----> PUNCT ::::: .
# Tree ----> PROPN ::::: Tree
# Trunks ----> NOUN ::::: trunk
# , ----> PUNCT ::::: ,
# get ----> VERB ::::: get
# those ----> DET ::::: those
# hot ----> ADJ ::::: hot
# buns ----> NOUN ::::: bun
# in ----> ADP ::::: in
# here ----> ADV ::::: here
# , ----> PUNCT ::::: ,
# girl ----> NOUN ::::: girl
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Tree ----> PROPN ::::: Tree
# Trunks ----> NOUN ::::: trunk
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Carrying ----> VERB ::::: carry
# hot ----> ADJ ::::: hot
# cross ----> NOUN ::::: cross
# buns ----> NOUN ::::: bun
# ] ----> X ::::: ]
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# hope ----> VERB ::::: hope
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# bad ----> ADJ ::::: bad
# news ----> NOUN ::::: news
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# and ----> CCONJ ::::: and
# Finn ----> PROPN ::::: Finn
# close ----> VERB ::::: close
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Did ----> AUX ::::: do
# we ----> PRON ::::: we
# get ----> VERB ::::: get
# everyone ----> PRON ::::: everyone
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Manfried ----> PROPN ::::: Manfried
# : ----> PUNCT ::::: :
# All ----> PRON ::::: all
# present ----> ADJ ::::: present
# and ----> CCONJ ::::: and
# accounted ----> VERB ::::: account
# for ----> ADP ::::: for
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Thanks ----> NOUN ::::: thank
# , ----> PUNCT ::::: ,
# Manfried ----> PROPN ::::: Manfried
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Manfried ----> PROPN ::::: Manfried
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# welcome ----> ADJ ::::: welcome
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Citizens ----> NOUN ::::: citizen
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# are ----> AUX ::::: be
# assembled ----> VERB ::::: assemble
# here ----> ADV ::::: here
# in ----> ADP ::::: in
# the ----> DET ::::: the
# candy ----> NOUN ::::: candy
# foyer ----> NOUN ::::: foyer
# for ----> ADP ::::: for
# a ----> DET ::::: a
# momentous ----> ADJ ::::: momentous
# announcement ----> NOUN ::::: announcement
# . ----> PUNCT ::::: .
# Tonight ----> NOUN ::::: tonight
# we ----> PRON ::::: we
# are ----> AUX ::::: be
# all ----> PRON ::::: all
# going ----> VERB ::::: go
# to ----> PART ::::: to
# have ----> VERB ::::: have
# ... ----> PUNCT ::::: ...
# a ----> DET ::::: a
# slumber ----> NOUN ::::: slumber
# party ----> NOUN ::::: party
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Crowd ----> NOUN ::::: crowd
# cheers ----> VERB ::::: cheer
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Wait ----> VERB ::::: wait
# ! ----> PUNCT ::::: !
# What ----> PRON ::::: what
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zom-- ----> NUM ::::: zom--
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# covers ----> VERB ::::: cover
# his ----> PRON ::::: his
# mouth ----> NOUN ::::: mouth
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Go ----> VERB ::::: go
# ahead ----> ADV ::::: ahead
# and ----> CCONJ ::::: and
# start ----> VERB ::::: start
# partying ----> VERB ::::: party
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> PUNCT ::::: [
# Voice ----> PROPN ::::: Voice
# muffled ----> VERB ::::: muffle
# ] ----> PUNCT ::::: ]
# But ----> CCONJ ::::: but
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# Undead-- ----> PROPN ::::: Undead--
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Carries ----> VERB ::::: carry
# Finn ----> PROPN ::::: Finn
# to ----> ADP ::::: to
# the ----> DET ::::: the
# lab ----> NOUN ::::: lab
# ] ----> X ::::: ]
# We ----> PRON ::::: we
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# right ----> ADV ::::: right
# back ----> ADV ::::: back
# , ----> PUNCT ::::: ,
# everyone ----> PRON ::::: everyone
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whooo ----> PROPN ::::: Whooo
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# In ----> ADP ::::: in
# the ----> DET ::::: the
# lab ----> NOUN ::::: lab
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Finn ----> PROPN ::::: Finn
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# People ----> NOUN ::::: People
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# know ----> VERB ::::: know
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Wha ----> PROPN ::::: Wha
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# If ----> SCONJ ::::: if
# they ----> PRON ::::: they
# knew ----> VERB ::::: know
# , ----> PUNCT ::::: ,
# they ----> PRON ::::: they
# would ----> AUX ::::: would
# flip ----> VERB ::::: flip
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# mean ----> VERB ::::: mean
# " ----> PUNCT ::::: "
# flip ----> VERB ::::: flip
# out ----> ADP ::::: out
# " ----> PUNCT ::::: "
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# mean ----> VERB ::::: mean
# they ----> PRON ::::: they
# would ----> AUX ::::: would
# flip ----> VERB ::::: flip
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Scene ----> PROPN ::::: Scene
# changes ----> VERB ::::: change
# to ----> ADP ::::: to
# the ----> DET ::::: the
# cemetery ----> NOUN ::::: cemetery
# ; ----> PUNCT ::::: ;
# Starchy ----> PROPN ::::: Starchy
# arrives ----> VERB ::::: arrive
# with ----> ADP ::::: with
# a ----> DET ::::: a
# shovel ----> NOUN ::::: shovel
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Starchy ----> PROPN ::::: Starchy
# : ----> PUNCT ::::: :
# Princess ----> PROPN ::::: Princess
# ? ----> PUNCT ::::: ?
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# Starchy ----> PROPN ::::: Starchy
# the ----> DET ::::: the
# gravedigger ----> NOUN ::::: gravedigger
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# brought ----> VERB ::::: bring
# you ----> PRON ::::: you
# a ----> DET ::::: a
# larger ----> ADJ ::::: large
# corpse ----> NOUN ::::: corpse
# shovel ----> NOUN ::::: shovel
# . ----> PUNCT ::::: .
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# ? ----> PUNCT ::::: ?
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# just ----> ADV ::::: just
# wait ----> VERB ::::: wait
# for ----> ADP ::::: for
# you ----> PRON ::::: you
# here ----> ADV ::::: here
# , ----> PUNCT ::::: ,
# then ----> ADV ::::: then
# . ----> PUNCT ::::: .
# By ----> ADP ::::: by
# the ----> DET ::::: the
# mausoleum ----> NOUN ::::: mausoleum
# . ----> PUNCT ::::: .
# With ----> SCONJ ::::: with
# my ----> PRON ::::: my
# back ----> NOUN ::::: back
# turned ----> VERB ::::: turn
# . ----> PUNCT ::::: .
# And ----> CCONJ ::::: and
# my ----> PRON ::::: my
# defenses ----> NOUN ::::: defense
# lowered ----> VERB ::::: lower
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# As ----> SCONJ ::::: as
# Starchy ----> PROPN ::::: Starchy
# does ----> VERB ::::: do
# so ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# Candy ----> PROPN ::::: Candy
# Zombie ----> PROPN ::::: Zombie
# comes ----> VERB ::::: come
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# the ----> DET ::::: the
# mausoleum ----> NOUN ::::: mausoleum
# and ----> CCONJ ::::: and
# goes ----> VERB ::::: go
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# Starchy ----> PROPN ::::: Starchy
# , ----> PUNCT ::::: ,
# Starchy ----> PROPN ::::: Starchy
# starts ----> VERB ::::: start
# to ----> PART ::::: to
# scream ----> VERB ::::: scream
# and ----> CCONJ ::::: and
# gasp ----> VERB ::::: gasp
# and ----> CCONJ ::::: and
# then ----> ADV ::::: then
# ... ----> PUNCT ::::: ...
# KABOOM ----> PROPN ::::: KABOOM
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# He ----> PRON ::::: he
# explodes ----> VERB ::::: explode
# in ----> ADP ::::: in
# a ----> DET ::::: a
# flash ----> NOUN ::::: flash
# of ----> ADP ::::: of
# light ----> NOUN ::::: light
# . ----> PUNCT ::::: .
# Back ----> ADV ::::: back
# at ----> ADP ::::: at
# the ----> DET ::::: the
# castle ----> NOUN ::::: castle
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Candy ----> NOUN ::::: candy
# People ----> NOUN ::::: People
# explode ----> VERB ::::: explode
# when ----> SCONJ ::::: when
# they ----> PRON ::::: they
# get ----> VERB ::::: get
# scared ----> ADJ ::::: scared
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Not ----> PART ::::: not
# telling ----> VERB ::::: tell
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# People ----> PROPN ::::: People
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# is ----> AUX ::::: be
# so ----> ADV ::::: so
# important ----> ADJ ::::: important
# that ----> SCONJ ::::: that
# you ----> PRON ::::: you
# need ----> VERB ::::: need
# to ----> PART ::::: to
# promise ----> VERB ::::: promise
# , ----> PUNCT ::::: ,
# Royal ----> PROPN ::::: Royal
# Promise ----> PROPN ::::: Promise
# , ----> PUNCT ::::: ,
# not ----> PART ::::: not
# to ----> PART ::::: to
# let ----> VERB ::::: let
# anyone ----> PRON ::::: anyone
# find ----> VERB ::::: find
# out ----> ADP ::::: out
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# , ----> PUNCT ::::: ,
# ever ----> ADV ::::: ever
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Okay ----> INTJ ::::: okay
# , ----> PUNCT ::::: ,
# sure ----> ADJ ::::: sure
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# No ----> PROPN ::::: No
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# have ----> VERB ::::: have
# to ----> ADP ::::: to
# Royal ----> PROPN ::::: Royal
# Promise ----> PROPN ::::: Promise
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# [ ----> X ::::: [
# kneels ----> VERB ::::: kneel
# ] ----> X ::::: ]
# I ----> PRON ::::: I
# Royal ----> PROPN ::::: Royal
# Promise ----> PROPN ::::: Promise
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Now ----> ADV ::::: now
# I ----> PRON ::::: I
# must ----> AUX ::::: must
# cloister ----> VERB ::::: cloister
# myself ----> PRON ::::: myself
# in ----> ADP ::::: in
# the ----> DET ::::: the
# lab ----> NOUN ::::: lab
# and ----> CCONJ ::::: and
# finish ----> VERB ::::: finish
# the ----> DET ::::: the
# equation ----> NOUN ::::: equation
# to ----> ADP ::::: to
# my ----> PRON ::::: my
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# keep ----> VERB ::::: keep
# the ----> DET ::::: the
# candy ----> NOUN ::::: candy
# folk ----> NOUN ::::: folk
# distracted ----> VERB ::::: distract
# and ----> CCONJ ::::: and
# ignorant ----> ADJ ::::: ignorant
# . ----> PUNCT ::::: .
# Can ----> AUX ::::: can
# you ----> PRON ::::: you
# do ----> VERB ::::: do
# that ----> PRON ::::: that
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# your ----> PRON ::::: your
# highness ----> NOUN ::::: highness
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Good ----> PROPN ::::: Good
# . ----> PUNCT ::::: .
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# tell ----> VERB ::::: tell
# anyone ----> PRON ::::: anyone
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# . ----> PUNCT ::::: .
# Never ----> ADV ::::: never
# ever ----> ADV ::::: ever
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# She ----> PRON ::::: she
# leaves ----> VERB ::::: leave
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# wait ----> VERB ::::: wait
# . ----> PUNCT ::::: .
# Can ----> AUX ::::: can
# I ----> PRON ::::: I
# at ----> ADV ::::: at
# least ----> ADJ ::::: least
# tell ----> VERB ::::: tell
# [ ----> X ::::: [
# Jake ----> PROPN ::::: Jake
# enters ----> VERB ::::: enter
# ] ----> PUNCT ::::: ]
# Jake ----> PROPN ::::: Jake
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Tell ----> VERB ::::: tell
# me ----> PRON ::::: I
# about ----> ADP ::::: about
# what ----> PRON ::::: what
# , ----> PUNCT ::::: ,
# dude ----> NOUN ::::: dude
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# know ----> VERB ::::: know
# , ----> PUNCT ::::: ,
# about ----> ADP ::::: about
# the ----> DET ::::: the
# outbreak ----> NOUN ::::: outbreak
# of ----> ADP ::::: of
# zom-- ----> NUM ::::: zom--
# [ ----> X ::::: [
# Covers ----> VERB ::::: cover
# his ----> PRON ::::: his
# mouth ----> NOUN ::::: mouth
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Chuckles ----> X ::::: chuckles
# ] ----> PUNCT ::::: ]
# Alright ----> INTJ ::::: alright
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Uhh ----> INTJ ::::: uhh
# , ----> PUNCT ::::: ,
# nothing ----> PRON ::::: nothing
# at ----> ADV ::::: at
# all ----> ADV ::::: all
# , ----> PUNCT ::::: ,
# buddy ----> NOUN ::::: buddy
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Laughs ----> VERB ::::: laugh
# awkwardly ----> ADV ::::: awkwardly
# and ----> CCONJ ::::: and
# skips ----> VERB ::::: skip
# into ----> ADP ::::: into
# the ----> DET ::::: the
# foyer ----> NOUN ::::: foyer
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# dude ----> NOUN ::::: dude
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# think ----> VERB ::::: think
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# Bubblegum ----> NOUN ::::: bubblegum
# are ----> AUX ::::: be
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# something ----> PRON ::::: something
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# nervously ----> ADV ::::: nervously
# ] ----> X ::::: ]
# Ahha ----> INTJ ::::: ahha
# ah ----> INTJ ::::: ah
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# no ----> DET ::::: no
# way ----> NOUN ::::: way
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoa ----> INTJ ::::: whoa
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# guys ----> NOUN ::::: guy
# are ----> AUX ::::: be
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# something ----> PRON ::::: something
# . ----> PUNCT ::::: .
# Is ----> AUX ::::: be
# it ----> PRON ::::: it
# some ----> DET ::::: some
# sort ----> NOUN ::::: sort
# of ----> ADP ::::: of
# prank ----> NOUN ::::: prank
# ? ----> PUNCT ::::: ?
# Can ----> AUX ::::: can
# I ----> PRON ::::: I
# get ----> VERB ::::: get
# in ----> ADP ::::: in
# on ----> ADP ::::: on
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# To ----> ADP ::::: to
# party ----> NOUN ::::: party
# - ----> PUNCT ::::: -
# goers ----> NOUN ::::: goer
# ] ----> PUNCT ::::: ]
# Who ----> PRON ::::: who
# wants ----> VERB ::::: want
# to ----> PART ::::: to
# play ----> VERB ::::: play
# " ----> PUNCT ::::: "
# Truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# Dare ----> PROPN ::::: Dare
# " ----> PUNCT ::::: "
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Hmm ----> PROPN ::::: Hmm
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Ok ----> ADJ ::::: ok
# , ----> PUNCT ::::: ,
# Chocoberry ----> PROPN ::::: Chocoberry
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# may ----> AUX ::::: may
# ask ----> VERB ::::: ask
# someone ----> PRON ::::: someone
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# a ----> DET ::::: a
# deep ----> ADJ ::::: deep
# truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# a ----> DET ::::: a
# saucy ----> ADJ ::::: saucy
# dare ----> NOUN ::::: dare
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Chocoberry ----> PROPN ::::: Chocoberry
# : ----> PUNCT ::::: :
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# , ----> PUNCT ::::: ,
# truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# dare ----> VERB ::::: dare
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# : ----> PUNCT ::::: :
# Dare ----> PROPN ::::: Dare
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Chocoberry ----> PROPN ::::: Chocoberry
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# dare ----> VERB ::::: dare
# you ----> PRON ::::: you
# to ----> PART ::::: to
# take ----> VERB ::::: take
# off ----> ADP ::::: off
# your ----> PRON ::::: your
# wrapper ----> NOUN ::::: wrapper
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Everyone ----> PRON ::::: everyone
# goes ----> VERB ::::: go
# " ----> PUNCT ::::: "
# Oooh ----> INTJ ::::: oooh
# " ----> PUNCT ::::: "
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Shoulders ----> PROPN ::::: Shoulders
# Finn ----> PROPN ::::: Finn
# ] ----> PUNCT ::::: ]
# Hey ----> INTJ ::::: hey
# seriously ----> ADV ::::: seriously
# , ----> PUNCT ::::: ,
# man ----> INTJ ::::: man
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# your ----> PRON ::::: your
# bro ----> NOUN ::::: bro
# . ----> PUNCT ::::: .
# Bros ----> PROPN ::::: Bros
# are ----> AUX ::::: be
# supposed ----> VERB ::::: suppose
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# bros ----> PROPN ::::: bros
# everything ----> PRON ::::: everything
# all ----> DET ::::: all
# the ----> DET ::::: the
# time ----> NOUN ::::: time
# . ----> PUNCT ::::: .
# What ----> PRON ::::: what
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# Bubblegum ----> PROPN ::::: Bubblegum
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# ? ----> PUNCT ::::: ?
# Is ----> AUX ::::: be
# everything ----> PRON ::::: everything
# alright ----> ADJ ::::: alright
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yep ----> INTJ ::::: yep
# ! ----> PUNCT ::::: !
# Fine ----> INTJ ::::: fine
# ! ----> PUNCT ::::: !
# Everything ----> PRON ::::: everything
# is ----> AUX ::::: be
# great ----> ADJ ::::: great
# ! ----> PUNCT ::::: !
# Heh ----> INTJ ::::: heh
# , ----> PUNCT ::::: ,
# heh ----> INTJ ::::: heh
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Crinkling ----> NOUN ::::: crinkling
# sound ----> NOUN ::::: sound
# ] ----> PUNCT ::::: ]
# Except ----> SCONJ ::::: except
# for ----> ADP ::::: for
# that ----> PRON ::::: that
# . ----> PUNCT ::::: .
# Whoa ----> INTJ ::::: whoa
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# has ----> AUX ::::: have
# shed ----> VERB ::::: shed
# his ----> PRON ::::: his
# wrapper ----> NOUN ::::: wrapper
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Peppermint ----> PROPN ::::: Peppermint
# Butler ----> PROPN ::::: Butler
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# did ----> AUX ::::: do
# n't ----> PART ::::: not
# know ----> VERB ::::: know
# he ----> PRON ::::: he
# was ----> AUX ::::: be
# chocolate ----> NOUN ::::: chocolate
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# : ----> PUNCT ::::: :
# Jake ----> PROPN ::::: Jake
# , ----> PUNCT ::::: ,
# truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# dare ----> VERB ::::: dare
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Truth ----> PROPN ::::: Truth
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# prefer ----> VERB ::::: prefer
# chocolate ----> NOUN ::::: chocolate
# or ----> CCONJ ::::: or
# fudge ----> NOUN ::::: fudge
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# eat ----> VERB ::::: eat
# chocolate ----> NOUN ::::: chocolate
# or ----> CCONJ ::::: or
# fudge ----> NOUN ::::: fudge
# 'cause ----> SCONJ ::::: 'cause
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# a ----> DET ::::: a
# dog ----> NOUN ::::: dog
# and ----> CCONJ ::::: and
# they ----> PRON ::::: they
# 'd ----> AUX ::::: would
# probably ----> ADV ::::: probably
# kill ----> VERB ::::: kill
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# hmmmmm ----> INTJ ::::: hmmmmm
# probably ----> ADV ::::: probably
# ... ----> PUNCT ::::: ...
# neither ----> PRON ::::: neither
# . ----> PUNCT ::::: .
# Finn ----> PROPN ::::: Finn
# ! ----> PUNCT ::::: !
# Truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# dare ----> VERB ::::: dare
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Dare ----> PROPN ::::: Dare
# ! ----> PUNCT ::::: !
# Haha ----> INTJ ::::: haha
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# dare ----> VERB ::::: dare
# you ----> PRON ::::: you
# ... ----> PUNCT ::::: ...
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# me ----> PRON ::::: I
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# about ----> ADP ::::: about
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# in ----> ADP ::::: in
# your ----> PRON ::::: your
# mind ----> NOUN ::::: mind
# . ----> PUNCT ::::: .
# What ----> PRON ::::: what
# were ----> AUX ::::: be
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# Bubblegum ----> NOUN ::::: bubblegum
# talking ----> VERB ::::: talk
# about ----> ADP ::::: about
# when ----> SCONJ ::::: when
# you ----> PRON ::::: you
# were ----> AUX ::::: be
# alone ----> ADJ ::::: alone
# together ----> ADV ::::: together
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Everybody ----> PRON ::::: everybody
# goes ----> VERB ::::: go
# " ----> PUNCT ::::: "
# Oooh ----> INTJ ::::: oooh
# " ----> PUNCT ::::: "
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Nervously ----> ADV ::::: nervously
# ] ----> X ::::: ]
# Umm ----> INTJ ::::: umm
# , ----> PUNCT ::::: ,
# ahh ----> INTJ ::::: ahh
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# is ----> AUX ::::: be
# , ----> PUNCT ::::: ,
# ahhh ----> INTJ ::::: ahhh
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# visualizes ----> VERB ::::: visualize
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# 's ----> PART ::::: 's
# face ----> NOUN ::::: face
# on ----> ADP ::::: on
# Jake ----> PROPN ::::: Jake
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Hallucination ----> PROPN ::::: Hallucination
# of ----> ADP ::::: of
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# promised ----> VERB ::::: promise
# you ----> PRON ::::: you
# would ----> AUX ::::: would
# n't ----> PART ::::: not
# freakin ----> VERB ::::: freakin
# ' ----> PUNCT ::::: '
# tell ----> VERB ::::: tell
# anyone ----> PRON ::::: anyone
# ! ----> PUNCT ::::: !
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# so ----> ADV ::::: so
# cute ----> ADJ ::::: cute
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Ahhh ----> PROPN ::::: Ahhh
# ... ----> PUNCT ::::: ...
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# is ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
# that ----> SCONJ ::::: that
# I ----> PRON ::::: I
# 'd ----> AUX ::::: would
# rather ----> ADV ::::: rather
# play ----> VERB ::::: play
# Dodge ----> PROPN ::::: Dodge
# Socks ----> PROPN ::::: Socks
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# throws ----> VERB ::::: throw
# a ----> DET ::::: a
# sock ----> NOUN ::::: sock
# at ----> ADP ::::: at
# Jake ----> PROPN ::::: Jake
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# 's ----> PART ::::: 's
# face ----> NOUN ::::: face
# goes ----> VERB ::::: go
# away ----> ADV ::::: away
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# not ----> PART ::::: not
# playing ----> VERB ::::: play
# dodge ----> NOUN ::::: dodge
# socks ----> NOUN ::::: sock
# ' ----> VERB ::::: '
# til ----> SCONJ ::::: til
# you ----> PRON ::::: you
# stop ----> VERB ::::: stop
# dodging ----> VERB ::::: dodge
# my ----> PRON ::::: my
# questions ----> NOUN ::::: question
# . ----> PUNCT ::::: .
# Hey ----> INTJ ::::: hey
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# Sniffs ----> PROPN ::::: Sniffs
# socks ----> VERB ::::: sock
# ] ----> X ::::: ]
# Old ----> ADJ ::::: old
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# ? ----> PUNCT ::::: ?
# Is ----> AUX ::::: be
# n't ----> PART ::::: not
# he ----> PRON ::::: he
# dead ----> ADJ ::::: dead
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# give ----> VERB ::::: give
# me ----> PRON ::::: I
# my ----> PRON ::::: my
# sock ----> NOUN ::::: sock
# back ----> ADP ::::: back
# ! ----> PUNCT ::::: !
# Dodge ----> PROPN ::::: Dodge
# Socks ----> PROPN ::::: Socks
# was ----> AUX ::::: be
# a ----> DET ::::: a
# bad ----> ADJ ::::: bad
# idea ----> NOUN ::::: idea
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoa ----> INTJ ::::: whoa
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# angrily ----> ADV ::::: angrily
# ] ----> PUNCT ::::: ]
# Look ----> VERB ::::: look
# dude ----> NOUN ::::: dude
# , ----> PUNCT ::::: ,
# just ----> ADV ::::: just
# tell ----> VERB ::::: tell
# me ----> PRON ::::: I
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# up ----> ADV ::::: up
# , ----> PUNCT ::::: ,
# 'cause ----> SCONJ ::::: 'cause
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# crazier ----> ADJ ::::: crazy
# than ----> ADP ::::: than
# a ----> DET ::::: a
# cannonball ----> NOUN ::::: cannonball
# tonight ----> NOUN ::::: tonight
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# looks ----> VERB ::::: look
# out ----> ADP ::::: out
# a ----> DET ::::: a
# window ----> NOUN ::::: window
# behind ----> ADP ::::: behind
# Jake ----> PROPN ::::: Jake
# and ----> CCONJ ::::: and
# sees ----> VERB ::::: see
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# coming ----> VERB ::::: come
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Thinking ----> NOUN ::::: thinking
# ] ----> X ::::: ]
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# goodness ----> NOUN ::::: goodness
# ! ----> PUNCT ::::: !
# Princess ----> PROPN ::::: Princess
# has ----> AUX ::::: have
# n't ----> PART ::::: not
# finished ----> VERB ::::: finish
# the ----> DET ::::: the
# equation ----> NOUN ::::: equation
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# are ----> AUX ::::: be
# here ----> ADV ::::: here
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# uh ----> INTJ ::::: uh
# , ----> PUNCT ::::: ,
# she ----> PRON ::::: she
# just ----> ADV ::::: just
# want ----> VERB ::::: want
# this ----> DET ::::: this
# slumber ----> NOUN ::::: slumber
# party ----> NOUN ::::: party
# to ----> PART ::::: to
# be ----> AUX ::::: be
# super ----> ADJ ::::: super
# fun ----> NOUN ::::: fun
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# if ----> SCONJ ::::: if
# I ----> PRON ::::: I
# did ----> AUX ::::: do
# have ----> VERB ::::: have
# something ----> PRON ::::: something
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# then ----> ADV ::::: then
# I ----> PRON ::::: I
# would ----> AUX ::::: would
# ...
# now ----> ADV ::::: now
# answer ----> VERB ::::: answer
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Guardian ----> PROPN ::::: Guardian
# 2 ----> NUM ::::: 2
# : ----> PUNCT ::::: :
# ... ----> PUNCT ::::: ...
# Math ----> NOUN ::::: math
# questions ----> NOUN ::::: question
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Mathematical ----> PROPN ::::: Mathematical
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Finn ----> PROPN ::::: Finn
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# terrible ----> ADJ ::::: terrible
# at ----> ADP ::::: at
# math ----> NOUN ::::: math
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Awww ----> PROPN ::::: Awww
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Guardian ----> PROPN ::::: Guardian
# 1 ----> NUM ::::: 1
# : ----> PUNCT ::::: :
# Now ----> ADV ::::: now
# , ----> PUNCT ::::: ,
# solve ----> VERB ::::: solve
# this ----> PRON ::::: this
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Puts ----> VERB ::::: put
# Finn ----> PROPN ::::: Finn
# in ----> ADP ::::: in
# front ----> NOUN ::::: front
# of ----> ADP ::::: of
# Guardian ----> PROPN ::::: Guardian
# 2 ----> NUM ::::: 2
# , ----> PUNCT ::::: ,
# who ----> PRON ::::: who
# puts ----> VERB ::::: put
# up ----> ADP ::::: up
# a ----> DET ::::: a
# hologram ----> NOUN ::::: hologram
# of ----> ADP ::::: of
# an ----> DET ::::: an
# overly ----> ADV ::::: overly
# complicated ----> ADJ ::::: complicated
# math ----> NOUN ::::: math
# equation ----> NOUN ::::: equation
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Uhh ----> PROPN ::::: Uhh
# .... ----> PROPN ::::: ....
#
#  ----> SPACE :::::
#
# Guardian ----> PROPN ::::: Guardian
# 2 ----> NUM ::::: 2
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# wait ----> VERB ::::: wait
# , ----> PUNCT ::::: ,
# wait ----> VERB ::::: wait
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# thought ----> VERB ::::: think
# of ----> ADP ::::: of
# a ----> DET ::::: a
# better ----> ADJ ::::: well
# one ----> NOUN ::::: one
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Replaces ----> VERB ::::: replace
# the ----> DET ::::: the
# equation ----> NOUN ::::: equation
# with ----> ADP ::::: with
# one ----> NUM ::::: one
# that ----> PRON ::::: that
# says ----> VERB ::::: say
# " ----> PUNCT ::::: "
# 2 ----> NUM ::::: 2
# + ----> NUM ::::: +
# 2 ----> NUM ::::: 2
# " ----> PUNCT ::::: "
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Guardian ----> PROPN ::::: Guardian
# 1 ----> NUM ::::: 1
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# ! ----> PUNCT ::::: !
# Two ----> NUM ::::: two
# plus ----> CCONJ ::::: plus
# two ----> NUM ::::: two
# . ----> PUNCT ::::: .
# Solve ----> VERB ::::: solve
# it ----> PRON ::::: it
# or ----> CCONJ ::::: or
# die ----> VERB ::::: die
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Uhh ----> INTJ ::::: uhh
# . ----> PUNCT ::::: .
# Four ----> NUM ::::: four
# , ----> PUNCT ::::: ,
# right ----> ADJ ::::: right
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Guardians ----> PROPN ::::: Guardians
# laugh ----> VERB ::::: laugh
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Guardian ----> PROPN ::::: Guardian
# 1 ----> NUM ::::: 1
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# correct ----> ADJ ::::: correct
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Guardians ----> NOUN ::::: guardian
# heads ----> NOUN ::::: head
# explode ----> VERB ::::: explode
# and ----> CCONJ ::::: and
# time ----> NOUN ::::: time
# rewinds ----> NOUN ::::: rewind
# , ----> PUNCT ::::: ,
# night ----> NOUN ::::: night
# becomes ----> VERB ::::: become
# day ----> NOUN ::::: day
# , ----> PUNCT ::::: ,
# Guardian ----> PROPN ::::: Guardian
# 2 ----> PROPN ::::: 2
# 's ----> PART ::::: 's
# head ----> NOUN ::::: head
# comes ----> VERB ::::: come
# back ----> ADV ::::: back
# and ----> CCONJ ::::: and
# he ----> PRON ::::: he
# talks ----> VERB ::::: talk
# backwards ----> ADV ::::: backwards
# and ----> CCONJ ::::: and
# goes ----> VERB ::::: go
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# sitting ----> VERB ::::: sit
# and ----> CCONJ ::::: and
# blowing ----> VERB ::::: blow
# bubbles ----> NOUN ::::: bubble
# around ----> ADP ::::: around
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# Kingdom ----> PROPN ::::: Kingdom
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# happening ----> VERB ::::: happen
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 've ----> AUX ::::: have
# defeated ----> VERB ::::: defeat
# the ----> DET ::::: the
# broken ----> VERB ::::: break
# royal ----> ADJ ::::: royal
# promise ----> NOUN ::::: promise
# ! ----> PUNCT ::::: !
# The ----> DET ::::: the
# Gumball ----> PROPN ::::: Gumball
# Guardians ----> PROPN ::::: Guardians
# are ----> AUX ::::: be
# resetting ----> VERB ::::: reset
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Guardian ----> PROPN ::::: Guardian
# 1 ----> NUM ::::: 1
# drops ----> VERB ::::: drop
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# , ----> PUNCT ::::: ,
# who ----> PRON ::::: who
# teleport ----> VERB ::::: teleport
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# 's ----> PART ::::: 's
# lab ----> NOUN ::::: lab
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Slamacow ----> PROPN ::::: Slamacow
# ! ----> PUNCT ::::: !
# That ----> PRON ::::: that
# was ----> AUX ::::: be
# tops ----> NOUN ::::: top
# ! ----> PUNCT ::::: !
# Who ----> PRON ::::: who
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# good ----> ADJ ::::: good
# at ----> ADP ::::: at
# math ----> NOUN ::::: math
# ? ----> PUNCT ::::: ?
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# all ----> PRON ::::: all
# " ----> PUNCT ::::: "
# Four ----> NUM ::::: four
# ! ----> PUNCT ::::: !
# " ----> PUNCT ::::: "
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Four ----> NUM ::::: four
# , ----> PUNCT ::::: ,
# four ----> NUM ::::: four
# ... ----> PUNCT ::::: ...
# Four ----> NUM ::::: four
# , ----> PUNCT ::::: ,
# four ----> NUM ::::: four
# , ----> PUNCT ::::: ,
# four ----> NUM ::::: four
# ... ----> PUNCT ::::: ...
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
# The ----> DET ::::: the
# answer ----> NOUN ::::: answer
# was ----> AUX ::::: be
# so ----> ADV ::::: so
# simple ----> ADJ ::::: simple
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# too ----> ADV ::::: too
# smart ----> ADJ ::::: smart
# to ----> PART ::::: to
# see ----> VERB ::::: see
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# welcome ----> ADJ ::::: welcome
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# ' ----> PUNCT ::::: '
# 4 ----> NUM ::::: 4
# ' ----> PUNCT ::::: '
# is ----> AUX ::::: be
# the ----> DET ::::: the
# last ----> ADJ ::::: last
# figure ----> NOUN ::::: figure
# I ----> PRON ::::: I
# need ----> VERB ::::: need
# to ----> PART ::::: to
# perfect ----> VERB ::::: perfect
# my ----> PRON ::::: my
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# In ----> ADP ::::: in
# the ----> DET ::::: the
# foyer ----> NOUN ::::: foyer
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# pours ----> VERB ::::: pour
# the ----> DET ::::: the
# serum ----> NOUN ::::: serum
# on ----> ADP ::::: on
# a ----> DET ::::: a
# zombie ----> NOUN ::::: zombie
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Revived ----> VERB ::::: revive
# Zombie ----> PROPN ::::: Zombie
# : ----> PUNCT ::::: :
# Golly ----> PROPN ::::: Golly
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# pour ----> VERB ::::: pour
# the ----> DET ::::: the
# serum ----> NOUN ::::: serum
# on ----> ADP ::::: on
# all ----> DET ::::: all
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Woohoo ----> PROPN ::::: Woohoo
# ! ----> PUNCT ::::: !
# Yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# messed ----> VERB ::::: mess
# up ----> ADP ::::: up
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# sweet ----> ADJ ::::: sweet
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# : ----> PUNCT ::::: :
# 진짜로 ----> NOUN ::::: 진짜로
# . ----> PUNCT ::::: .
# ( ----> PUNCT ::::: (
# " ----> PUNCT ::::: "
# Truly ----> ADV ::::: truly
# it ----> PRON ::::: it
# is ----> AUX ::::: be
# . ----> PUNCT ::::: .
# " ----> PUNCT ::::: "
# ) ----> PUNCT ::::: )
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# revive ----> VERB ::::: revive
# more ----> ADJ ::::: more
# Candy ----> PROPN ::::: Candy
# Zombies ----> PROPN ::::: Zombies
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Candy ----> PROPN ::::: Candy
# Person ----> PROPN ::::: Person
# 1 ----> NUM ::::: 1
# : ----> PUNCT ::::: :
# Uncle ----> PROPN ::::: Uncle
# Chewy ----> PROPN ::::: Chewy
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Candy ----> PROPN ::::: Candy
# Person ----> PROPN ::::: Person
# 2 ----> NUM ::::: 2
# : ----> PUNCT ::::: :
# Grandma ----> PROPN ::::: Grandma
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Ice ----> PROPN ::::: Ice
# Cream ----> PROPN ::::: Cream
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Former ----> ADJ ::::: former
# dead ----> ADJ ::::: dead
# relative ----> NOUN ::::: relative
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Starchy ----> PROPN ::::: Starchy
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Starchy ----> PROPN ::::: Starchy
# : ----> PUNCT ::::: :
# Mornin ----> PROPN ::::: Mornin
# ' ----> PUNCT ::::: '
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> PUNCT ::::: [
# Walks ----> VERB ::::: walk
# over ----> ADP ::::: over
# to ----> ADP ::::: to
# Finn ----> PROPN ::::: Finn
# ] ----> PUNCT ::::: ]
# Man ----> NOUN ::::: man
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# broke ----> VERB ::::: break
# a ----> DET ::::: a
# Royal ----> PROPN ::::: Royal
# Promise ----> PROPN ::::: Promise
# ? ----> PUNCT ::::: ?
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# nuts ----> ADJ ::::: nuts
# . ----> PUNCT ::::: .
# All ----> PRON ::::: all
# you ----> PRON ::::: you
# had ----> VERB ::::: have
# to ----> PART ::::: to
# do ----> VERB ::::: do
# is ----> AUX ::::: be
# say ----> VERB ::::: say
# that ----> SCONJ ::::: that
# it ----> PRON ::::: it
# was ----> AUX ::::: be
# a ----> DET ::::: a
# royal ----> ADJ ::::: royal
# secret ----> NOUN ::::: secret
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# know ----> VERB ::::: know
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# up ----> ADP ::::: up
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Walks ----> VERB ::::: walk
# away ----> ADV ::::: away
# from ----> ADP ::::: from
# Finn ----> PROPN ::::: Finn
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# hope ----> VERB ::::: hope
# you ----> PRON ::::: you
# grasp ----> VERB ::::: grasp
# the ----> DET ::::: the
# full ----> ADJ ::::: full
# consequences ----> NOUN ::::: consequence
# of ----> ADP ::::: of
# breaking ----> VERB ::::: break
# promises ----> NOUN ::::: promise
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Heck ----> INTJ ::::: heck
# yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# If ----> SCONJ ::::: if
# I ----> PRON ::::: I
# break ----> VERB ::::: break
# a ----> DET ::::: a
# Royal ----> PROPN ::::: Royal
# Promise ----> PROPN ::::: Promise
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# get ----> VERB ::::: get
# to ----> PART ::::: to
# fight ----> VERB ::::: fight
# zombies ----> NOUN ::::: zombie
# , ----> PUNCT ::::: ,
# throw ----> VERB ::::: throw
# slumber ----> NOUN ::::: slumber
# parties ----> NOUN ::::: party
# , ----> PUNCT ::::: ,
# awake ----> ADJ ::::: awake
# Gumball ----> PROPN ::::: Gumball
# Guardians ----> PROPN ::::: Guardians
# and ----> CCONJ ::::: and
# ... ----> PUNCT ::::: ...
# and ----> CCONJ ::::: and
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Alright ----> INTJ ::::: alright
# , ----> PUNCT ::::: ,
# alright ----> INTJ ::::: alright
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# evilly ----> ADV ::::: evilly
# ] ----> PUNCT ::::: ]
# And ----> CCONJ ::::: and
# reverse ----> VERB ::::: reverse
# death ----> NOUN ::::: death
# itself ----> PRON ::::: itself
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# adorable ----> ADJ ::::: adorable
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# keep ----> VERB ::::: keep
# your ----> PRON ::::: your
# promises ----> NOUN ::::: promise
# , ----> PUNCT ::::: ,
# okay ----> INTJ ::::: okay
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# will ----> AUX ::::: will
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# notices ----> VERB ::::: notice
# Starchy ----> PROPN ::::: Starchy
# gnawing ----> VERB ::::: gnaw
# on ----> ADP ::::: on
# his ----> PRON ::::: his
# leg ----> NOUN ::::: leg
# and ----> CCONJ ::::: and
# picks ----> VERB ::::: pick
# him ----> PRON ::::: he
# up ----> ADP ::::: up
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Starchy ----> PROPN ::::: Starchy
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# a ----> DET ::::: a
# zombie ----> NOUN ::::: zombie
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Starchy ----> PROPN ::::: Starchy
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# help ----> VERB ::::: help
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
# Flesh ----> NOUN ::::: flesh
# is ----> AUX ::::: be
# delicious ----> ADJ ::::: delicious
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# delicious ----> ADJ ::::: delicious
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Starchy ----> PROPN ::::: Starchy
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# squeeze ----> VERB ::::: squeeze
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# fart ----> VERB ::::: fart
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# squeezes ----> VERB ::::: squeeze
# him ----> PRON ::::: he
# , ----> PUNCT ::::: ,
# Starchy ----> PROPN ::::: Starchy
# farts ----> NOUN ::::: fart
# ] ----> PUNCT ::::: ]
#
#
#  ----> SPACE :::::
#
#
# Episodes ----> NOUN ::::: episode
# ends ----> VERB ::::: end

# %%
spacy.explain("NOUN")
# Out:
# 'noun'

# %% [markdown]
# ### For spaCy: define a function to collect the words you want

# %%
def wordCollector(words):
    wordList = []
    count = 0
    for token in words:
        if token.pos_ == "VERB":
            count += 1
            # print(count, ": ", token.text, " lemma: ", token.lemma_, " pos: ", token.pos_)
            # don't forget the underscore after token.lemma_ , token.pos_, etc.!
            wordList.append(token.lemma_)
            # print(count, ": ", token, token.pos_)
    # print(count, ": ", adjectives)
    return wordList
myWords = wordCollector(spacyRead)
print(myWords)
# Out:
# ['begin', 'chase', 'think', 'get', 'stretch', 'catch', 'let', 'add', 'add', 'shape', 'puff', 'bring', 'fill', 'look', 'do', 'do', 'hit', 'pick', 'pick', 'serve', 'open', 'reveal', 'use', 'apply', 'start', 'glow', 'fizz', 'happen', 'come', 'come', 'arise', 'moan', 'wait', 'leap', 'fall', 'infect', 'begin', 'arise', 'look', 'work', 'come', "they're", 'rub', 'look', 'lash', 'eat', 'push', 'ground', 'go', 'attract', 'make', 'chew', 'kick', 'run', 'kick', 'get', 'ring', 'mumble', 'walk', 'go', 'notice', 'leave', 'worry', 'hurry', 'hear', 'come', 'explain', 'get', 'carry', 'hope', 'close', 'get', 'account', 'assemble', 'go', 'have', 'cheer', 'wait', 'cover', 'go', 'start', 'party', 'muffle', 'carry', 'know', 'know', 'flip', 'mean', 'flip', 'mean', 'flip', 'change', 'arrive', 'bring', 'wait', 'turn', 'lower', 'do', 'come', 'go', 'start', 'scream', 'gasp', 'explode', 'explode', 'get', 'tell', 'need', 'promise', 'let', 'find', 'have', 'kneel', 'cloister', 'finish', 'keep', 'distract', 'do', 'tell', 'leave', 'wait', 'tell', 'enter', 'tell', 'know', 'cover', 'go', 'laugh', 'skip', 'think', 'get', 'want', 'play', 'ask', 'tell', 'dare', 'dare', 'take', 'go', 'suppose', 'tell', 'shed', 'know', 'dare', 'prefer', 'eat', 'kill', 'dare', 'dare', 'tell', 'go', 'talk', 'go', 'visualize', 'promise', 'freakin', 'tell', 'play', 'throw', 'go', 'play', "'", 'stop', 'dodge', 'sock', 'give', 'look', 'tell', 'look', 'see', 'come', 'finish', 'want', 'have', 'tell', 'make', 'be', 'stop', 'be', 'arise', 'shut', 'lose', 'know', '웃겨', 'got', 'kid', 'play', 'close', 'go', 'come', 'make', 'spill', 'hear', 'look', 'shout', 'come', 'begin', 'bang', 'hear', 'hear', 'hear', 'begin', 'hear', 'hear', 'understand', 'make', 'begin', 'shake', 'wait', 'mean', 'turn', 'come', 'dance', 'bust', 'come', 'rush', 'grab', 'play', 'barricade', 'come', 'let', 'block', 'cheer', 'begin', 'blockade', 'come', 'think', 'keep', 'find', 'find', 'talk', 'give', 'grab', 'go', 'smash', 'thank', 'take', 'don', 'run', 'swing', 'get', 'hang', 'burst', 'smash', 'smash', 'smash', 'cause', 'fall', 'kneel', 'lick', 'smash', 'eat', 'do', 'work', 'come', 'grab', 'fill', 'eat', 'notice', 'happen', 'kill', 'raise', 'freeze', 'leave', 'move', 'go', 'enter', 'break', 'mean', 'freak', 'break', 'start', 'shake', 'come', 'burst', 'grab', 'pull', 'break', 'breathe', 'wait', 'care', 'give', 'answer', 'solve', 'put', 'put', 'wait', 'wait', 'think', 'replace', 'say', 'solve', 'die', 'laugh', 'explode', 'become', 'come', 'talk', 'go', 'sit', 'blow', 'happen', 'defeat', 'break', 'reset', 'drop', 'teleport', 'see', 'need', 'perfect', 'pour', 'revive', 'pour', 'mess', 'revive', 'walk', 'break', 'have', 'do', 'say', 'know', 'walk', 'hope', 'grasp', 'break', 'break', 'get', 'fight', 'throw', 'reverse', 'keep', 'notice', 'gnaw', 'pick', 'help', 'squeeze', 'fart', 'squeeze', 'end']

# %% [markdown]
# ### Frequency of words
# Here is something we can do: Because we didn't make a set of unique words, we have a list full of the original words.
#
# The **Counter function** in python's collections library provides a speedy way to count the number of times something appears in a list!
#
# What we see in the output of this next cell is a special data structure in python: it's a list of tuples: `[('token', number), ('token', number), ...]`

# %%
from collections import Counter

word_freq = Counter(myWords)
# most_common() converts the Counter's dictionary to a tuple series and sorts it
ranked = word_freq.most_common()
topTen = word_freq.most_common(10)
print(topTen)
lastTen = word_freq.most_common()[:-11:-1]
print(lastTen)
# Out:
# [('come', 15), ('go', 14), ('tell', 10), ('get', 8), ('wait', 8), ('hear', 7), ('break', 7), ('begin', 6), ('look', 6), ('do', 6)]
# [('end', 1), ('fart', 1), ('help', 1), ('gnaw', 1), ('reverse', 1), ('fight', 1), ('grasp', 1), ('mess', 1), ('perfect', 1), ('teleport', 1)]

# %% [markdown]
# ## Write something to an output file (just text)
#
# Let's write that to an output file and save it, just to practice this.
# Set this to output in your workspace where you want it (same folder as this notebook or someplace new?)
# You can set a relative filepath if you want to be tidy and save things in an output folder...
#
# When you're saving output, Python (and most imperative programming languages) require that you first **open** the file you're going to be saving and set **w** for write.
# Here we're storing that opened file in a variable named `o`, and then **filling** it with the contents of your variable using `o.write()`.
# One more tricky thing: if we try to output `r` straight, we'll see an interesting error...run the cell to see it.

# %%
o = open("verbFreq.txt", "w")
for r in ranked:
    o.write(r + "\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 o = open("verbFreq.txt", "w")
#       2 for r in ranked:
# ----> 3     o.write(r + "\n")
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %% [markdown]
# **Let's try that again...**
# The error message shows you what's wrong: Python won't print its super special tuple form to a file, so
# we convert it to a nice string with `str()`.

# %%
o = open("verbFreq.txt", "w")
for r in ranked:
    o.write(str(r) + "\n")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[11], line 3
#       1 o = open("verbFreq.txt", "w")
#       2 for r in ranked:
# ----> 3     o.write(str(r) + "\n")
#
# File c:\python312\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 2-3: character maps to <undefined>

# %% [markdown]
# ## Plotting a simple chart with a Python Library
#
# We have data we can use to plot. There are SVG plotting libraries designed for Python, and one of the best for us working on websites is PyGal, since it's easy to customize and outputs a nice file for use on a website.
#
# Read the [PyGal documentation](https://www.pygal.org/en/stable/documentation/index.html) (or any plotting library you find) to see how you can adapt it as you wish.

# %%
import pygal
from pygal.style import DarkSolarizedStyle

# Create chart
bar_chart = pygal.Bar(style=DarkSolarizedStyle)
bar_chart.title = 'Top 10 Most Frequent Verbs in Sixteen Candles'

# Add data
for word, freq in topTen:
    bar_chart.add(word, freq)

# Save chart
bar_chart.render_to_file('top10_verbs.svg')

# %% [markdown]
# ### Go find the output SVG!
# ##### and go back and change the style :-)
# pygal's `render_to_file('....')` function is very convenient. Notice you don't have to open a file to write the output and all that, because pygal's function library is handling it.
#
# Remember to save your output file with the `.svg` output exgtension
#
# Open the output in a file browser on your computer. Like it? You can/should change the style to see how they look:
#
# * Check out the different types of plots (only you want to choose plot types that make sense for your data).
#   What else could you use? [PyGal documentation](https://www.pygal.org/en/stable/documentation/index.html)
#   * Notice that different plot types are looking for specific pieces of data.
# * Check out the styles: [PyGal Styles](https://www.pygal.org/en/stable/documentation/builtin_styles.html)
#
# You may want to change where you save this in your local workspace!

# %% [markdown]
# ### Send my list of words OR word lemmas to WordNet and get me synset info
#
# Okay, how about we try to connect this up with Wordnet to study ambiguity and such? We can use NLTK's power tools with spaCy as we wish. . .

# %%
import nltk
from nltk.corpus import wordnet as wn

# %%
setOfWords = set(myWords)
lowerCased = [w.lower() for w in setOfWords]

sortedWords = sorted(lowerCased)
print(sortedWords)
# Out:
# ["'", 'account', 'add', 'answer', 'apply', 'arise', 'arrive', 'ask', 'assemble', 'attract', 'bang', 'barricade', 'be', 'become', 'begin', 'block', 'blockade', 'blow', 'break', 'breathe', 'bring', 'burst', 'bust', 'care', 'carry', 'catch', 'cause', 'change', 'chase', 'cheer', 'chew', 'cloister', 'close', 'come', 'cover', 'dance', 'dare', 'defeat', 'die', 'distract', 'do', 'dodge', 'don', 'drop', 'eat', 'end', 'enter', 'explain', 'explode', 'fall', 'fart', 'fight', 'fill', 'find', 'finish', 'fizz', 'flip', 'freak', 'freakin', 'freeze', 'gasp', 'get', 'give', 'glow', 'gnaw', 'go', 'got', 'grab', 'grasp', 'ground', 'hang', 'happen', 'have', 'hear', 'help', 'hit', 'hope', 'hurry', 'infect', 'keep', 'kick', 'kid', 'kill', 'kneel', 'know', 'lash', 'laugh', 'leap', 'leave', 'let', 'lick', 'look', 'lose', 'lower', 'make', 'mean', 'mess', 'moan', 'move', 'muffle', 'mumble', 'need', 'notice', 'open', 'party', 'perfect', 'pick', 'play', 'pour', 'prefer', 'promise', 'puff', 'pull', 'push', 'put', 'raise', 'replace', 'reset', 'reveal', 'reverse', 'revive', 'ring', 'rub', 'run', 'rush', 'say', 'scream', 'see', 'serve', 'shake', 'shape', 'shed', 'shout', 'shut', 'sit', 'skip', 'smash', 'sock', 'solve', 'spill', 'squeeze', 'start', 'stop', 'stretch', 'suppose', 'swing', 'take', 'talk', 'teleport', 'tell', 'thank', "they're", 'think', 'throw', 'turn', 'understand', 'use', 'visualize', 'wait', 'walk', 'want', 'work', 'worry', '웃겨']

# %%
for w in myWords:
    synsets = len(wn.synsets(w))
    print("The word ", w, "belongs to ", synsets, "synsets in WordNet.")
# Out:
# The word  begin belongs to  11 synsets in WordNet.
# The word  chase belongs to  7 synsets in WordNet.
# The word  think belongs to  14 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  stretch belongs to  20 synsets in WordNet.
# The word  catch belongs to  39 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  add belongs to  7 synsets in WordNet.
# The word  add belongs to  7 synsets in WordNet.
# The word  shape belongs to  11 synsets in WordNet.
# The word  puff belongs to  17 synsets in WordNet.
# The word  bring belongs to  11 synsets in WordNet.
# The word  fill belongs to  11 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  hit belongs to  24 synsets in WordNet.
# The word  pick belongs to  21 synsets in WordNet.
# The word  pick belongs to  21 synsets in WordNet.
# The word  serve belongs to  16 synsets in WordNet.
# The word  open belongs to  36 synsets in WordNet.
# The word  reveal belongs to  3 synsets in WordNet.
# The word  use belongs to  13 synsets in WordNet.
# The word  apply belongs to  10 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  glow belongs to  12 synsets in WordNet.
# The word  fizz belongs to  2 synsets in WordNet.
# The word  happen belongs to  5 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  arise belongs to  7 synsets in WordNet.
# The word  moan belongs to  2 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  leap belongs to  8 synsets in WordNet.
# The word  fall belongs to  44 synsets in WordNet.
# The word  infect belongs to  4 synsets in WordNet.
# The word  begin belongs to  11 synsets in WordNet.
# The word  arise belongs to  7 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  work belongs to  34 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  they're belongs to  0 synsets in WordNet.
# The word  rub belongs to  5 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  lash belongs to  7 synsets in WordNet.
# The word  eat belongs to  6 synsets in WordNet.
# The word  push belongs to  15 synsets in WordNet.
# The word  ground belongs to  30 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  attract belongs to  3 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  chew belongs to  3 synsets in WordNet.
# The word  kick belongs to  14 synsets in WordNet.
# The word  run belongs to  57 synsets in WordNet.
# The word  kick belongs to  14 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  ring belongs to  15 synsets in WordNet.
# The word  mumble belongs to  3 synsets in WordNet.
# The word  walk belongs to  17 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  notice belongs to  11 synsets in WordNet.
# The word  leave belongs to  17 synsets in WordNet.
# The word  worry belongs to  8 synsets in WordNet.
# The word  hurry belongs to  6 synsets in WordNet.
# The word  hear belongs to  5 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  explain belongs to  3 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  carry belongs to  41 synsets in WordNet.
# The word  hope belongs to  9 synsets in WordNet.
# The word  close belongs to  37 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  account belongs to  14 synsets in WordNet.
# The word  assemble belongs to  3 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  cheer belongs to  7 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  cover belongs to  36 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  party belongs to  6 synsets in WordNet.
# The word  muffle belongs to  3 synsets in WordNet.
# The word  carry belongs to  41 synsets in WordNet.
# The word  know belongs to  12 synsets in WordNet.
# The word  know belongs to  12 synsets in WordNet.
# The word  flip belongs to  18 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  flip belongs to  18 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  flip belongs to  18 synsets in WordNet.
# The word  change belongs to  20 synsets in WordNet.
# The word  arrive belongs to  2 synsets in WordNet.
# The word  bring belongs to  11 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  turn belongs to  38 synsets in WordNet.
# The word  lower belongs to  16 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  scream belongs to  6 synsets in WordNet.
# The word  gasp belongs to  2 synsets in WordNet.
# The word  explode belongs to  10 synsets in WordNet.
# The word  explode belongs to  10 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  need belongs to  7 synsets in WordNet.
# The word  promise belongs to  6 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  kneel belongs to  2 synsets in WordNet.
# The word  cloister belongs to  5 synsets in WordNet.
# The word  finish belongs to  15 synsets in WordNet.
# The word  keep belongs to  25 synsets in WordNet.
# The word  distract belongs to  2 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  leave belongs to  17 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  enter belongs to  9 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  know belongs to  12 synsets in WordNet.
# The word  cover belongs to  36 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  laugh belongs to  4 synsets in WordNet.
# The word  skip belongs to  8 synsets in WordNet.
# The word  think belongs to  14 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  want belongs to  9 synsets in WordNet.
# The word  play belongs to  52 synsets in WordNet.
# The word  ask belongs to  7 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  dare belongs to  4 synsets in WordNet.
# The word  dare belongs to  4 synsets in WordNet.
# The word  take belongs to  44 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  suppose belongs to  5 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  shed belongs to  6 synsets in WordNet.
# The word  know belongs to  12 synsets in WordNet.
# The word  dare belongs to  4 synsets in WordNet.
# The word  prefer belongs to  4 synsets in WordNet.
# The word  eat belongs to  6 synsets in WordNet.
# The word  kill belongs to  17 synsets in WordNet.
# The word  dare belongs to  4 synsets in WordNet.
# The word  dare belongs to  4 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  talk belongs to  11 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  visualize belongs to  4 synsets in WordNet.
# The word  promise belongs to  6 synsets in WordNet.
# The word  freakin belongs to  0 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  play belongs to  52 synsets in WordNet.
# The word  throw belongs to  20 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  play belongs to  52 synsets in WordNet.
# The word  ' belongs to  0 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  dodge belongs to  6 synsets in WordNet.
# The word  sock belongs to  3 synsets in WordNet.
# The word  give belongs to  45 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  see belongs to  25 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  finish belongs to  15 synsets in WordNet.
# The word  want belongs to  9 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  arise belongs to  7 synsets in WordNet.
# The word  shut belongs to  5 synsets in WordNet.
# The word  lose belongs to  11 synsets in WordNet.
# The word  know belongs to  12 synsets in WordNet.
# The word  웃겨 belongs to  0 synsets in WordNet.
# The word  got belongs to  36 synsets in WordNet.
# The word  kid belongs to  7 synsets in WordNet.
# The word  play belongs to  52 synsets in WordNet.
# The word  close belongs to  37 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  spill belongs to  10 synsets in WordNet.
# The word  hear belongs to  5 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  shout belongs to  5 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  begin belongs to  11 synsets in WordNet.
# The word  bang belongs to  12 synsets in WordNet.
# The word  hear belongs to  5 synsets in WordNet.
# The word  hear belongs to  5 synsets in WordNet.
# The word  hear belongs to  5 synsets in WordNet.
# The word  begin belongs to  11 synsets in WordNet.
# The word  hear belongs to  5 synsets in WordNet.
# The word  hear belongs to  5 synsets in WordNet.
# The word  understand belongs to  5 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  begin belongs to  11 synsets in WordNet.
# The word  shake belongs to  15 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  turn belongs to  38 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  dance belongs to  7 synsets in WordNet.
# The word  bust belongs to  10 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  rush belongs to  16 synsets in WordNet.
# The word  grab belongs to  8 synsets in WordNet.
# The word  play belongs to  52 synsets in WordNet.
# The word  barricade belongs to  5 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  block belongs to  28 synsets in WordNet.
# The word  cheer belongs to  7 synsets in WordNet.
# The word  begin belongs to  11 synsets in WordNet.
# The word  blockade belongs to  6 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  think belongs to  14 synsets in WordNet.
# The word  keep belongs to  25 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  talk belongs to  11 synsets in WordNet.
# The word  give belongs to  45 synsets in WordNet.
# The word  grab belongs to  8 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  smash belongs to  16 synsets in WordNet.
# The word  thank belongs to  1 synsets in WordNet.
# The word  take belongs to  44 synsets in WordNet.
# The word  don belongs to  7 synsets in WordNet.
# The word  run belongs to  57 synsets in WordNet.
# The word  swing belongs to  22 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  hang belongs to  18 synsets in WordNet.
# The word  burst belongs to  12 synsets in WordNet.
# The word  smash belongs to  16 synsets in WordNet.
# The word  smash belongs to  16 synsets in WordNet.
# The word  smash belongs to  16 synsets in WordNet.
# The word  cause belongs to  7 synsets in WordNet.
# The word  fall belongs to  44 synsets in WordNet.
# The word  kneel belongs to  2 synsets in WordNet.
# The word  lick belongs to  7 synsets in WordNet.
# The word  smash belongs to  16 synsets in WordNet.
# The word  eat belongs to  6 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  work belongs to  34 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  grab belongs to  8 synsets in WordNet.
# The word  fill belongs to  11 synsets in WordNet.
# The word  eat belongs to  6 synsets in WordNet.
# The word  notice belongs to  11 synsets in WordNet.
# The word  happen belongs to  5 synsets in WordNet.
# The word  kill belongs to  17 synsets in WordNet.
# The word  raise belongs to  31 synsets in WordNet.
# The word  freeze belongs to  14 synsets in WordNet.
# The word  leave belongs to  17 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  enter belongs to  9 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  freak belongs to  3 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  shake belongs to  15 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  burst belongs to  12 synsets in WordNet.
# The word  grab belongs to  8 synsets in WordNet.
# The word  pull belongs to  24 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  breathe belongs to  9 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  care belongs to  11 synsets in WordNet.
# The word  give belongs to  45 synsets in WordNet.
# The word  answer belongs to  15 synsets in WordNet.
# The word  solve belongs to  3 synsets in WordNet.
# The word  put belongs to  10 synsets in WordNet.
# The word  put belongs to  10 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  think belongs to  14 synsets in WordNet.
# The word  replace belongs to  4 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  solve belongs to  3 synsets in WordNet.
# The word  die belongs to  14 synsets in WordNet.
# The word  laugh belongs to  4 synsets in WordNet.
# The word  explode belongs to  10 synsets in WordNet.
# The word  become belongs to  4 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  talk belongs to  11 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  sit belongs to  10 synsets in WordNet.
# The word  blow belongs to  29 synsets in WordNet.
# The word  happen belongs to  5 synsets in WordNet.
# The word  defeat belongs to  4 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  reset belongs to  4 synsets in WordNet.
# The word  drop belongs to  32 synsets in WordNet.
# The word  teleport belongs to  1 synsets in WordNet.
# The word  see belongs to  25 synsets in WordNet.
# The word  need belongs to  7 synsets in WordNet.
# The word  perfect belongs to  5 synsets in WordNet.
# The word  pour belongs to  6 synsets in WordNet.
# The word  revive belongs to  5 synsets in WordNet.
# The word  pour belongs to  6 synsets in WordNet.
# The word  mess belongs to  8 synsets in WordNet.
# The word  revive belongs to  5 synsets in WordNet.
# The word  walk belongs to  17 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  know belongs to  12 synsets in WordNet.
# The word  walk belongs to  17 synsets in WordNet.
# The word  hope belongs to  9 synsets in WordNet.
# The word  grasp belongs to  6 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  fight belongs to  9 synsets in WordNet.
# The word  throw belongs to  20 synsets in WordNet.
# The word  reverse belongs to  14 synsets in WordNet.
# The word  keep belongs to  25 synsets in WordNet.
# The word  notice belongs to  11 synsets in WordNet.
# The word  gnaw belongs to  2 synsets in WordNet.
# The word  pick belongs to  21 synsets in WordNet.
# The word  help belongs to  12 synsets in WordNet.
# The word  squeeze belongs to  17 synsets in WordNet.
# The word  fart belongs to  2 synsets in WordNet.
# The word  squeeze belongs to  17 synsets in WordNet.
# The word  end belongs to  18 synsets in WordNet.

# %% [markdown]
# ## PyGal Fun with Ambiguity Data
# Okay, what if I want to customize the colors of my plot using the synset ambiguity information?
# This is a little tricky, but we can work with the rgb() color values to plot on a scale of 0 to 255. Here's a little recipe I cooked up, and I got a little help from ChatGPT for the color function.

# %%
from collections import Counter
import pygal
from pygal.style import Style
from nltk.corpus import wordnet as wn

word_freq = Counter(myWords)
topTen = word_freq.most_common(10)
print(topTen)

# Step 1: Get synset count for each of the top 10 verbs
synset_counts = {}
for word, freq in topTen:
    synset_counts[word] = len(wn.synsets(word, pos='v'))

# Step 2: Normalize synset counts to 0–255 for coloring
max_syn = max(synset_counts.values())
min_syn = min(synset_counts.values())

def synset_to_color(syn_count):
    """Maps synset count to a shade of blue (darker = more ambiguous)"""
    if max_syn == min_syn:
        blue = 150
    else:
        blue = int(50 + 205 * (syn_count - min_syn) / (max_syn - min_syn))
    return f'#{0:02x}{0:02x}{blue:02x}'

# Step 3: Create custom Pygal style
custom_style = Style(
    background='white',
    plot_background='white',
    foreground='black',
    foreground_strong='black',
    foreground_subtle='gray',
    opacity='.8',
    opacity_hover='.9',
    transition='400ms ease-in',
    colors=('#cccccc',)  # Give PyGal a dummy color to start
)

# Step 4: Create the bar chart
bar_chart = pygal.Bar(style=custom_style)
bar_chart.title = 'Top 10 Verb Frequencies Colored by Ambiguity (Synsets)'

for word, freq in topTen:
    syns = synset_counts[word]
    color = synset_to_color(syns)
    bar_chart.add(word, [{'value': freq, 'label': f'{word} has {syns} synsets', 'style': f'fill:{color}'}])
    # I can add whatever new info I want (beyond the 'value') to PyGal's tooltip using 'label': 

# Step 5: Render the SVG chart
bar_chart.render_to_file('top_verbs_colored_by_synsets.svg')
# Out:
# [('come', 15), ('go', 14), ('tell', 10), ('get', 8), ('wait', 8), ('hear', 7), ('break', 7), ('begin', 6), ('look', 6), ('do', 6)]

# %% [markdown]
# ## Your Turn!
# Adapt this notebook to explore one or more of your project files. Be sure that you are able to:
# * **Open a file with Python first before you tokenize it**. (This time, try out spaCy.)
# * Collect a selection of words, with POS tagging or without it. (Can you output all the tokens that just have the same beginning or ending?)
# * Options:
#      * Send your words or word lemmas to WordNet and return synset info, and/or
#      * Find out about how frequently each of your selected tokens is used in the text using the Counter.
# * This time, **open a file to write some of the information you retrieve to output**.
# * Add, commit, and push to your GitHub repo.
