# %% [markdown]
# ## Words to Network Data
#
# Now that we know some ways to pull an interesting selection of words, let's think about them like a network. Network analysis involves looking at how things relate to each other based on shared properties.
#
# In this notebook, we will address a simple research question: Which **files** (or **chapters**, or **scenes**, or **authors**, or **titles**) share each others' top 5 or 10 **verbs** (or **adjectives**, or **nouns**, or **WordNet synsets**, etc)?
#
# We will try exploring this as a network of data and import it into network visualization software.
#
# ### Installs in your Terminal
# * If you did not do this in the previous notebook: `pip install spacy`
# * We need the **pandas** library to make dataframes: `pip install pandas`
#
# <pre>
#     ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⣶⣿⣷⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣦⡀
# ⠀⠀⠀⠀⢀⠄⠀⠀⠀⠀⢈⣿⣿⣿⠟⠛⠁⠀⠀⠀⠀⠀⠀⠐⢿⣿⣿⣿⣿⣷
# ⠀⠀⢀⡔⠁⠀⠀⠀⢀⣴⡿⠃⠈⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣿⠟⠁
# ⠀⣠⡟⠀⠀⠀⠀⣰⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢠⣿⠁⠀⠀⠀⢰⣿⣿⡏⠀⠀⠀⢀⣤⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⣾⣿⠀⠀⠀⠀⢸⣿⣿⡇⠀⠀⢠⣿⣿⣿⣿⠀⠀⠀⠀⣰⣾⣶⣆⠀⠀⠀⠀⡄
# ⣿⣿⡀⠀⠀⠀⢸⣿⣿⣧⠀⠀⢸⣿⣿⡿⠃⠀⠀⠀⠀⢿⣿⣿⣿⡆⠀⠀⢸⣧
# ⢿⣿⣧⠀⠀⠀⢸⣿⣿⣿⣦⡀⠀⠉⠉⠀⠀⠀⠀⠀⠀⠈⠻⣿⠿⠁⠀⢠⣿⣿
# ⢸⣿⣿⣷⣄⠀⣿⣿⣿⣿⣿⣿⣷⣦⣄⠀⠲⣶⣶⣶⠀⠀⠀⠀⠀⣀⣴⣿⣿⣿
# ⢰⣿⣿⣿⣿⣷⣽⣿⣿⣿⣿⣿⣿⣿⣿⣦⡄⣬⣅⣀⣠⣾⣿⣿⣿⣿⣿⣿⣿⡟
# ⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣤⣤⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⠇
# ⠀⠹⣿⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⠈⣿⣿⣿⣿⣿⣿⣿⡿⠀
# ⠀⠀⠻⣿⣿⣿⣿⣿⡎⢿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⣿⣿⣿⣿⣿⣿⣿⠃⠀
# ⠀⠀⠀⠙⠻⠿⣿⣿⠗⠀⢻⣿⣿⣿⣿⣿⣿⣿⡇⠀⢸⣿⣿⣿⣿⣿⡿⠃⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣿⣿⣿⣿⣿⣿⣿⠀⢸⣿⣿⣿⡿⠟⠁⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⠿⢿⣿⣿⡿⠇⠀⠈⠉⠁⠀⠀⠀⠀⠀⠀
# </pre>
#
#
#
# Image credit: <https://emojicombos.com/panda-ascii-art>
#
# ### Language Models
# Like NLTK's collections that we downloaded, [spaCy has trained language models](https://spacy.io/usage/models) to download. You download these in your Python script after you import spacy, and after you download once, you don't need to do it again (so you can comment out the download line). We're going to try the medium and large models in English. (It's good to know that both spaCy and NLTK have resources for NLP on other languages, too!)

# %%
import spacy
import os

# %% [markdown]
# ### Downloading language models
# To work with spaCy's pre-trained language models, you need to download them to you virtual environment. There are:
# * en_core_web_sm (smallest--not as much info as the others)
# * **en_core_web_md** (Pretty good date here, size: 34 MB )
# * **en_core_web_lg** (Lots of data here, size: 400 MB.)
# Note that the LARGEST  one will have the most data and probably be the most reliable.

# %%
# CAN YOU SKIP THIS???
# After you download a model into your virtual environment for the first time, you can comment out the download line.
# spaCy's medium and large models will give us the best results for NLP tagging.
# nlp = spacy.cli.download("en_core_web_sm")
# nlp = spacy.cli.download("en_core_web_md")
nlp = spacy.cli.download("en_core_web_lg")

# %% [markdown]
# ### Load the model
# Now we redefine the nlp variable to LOAD the model you downloaded.

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## File Collection
# You can set this to read a collection of text files that you've prepped for natural language processing.
# For this notebook, we'll work with just the dialogue text we pulled from the One Piece project.
# The text is organized as one file for each volume of OnePiece, so we can maybe explore how much the dialogue is relying on certain words, and how it might be changing over the volumes.
#
# We're going to get volume information from OnePiece's filenames (which look like this: `vol-9.txt'. We can use the `os` library to help us isolate the filename from the file extension. Let's try that so we can simplify our references to the volumes when we output our data.

# %%
collPath = 'text'
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            lengthFile = len(readFile)
            print(lengthFile)
# We're just printing out the filepaths and lengths of the files as a "smoke test" to see if we're reading the files.
# Out:
# ATE1
# 13899
# ATE10
# 11434
# ATE11
# 12897
# ATE12
# 8106
# ATE13
# 14038
# ATE14
# 12161
# ATE15
# 11029
# ATE16
# 11513
# ATE17
# 12402
# ATE18
# 11511
# ATE19
# 14177
# ATE2
# 13910
# ATE20
# 14896
# ATE21
# 11371
# ATE22
# 13502
# ATE23
# 11169
# ATE24
# 13519
# ATE25
# 13651
# ATE26
# 12495
# ATE3
# 11505
# ATE4
# 10000
# ATE5
# 12820
# ATE6
# 12950
# ATE7
# 13061
# ATE8
# 13590
# ATE9
# 14545

# %% [markdown]
# ## Collect some words with a little help from spaCy
# Let's build this up to go file by file. We'll start by surveying what we have...(Ultimately we want to collect the top 5 or 10 most frequently repeating words of a kind.)

# %%
# SURVEY IT ALL! :-) (Yeah, lots of data...)
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            for token in spacyRead:
                print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# ATE1
# [ ----> X ::::: [
# The ----> DET ::::: the
# episode ----> NOUN ::::: episode
# begins ----> VERB ::::: begin
# in ----> ADP ::::: in
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# Kingdom ----> PROPN ::::: Kingdom
# , ----> PUNCT ::::: ,
# Jake ----> PROPN ::::: Jake
# is ----> AUX ::::: be
# playfully ----> ADV ::::: playfully
# chasing ----> VERB ::::: chase
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# think ----> VERB ::::: think
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# pretty ----> ADJ ::::: pretty
# way ----> ADV ::::: way
# up ----> ADV ::::: up
# there ----> ADV ::::: there
# but ----> CCONJ ::::: but
# I ----> PRON ::::: I
# can ----> AUX ::::: can
# get ----> VERB ::::: get
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# he ----> PRON ::::: he
# stretches ----> VERB ::::: stretch
# to ----> PART ::::: to
# be ----> AUX ::::: be
# on ----> ADP ::::: on
# Lady ----> PROPN ::::: Lady
# 's ----> PART ::::: 's
# level ----> NOUN ::::: level
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# : ----> PUNCT ::::: :
# 나 ----> X ::::: 나
# 잡아봐봐~ ----> PROPN ::::: 잡아봐봐~
# ( ----> PUNCT ::::: (
# " ----> PUNCT ::::: "
# Catch ----> VERB ::::: catch
# me ----> PRON ::::: I
# if ----> SCONJ ::::: if
# you ----> PRON ::::: you
# can ----> AUX ::::: can
# . ----> PUNCT ::::: .
# " ----> PUNCT ::::: "
# ) ----> PUNCT ::::: )
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# are ----> AUX ::::: be
# in ----> ADP ::::: in
# a ----> DET ::::: a
# cemetery ----> NOUN ::::: cemetery
# with ----> ADP ::::: with
# a ----> DET ::::: a
# table ----> NOUN ::::: table
# full ----> ADJ ::::: full
# of ----> ADP ::::: of
# different ----> ADJ ::::: different
# chemicals ----> NOUN ::::: chemical
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Alright ----> INTJ ::::: alright
# . ----> PUNCT ::::: .
# Let ----> VERB ::::: let
# me ----> PRON ::::: I
# just ----> ADV ::::: just
# add ----> VERB ::::: add
# three ----> NUM ::::: three
# more ----> ADJ ::::: more
# drops ----> NOUN ::::: drop
# of ----> ADP ::::: of
# explosive ----> ADJ ::::: explosive
# diarrhea ----> NOUN ::::: diarrhea
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# She ----> PRON ::::: she
# adds ----> VERB ::::: add
# the ----> DET ::::: the
# explosive ----> ADJ ::::: explosive
# diarrhea ----> NOUN ::::: diarrhea
# and ----> CCONJ ::::: and
# a ----> DET ::::: a
# giant ----> ADJ ::::: giant
# cloud ----> NOUN ::::: cloud
# shaped ----> VERB ::::: shape
# like ----> ADP ::::: like
# a ----> DET ::::: a
# skull ----> NOUN ::::: skull
# puffs ----> VERB ::::: puff
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
# Not ----> PART ::::: not
# a ----> DET ::::: a
# good ----> ADJ ::::: good
# omen ----> NOUN ::::: omen
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Oooo ----> PROPN ::::: Oooo
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# , ----> PUNCT ::::: ,
# when ----> SCONJ ::::: when
# we ----> PRON ::::: we
# bring ----> VERB ::::: bring
# the ----> DET ::::: the
# dead ----> NOUN ::::: dead
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# life ----> NOUN ::::: life
# , ----> PUNCT ::::: ,
# will ----> AUX ::::: will
# it ----> PRON ::::: it
# be ----> AUX ::::: be
# filled ----> VERB ::::: fill
# with ----> ADP ::::: with
# worms ----> NOUN ::::: worm
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# . ----> PUNCT ::::: .
# If ----> SCONJ ::::: if
# my ----> PRON ::::: my
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# works ----> NOUN ::::: work
# , ----> PUNCT ::::: ,
# all ----> DET ::::: all
# the ----> DET ::::: the
# dead ----> ADJ ::::: dead
# Candy ----> PROPN ::::: Candy
# People ----> NOUN ::::: People
# will ----> AUX ::::: will
# look ----> VERB ::::: look
# as ----> ADV ::::: as
# young ----> ADJ ::::: young
# and ----> CCONJ ::::: and
# healthy ----> ADJ ::::: healthy
# as ----> SCONJ ::::: as
# you ----> PRON ::::: you
# do ----> VERB ::::: do
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# does ----> VERB ::::: do
# a ----> DET ::::: a
# " ----> PUNCT ::::: "
# Tarzan ----> NOUN ::::: tarzan
# - ----> PUNCT ::::: -
# yell ----> NOUN ::::: yell
# " ----> PUNCT ::::: "
# while ----> SCONJ ::::: while
# hitting ----> VERB ::::: hit
# his ----> PRON ::::: his
# hands ----> NOUN ::::: hand
# against ----> ADP ::::: against
# his ----> PRON ::::: his
# chest ----> NOUN ::::: chest
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Pick ----> VERB ::::: pick
# up ----> ADP ::::: up
# that ----> DET ::::: that
# platter ----> NOUN ::::: platter
# , ----> PUNCT ::::: ,
# tough ----> ADJ ::::: tough
# guy ----> NOUN ::::: guy
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# picks ----> VERB ::::: pick
# up ----> ADP ::::: up
# a ----> DET ::::: a
# serving ----> VERB ::::: serve
# platter ----> NOUN ::::: platter
# and ----> CCONJ ::::: and
# open ----> VERB ::::: open
# the ----> DET ::::: the
# lid ----> NOUN ::::: lid
# , ----> PUNCT ::::: ,
# revealing ----> VERB ::::: reveal
# a ----> DET ::::: a
# Candy ----> PROPN ::::: Candy
# Person ----> PROPN ::::: Person
# corpse ----> NOUN ::::: corpse
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Old ----> PROPN ::::: Old
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Giggles ----> X ::::: giggles
# ] ----> X ::::: ]
# We ----> PRON ::::: we
# used ----> VERB ::::: use
# to ----> ADP ::::: to
# date ----> NOUN ::::: date
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Applies ----> VERB ::::: apply
# the ----> DET ::::: the
# serum ----> NOUN ::::: serum
# . ----> PUNCT ::::: .
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# 's ----> PART ::::: 's
# corpse ----> NOUN ::::: corpse
# starts ----> VERB ::::: start
# to ----> PART ::::: to
# glow ----> VERB ::::: glow
# and ----> CCONJ ::::: and
# overflow ----> NOUN ::::: overflow
# with ----> ADP ::::: with
# the ----> DET ::::: the
# fizzing ----> VERB ::::: fizz
# serum ----> NOUN ::::: serum
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Something ----> PRON ::::: something
# 's ----> AUX ::::: be
# happening ----> VERB ::::: happen
# ! ----> PUNCT ::::: !
# Come ----> VERB ::::: come
# on ----> ADP ::::: on
# , ----> PUNCT ::::: ,
# come ----> VERB ::::: come
# on ----> ADP ::::: on
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Work ----> NOUN ::::: work
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# A ----> DET ::::: a
# zombie ----> NOUN ::::: zombie
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# arises ----> VERB ::::: arise
# and ----> CCONJ ::::: and
# moans ----> VERB ::::: moan
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Algebraic ----> PROPN ::::: Algebraic
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Wait ----> VERB ::::: wait
# , ----> PUNCT ::::: ,
# something ----> PRON ::::: something
# 's ----> AUX ::::: be
# wrong ----> ADJ ::::: wrong
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Zombie ----> PROPN ::::: Zombie
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# : ----> PUNCT ::::: :
# Sugar ----> PROPN ::::: Sugar
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Squirts ----> NOUN ::::: squirt
# serum ----> NOUN ::::: serum
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# his ----> PRON ::::: his
# eyes ----> NOUN ::::: eye
# and ----> CCONJ ::::: and
# mouth ----> NOUN ::::: mouth
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Ew ----> PROPN ::::: Ew
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Zombie ----> PROPN ::::: Zombie
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# leaps ----> VERB ::::: leap
# into ----> ADP ::::: into
# a ----> DET ::::: a
# giant ----> ADJ ::::: giant
# test ----> NOUN ::::: test
# tube ----> NOUN ::::: tube
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# test ----> NOUN ::::: test
# tube ----> NOUN ::::: tube
# falls ----> VERB ::::: fall
# and ----> CCONJ ::::: and
# infects ----> VERB ::::: infect
# the ----> DET ::::: the
# whole ----> ADJ ::::: whole
# cemetery ----> NOUN ::::: cemetery
# . ----> PUNCT ::::: .
# Zombie ----> PROPN ::::: Zombie
# Candy ----> PROPN ::::: Candy
# People ----> NOUN ::::: People
# begin ----> VERB ::::: begin
# to ----> PART ::::: to
# arise ----> VERB ::::: arise
# from ----> ADP ::::: from
# their ----> PRON ::::: their
# graves ----> NOUN ::::: graf
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# look ----> VERB ::::: look
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# is ----> AUX ::::: be
# working ----> VERB ::::: work
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# this ----> PRON ::::: this
# is ----> AUX ::::: be
# wrong ----> ADJ ::::: wrong
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# coming ----> VERB ::::: come
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# life ----> NOUN ::::: life
# -- ----> PUNCT ::::: --
# they're ----> VERB ::::: they're
# still ----> ADV ::::: still
# dead ----> ADJ ::::: dead
# ! ----> PUNCT ::::: !
# The ----> DET ::::: the
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# -- ----> PUNCT ::::: --
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# incomplete ----> ADJ ::::: incomplete
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# she ----> PRON ::::: she
# rubs ----> VERB ::::: rub
# the ----> DET ::::: the
# head ----> NOUN ::::: head
# of ----> ADP ::::: of
# a ----> DET ::::: a
# candy ----> NOUN ::::: candy
# person ----> NOUN ::::: person
# that ----> PRON ::::: that
# looks ----> VERB ::::: look
# like ----> ADP ::::: like
# a ----> DET ::::: a
# love ----> NOUN ::::: love
# heart ----> NOUN ::::: heart
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Zombie ----> PROPN ::::: Zombie
# Love ----> PROPN ::::: Love
# Heart ----> PROPN ::::: Heart
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# lashing ----> VERB ::::: lash
# out ----> ADP ::::: out
# at ----> ADP ::::: at
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# ] ----> X ::::: ]
# Rah ----> PROPN ::::: Rah
# . ----> PUNCT ::::: .
# Must ----> AUX ::::: must
# eat ----> VERB ::::: eat
# sugar ----> NOUN ::::: sugar
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Pushes ----> VERB ::::: push
# him ----> PRON ::::: he
# back ----> ADV ::::: back
# down ----> ADV ::::: down
# ] ----> PUNCT ::::: ]
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# grounded ----> VERB ::::: ground
# , ----> PUNCT ::::: ,
# Mister ----> PROPN ::::: Mister
# . ----> PROPN ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# this ----> PRON ::::: this
# is ----> AUX ::::: be
# really ----> ADV ::::: really
# bad ----> ADJ ::::: bad
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# be ----> AUX ::::: be
# attracted ----> VERB ::::: attract
# to ----> ADP ::::: to
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# Kingdom ----> PROPN ::::: Kingdom
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Why ----> SCONJ ::::: why
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Because ----> SCONJ ::::: because
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# People ----> NOUN ::::: People
# are ----> AUX ::::: be
# made ----> VERB ::::: make
# of ----> ADP ::::: of
# sugar ----> NOUN ::::: sugar
# , ----> PUNCT ::::: ,
# ya ----> PROPN ::::: ya
# ding ----> PROPN ::::: ding
# dong ----> PROPN ::::: dong
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Zombie ----> PROPN ::::: Zombie
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# On ----> ADP ::::: on
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# ] ----> PUNCT ::::: ]
# Gimme ----> PROPN ::::: Gimme
# some ----> DET ::::: some
# sugar ----> NOUN ::::: sugar
# , ----> PUNCT ::::: ,
# baby ----> NOUN ::::: baby
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Chew ----> VERB ::::: chew
# on ----> ADP ::::: on
# this ----> PRON ::::: this
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Kicks ----> VERB ::::: kick
# him ----> PRON ::::: he
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Giggles ----> X ::::: giggles
# ] ----> X ::::: ]
# Good ----> ADJ ::::: good
# one ----> NOUN ::::: one
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# . ----> PUNCT ::::: .
# Quickly ----> ADV ::::: quickly
# , ----> PUNCT ::::: ,
# to ----> ADP ::::: to
# the ----> DET ::::: the
# kingdom ----> NOUN ::::: kingdom
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# They ----> PRON ::::: they
# run ----> VERB ::::: run
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# the ----> DET ::::: the
# cemetery ----> NOUN ::::: cemetery
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Kicks ----> VERB ::::: kick
# another ----> DET ::::: another
# zombie ----> NOUN ::::: zombie
# ] ----> PUNCT ::::: ]
# Get ----> VERB ::::: get
# a ----> DET ::::: a
# life ----> NOUN ::::: life
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# is ----> AUX ::::: be
# at ----> ADP ::::: at
# the ----> DET ::::: the
# top ----> NOUN ::::: top
# of ----> ADP ::::: of
# her ----> PRON ::::: her
# castle ----> NOUN ::::: castle
# , ----> PUNCT ::::: ,
# ringing ----> VERB ::::: ring
# a ----> DET ::::: a
# large ----> ADJ ::::: large
# bell ----> NOUN ::::: bell
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# All ----> DET ::::: all
# citizens ----> NOUN ::::: citizen
# of ----> ADP ::::: of
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# Kingdom ----> PROPN ::::: Kingdom
# ! ----> PUNCT ::::: !
# Report ----> NOUN ::::: report
# to ----> ADP ::::: to
# the ----> DET ::::: the
# palace ----> NOUN ::::: palace
# , ----> PUNCT ::::: ,
# immediately ----> ADV ::::: immediately
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Candy ----> NOUN ::::: candy
# People ----> NOUN ::::: People
# mumble ----> VERB ::::: mumble
# in ----> ADP ::::: in
# confusion ----> NOUN ::::: confusion
# and ----> CCONJ ::::: and
# walk ----> VERB ::::: walk
# to ----> ADP ::::: to
# the ----> DET ::::: the
# palace ----> NOUN ::::: palace
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoa ----> INTJ ::::: whoa
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Jake ----> PROPN ::::: Jake
# and ----> CCONJ ::::: and
# Lady ----> PROPN ::::: Lady
# go ----> VERB ::::: go
# off ----> ADP ::::: off
# to ----> ADP ::::: to
# the ----> DET ::::: the
# palace ----> NOUN ::::: palace
# . ----> PUNCT ::::: .
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# notices ----> VERB ::::: notice
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# slowly ----> ADV ::::: slowly
# leaving ----> VERB ::::: leave
# the ----> DET ::::: the
# cemetery ----> NOUN ::::: cemetery
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# worried ----> VERB ::::: worry
# ] ----> PUNCT ::::: ]
# Hurry ----> VERB ::::: hurry
# , ----> PUNCT ::::: ,
# sweet ----> ADJ ::::: sweet
# citizens ----> NOUN ::::: citizen
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Alright ----> INTJ ::::: alright
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# heard ----> VERB ::::: hear
# the ----> DET ::::: the
# princess ----> NOUN ::::: princess
# , ----> PUNCT ::::: ,
# everyone ----> PRON ::::: everyone
# in ----> ADP ::::: in
# ! ----> PUNCT ::::: !
# Alright ----> INTJ ::::: alright
# , ----> PUNCT ::::: ,
# no ----> DET ::::: no
# pushing ----> NOUN ::::: pushing
# , ----> PUNCT ::::: ,
# come ----> VERB ::::: come
# on ----> ADP ::::: on
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Dude ----> NOUN ::::: dude
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# up ----> ADP ::::: up
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# princess ----> NOUN ::::: princess
# will ----> AUX ::::: will
# explain ----> VERB ::::: explain
# everything ----> PRON ::::: everything
# . ----> PUNCT ::::: .
# Tree ----> PROPN ::::: Tree
# Trunks ----> NOUN ::::: trunk
# , ----> PUNCT ::::: ,
# get ----> VERB ::::: get
# those ----> DET ::::: those
# hot ----> ADJ ::::: hot
# buns ----> NOUN ::::: bun
# in ----> ADP ::::: in
# here ----> ADV ::::: here
# , ----> PUNCT ::::: ,
# girl ----> NOUN ::::: girl
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Tree ----> PROPN ::::: Tree
# Trunks ----> NOUN ::::: trunk
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Carrying ----> VERB ::::: carry
# hot ----> ADJ ::::: hot
# cross ----> NOUN ::::: cross
# buns ----> NOUN ::::: bun
# ] ----> X ::::: ]
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# hope ----> VERB ::::: hope
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# bad ----> ADJ ::::: bad
# news ----> NOUN ::::: news
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# and ----> CCONJ ::::: and
# Finn ----> PROPN ::::: Finn
# close ----> VERB ::::: close
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Did ----> AUX ::::: do
# we ----> PRON ::::: we
# get ----> VERB ::::: get
# everyone ----> PRON ::::: everyone
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Manfried ----> PROPN ::::: Manfried
# : ----> PUNCT ::::: :
# All ----> PRON ::::: all
# present ----> ADJ ::::: present
# and ----> CCONJ ::::: and
# accounted ----> VERB ::::: account
# for ----> ADP ::::: for
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Thanks ----> NOUN ::::: thank
# , ----> PUNCT ::::: ,
# Manfried ----> PROPN ::::: Manfried
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Manfried ----> PROPN ::::: Manfried
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# welcome ----> ADJ ::::: welcome
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Citizens ----> NOUN ::::: citizen
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# are ----> AUX ::::: be
# assembled ----> VERB ::::: assemble
# here ----> ADV ::::: here
# in ----> ADP ::::: in
# the ----> DET ::::: the
# candy ----> NOUN ::::: candy
# foyer ----> NOUN ::::: foyer
# for ----> ADP ::::: for
# a ----> DET ::::: a
# momentous ----> ADJ ::::: momentous
# announcement ----> NOUN ::::: announcement
# . ----> PUNCT ::::: .
# Tonight ----> NOUN ::::: tonight
# we ----> PRON ::::: we
# are ----> AUX ::::: be
# all ----> PRON ::::: all
# going ----> VERB ::::: go
# to ----> PART ::::: to
# have ----> VERB ::::: have
# ... ----> PUNCT ::::: ...
# a ----> DET ::::: a
# slumber ----> NOUN ::::: slumber
# party ----> NOUN ::::: party
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Crowd ----> NOUN ::::: crowd
# cheers ----> VERB ::::: cheer
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Wait ----> VERB ::::: wait
# ! ----> PUNCT ::::: !
# What ----> PRON ::::: what
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zom-- ----> NUM ::::: zom--
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# covers ----> VERB ::::: cover
# his ----> PRON ::::: his
# mouth ----> NOUN ::::: mouth
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Go ----> VERB ::::: go
# ahead ----> ADV ::::: ahead
# and ----> CCONJ ::::: and
# start ----> VERB ::::: start
# partying ----> VERB ::::: party
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> PUNCT ::::: [
# Voice ----> PROPN ::::: Voice
# muffled ----> VERB ::::: muffle
# ] ----> PUNCT ::::: ]
# But ----> CCONJ ::::: but
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# Undead-- ----> PROPN ::::: Undead--
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Carries ----> VERB ::::: carry
# Finn ----> PROPN ::::: Finn
# to ----> ADP ::::: to
# the ----> DET ::::: the
# lab ----> NOUN ::::: lab
# ] ----> X ::::: ]
# We ----> PRON ::::: we
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# right ----> ADV ::::: right
# back ----> ADV ::::: back
# , ----> PUNCT ::::: ,
# everyone ----> PRON ::::: everyone
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whooo ----> PROPN ::::: Whooo
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# In ----> ADP ::::: in
# the ----> DET ::::: the
# lab ----> NOUN ::::: lab
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Finn ----> PROPN ::::: Finn
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# People ----> NOUN ::::: People
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# know ----> VERB ::::: know
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Wha ----> PROPN ::::: Wha
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# If ----> SCONJ ::::: if
# they ----> PRON ::::: they
# knew ----> VERB ::::: know
# , ----> PUNCT ::::: ,
# they ----> PRON ::::: they
# would ----> AUX ::::: would
# flip ----> VERB ::::: flip
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# mean ----> VERB ::::: mean
# " ----> PUNCT ::::: "
# flip ----> VERB ::::: flip
# out ----> ADP ::::: out
# " ----> PUNCT ::::: "
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# mean ----> VERB ::::: mean
# they ----> PRON ::::: they
# would ----> AUX ::::: would
# flip ----> VERB ::::: flip
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Scene ----> PROPN ::::: Scene
# changes ----> VERB ::::: change
# to ----> ADP ::::: to
# the ----> DET ::::: the
# cemetery ----> NOUN ::::: cemetery
# ; ----> PUNCT ::::: ;
# Starchy ----> PROPN ::::: Starchy
# arrives ----> VERB ::::: arrive
# with ----> ADP ::::: with
# a ----> DET ::::: a
# shovel ----> NOUN ::::: shovel
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Starchy ----> PROPN ::::: Starchy
# : ----> PUNCT ::::: :
# Princess ----> PROPN ::::: Princess
# ? ----> PUNCT ::::: ?
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# Starchy ----> PROPN ::::: Starchy
# the ----> DET ::::: the
# gravedigger ----> NOUN ::::: gravedigger
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# brought ----> VERB ::::: bring
# you ----> PRON ::::: you
# a ----> DET ::::: a
# larger ----> ADJ ::::: large
# corpse ----> NOUN ::::: corpse
# shovel ----> NOUN ::::: shovel
# . ----> PUNCT ::::: .
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# ? ----> PUNCT ::::: ?
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# just ----> ADV ::::: just
# wait ----> VERB ::::: wait
# for ----> ADP ::::: for
# you ----> PRON ::::: you
# here ----> ADV ::::: here
# , ----> PUNCT ::::: ,
# then ----> ADV ::::: then
# . ----> PUNCT ::::: .
# By ----> ADP ::::: by
# the ----> DET ::::: the
# mausoleum ----> NOUN ::::: mausoleum
# . ----> PUNCT ::::: .
# With ----> SCONJ ::::: with
# my ----> PRON ::::: my
# back ----> NOUN ::::: back
# turned ----> VERB ::::: turn
# . ----> PUNCT ::::: .
# And ----> CCONJ ::::: and
# my ----> PRON ::::: my
# defenses ----> NOUN ::::: defense
# lowered ----> VERB ::::: lower
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# As ----> SCONJ ::::: as
# Starchy ----> PROPN ::::: Starchy
# does ----> VERB ::::: do
# so ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# Candy ----> PROPN ::::: Candy
# Zombie ----> PROPN ::::: Zombie
# comes ----> VERB ::::: come
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# the ----> DET ::::: the
# mausoleum ----> NOUN ::::: mausoleum
# and ----> CCONJ ::::: and
# goes ----> VERB ::::: go
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# Starchy ----> PROPN ::::: Starchy
# , ----> PUNCT ::::: ,
# Starchy ----> PROPN ::::: Starchy
# starts ----> VERB ::::: start
# to ----> PART ::::: to
# scream ----> VERB ::::: scream
# and ----> CCONJ ::::: and
# gasp ----> VERB ::::: gasp
# and ----> CCONJ ::::: and
# then ----> ADV ::::: then
# ... ----> PUNCT ::::: ...
# KABOOM ----> PROPN ::::: KABOOM
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# He ----> PRON ::::: he
# explodes ----> VERB ::::: explode
# in ----> ADP ::::: in
# a ----> DET ::::: a
# flash ----> NOUN ::::: flash
# of ----> ADP ::::: of
# light ----> NOUN ::::: light
# . ----> PUNCT ::::: .
# Back ----> ADV ::::: back
# at ----> ADP ::::: at
# the ----> DET ::::: the
# castle ----> NOUN ::::: castle
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Candy ----> NOUN ::::: candy
# People ----> NOUN ::::: People
# explode ----> VERB ::::: explode
# when ----> SCONJ ::::: when
# they ----> PRON ::::: they
# get ----> VERB ::::: get
# scared ----> ADJ ::::: scared
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Not ----> PART ::::: not
# telling ----> VERB ::::: tell
# the ----> DET ::::: the
# Candy ----> PROPN ::::: Candy
# People ----> PROPN ::::: People
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# is ----> AUX ::::: be
# so ----> ADV ::::: so
# important ----> ADJ ::::: important
# that ----> SCONJ ::::: that
# you ----> PRON ::::: you
# need ----> VERB ::::: need
# to ----> PART ::::: to
# promise ----> VERB ::::: promise
# , ----> PUNCT ::::: ,
# Royal ----> PROPN ::::: Royal
# Promise ----> PROPN ::::: Promise
# , ----> PUNCT ::::: ,
# not ----> PART ::::: not
# to ----> PART ::::: to
# let ----> VERB ::::: let
# anyone ----> PRON ::::: anyone
# find ----> VERB ::::: find
# out ----> ADP ::::: out
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# , ----> PUNCT ::::: ,
# ever ----> ADV ::::: ever
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Okay ----> INTJ ::::: okay
# , ----> PUNCT ::::: ,
# sure ----> ADJ ::::: sure
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# No ----> PROPN ::::: No
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# have ----> VERB ::::: have
# to ----> ADP ::::: to
# Royal ----> PROPN ::::: Royal
# Promise ----> PROPN ::::: Promise
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# [ ----> X ::::: [
# kneels ----> VERB ::::: kneel
# ] ----> X ::::: ]
# I ----> PRON ::::: I
# Royal ----> PROPN ::::: Royal
# Promise ----> PROPN ::::: Promise
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Now ----> ADV ::::: now
# I ----> PRON ::::: I
# must ----> AUX ::::: must
# cloister ----> VERB ::::: cloister
# myself ----> PRON ::::: myself
# in ----> ADP ::::: in
# the ----> DET ::::: the
# lab ----> NOUN ::::: lab
# and ----> CCONJ ::::: and
# finish ----> VERB ::::: finish
# the ----> DET ::::: the
# equation ----> NOUN ::::: equation
# to ----> ADP ::::: to
# my ----> PRON ::::: my
# decorpsinator ----> NOUN ::::: decorpsinator
# serum ----> NOUN ::::: serum
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# keep ----> VERB ::::: keep
# the ----> DET ::::: the
# candy ----> NOUN ::::: candy
# folk ----> NOUN ::::: folk
# distracted ----> VERB ::::: distract
# and ----> CCONJ ::::: and
# ignorant ----> ADJ ::::: ignorant
# . ----> PUNCT ::::: .
# Can ----> AUX ::::: can
# you ----> PRON ::::: you
# do ----> VERB ::::: do
# that ----> PRON ::::: that
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# your ----> PRON ::::: your
# highness ----> NOUN ::::: highness
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# Good ----> PROPN ::::: Good
# . ----> PUNCT ::::: .
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# tell ----> VERB ::::: tell
# anyone ----> PRON ::::: anyone
# about ----> ADP ::::: about
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# . ----> PUNCT ::::: .
# Never ----> ADV ::::: never
# ever ----> ADV ::::: ever
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# She ----> PRON ::::: she
# leaves ----> VERB ::::: leave
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# wait ----> VERB ::::: wait
# . ----> PUNCT ::::: .
# Can ----> AUX ::::: can
# I ----> PRON ::::: I
# at ----> ADV ::::: at
# least ----> ADJ ::::: least
# tell ----> VERB ::::: tell
# [ ----> X ::::: [
# Jake ----> PROPN ::::: Jake
# enters ----> VERB ::::: enter
# ] ----> PUNCT ::::: ]
# Jake ----> PROPN ::::: Jake
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Tell ----> VERB ::::: tell
# me ----> PRON ::::: I
# about ----> ADP ::::: about
# what ----> PRON ::::: what
# , ----> PUNCT ::::: ,
# dude ----> NOUN ::::: dude
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# know ----> VERB ::::: know
# , ----> PUNCT ::::: ,
# about ----> ADP ::::: about
# the ----> DET ::::: the
# outbreak ----> NOUN ::::: outbreak
# of ----> ADP ::::: of
# zom-- ----> NUM ::::: zom--
# [ ----> X ::::: [
# Covers ----> VERB ::::: cover
# his ----> PRON ::::: his
# mouth ----> NOUN ::::: mouth
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Chuckles ----> X ::::: chuckles
# ] ----> PUNCT ::::: ]
# Alright ----> INTJ ::::: alright
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Uhh ----> INTJ ::::: uhh
# , ----> PUNCT ::::: ,
# nothing ----> PRON ::::: nothing
# at ----> ADV ::::: at
# all ----> ADV ::::: all
# , ----> PUNCT ::::: ,
# buddy ----> NOUN ::::: buddy
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Laughs ----> VERB ::::: laugh
# awkwardly ----> ADV ::::: awkwardly
# and ----> CCONJ ::::: and
# skips ----> VERB ::::: skip
# into ----> ADP ::::: into
# the ----> DET ::::: the
# foyer ----> NOUN ::::: foyer
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# dude ----> NOUN ::::: dude
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# think ----> VERB ::::: think
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# Bubblegum ----> NOUN ::::: bubblegum
# are ----> AUX ::::: be
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# something ----> PRON ::::: something
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# nervously ----> ADV ::::: nervously
# ] ----> X ::::: ]
# Ahha ----> INTJ ::::: ahha
# ah ----> INTJ ::::: ah
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# no ----> DET ::::: no
# way ----> NOUN ::::: way
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoa ----> INTJ ::::: whoa
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# guys ----> NOUN ::::: guy
# are ----> AUX ::::: be
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# something ----> PRON ::::: something
# . ----> PUNCT ::::: .
# Is ----> AUX ::::: be
# it ----> PRON ::::: it
# some ----> DET ::::: some
# sort ----> NOUN ::::: sort
# of ----> ADP ::::: of
# prank ----> NOUN ::::: prank
# ? ----> PUNCT ::::: ?
# Can ----> AUX ::::: can
# I ----> PRON ::::: I
# get ----> VERB ::::: get
# in ----> ADP ::::: in
# on ----> ADP ::::: on
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# To ----> ADP ::::: to
# party ----> NOUN ::::: party
# - ----> PUNCT ::::: -
# goers ----> NOUN ::::: goer
# ] ----> PUNCT ::::: ]
# Who ----> PRON ::::: who
# wants ----> VERB ::::: want
# to ----> PART ::::: to
# play ----> VERB ::::: play
# " ----> PUNCT ::::: "
# Truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# Dare ----> PROPN ::::: Dare
# " ----> PUNCT ::::: "
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Hmm ----> PROPN ::::: Hmm
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Ok ----> ADJ ::::: ok
# , ----> PUNCT ::::: ,
# Chocoberry ----> PROPN ::::: Chocoberry
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# may ----> AUX ::::: may
# ask ----> VERB ::::: ask
# someone ----> PRON ::::: someone
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# a ----> DET ::::: a
# deep ----> ADJ ::::: deep
# truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# a ----> DET ::::: a
# saucy ----> ADJ ::::: saucy
# dare ----> NOUN ::::: dare
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Chocoberry ----> PROPN ::::: Chocoberry
# : ----> PUNCT ::::: :
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# , ----> PUNCT ::::: ,
# truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# dare ----> VERB ::::: dare
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# : ----> PUNCT ::::: :
# Dare ----> PROPN ::::: Dare
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Chocoberry ----> PROPN ::::: Chocoberry
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# dare ----> VERB ::::: dare
# you ----> PRON ::::: you
# to ----> PART ::::: to
# take ----> VERB ::::: take
# off ----> ADP ::::: off
# your ----> PRON ::::: your
# wrapper ----> NOUN ::::: wrapper
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Everyone ----> PRON ::::: everyone
# goes ----> VERB ::::: go
# " ----> PUNCT ::::: "
# Oooh ----> INTJ ::::: oooh
# " ----> PUNCT ::::: "
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Shoulders ----> PROPN ::::: Shoulders
# Finn ----> PROPN ::::: Finn
# ] ----> PUNCT ::::: ]
# Hey ----> INTJ ::::: hey
# seriously ----> ADV ::::: seriously
# , ----> PUNCT ::::: ,
# man ----> INTJ ::::: man
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# your ----> PRON ::::: your
# bro ----> NOUN ::::: bro
# . ----> PUNCT ::::: .
# Bros ----> PROPN ::::: Bros
# are ----> AUX ::::: be
# supposed ----> VERB ::::: suppose
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# bros ----> PROPN ::::: bros
# everything ----> PRON ::::: everything
# all ----> DET ::::: all
# the ----> DET ::::: the
# time ----> NOUN ::::: time
# . ----> PUNCT ::::: .
# What ----> PRON ::::: what
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# Bubblegum ----> PROPN ::::: Bubblegum
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# ? ----> PUNCT ::::: ?
# Is ----> AUX ::::: be
# everything ----> PRON ::::: everything
# alright ----> ADJ ::::: alright
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yep ----> INTJ ::::: yep
# ! ----> PUNCT ::::: !
# Fine ----> INTJ ::::: fine
# ! ----> PUNCT ::::: !
# Everything ----> PRON ::::: everything
# is ----> AUX ::::: be
# great ----> ADJ ::::: great
# ! ----> PUNCT ::::: !
# Heh ----> INTJ ::::: heh
# , ----> PUNCT ::::: ,
# heh ----> INTJ ::::: heh
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Crinkling ----> NOUN ::::: crinkling
# sound ----> NOUN ::::: sound
# ] ----> PUNCT ::::: ]
# Except ----> SCONJ ::::: except
# for ----> ADP ::::: for
# that ----> PRON ::::: that
# . ----> PUNCT ::::: .
# Whoa ----> INTJ ::::: whoa
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# has ----> AUX ::::: have
# shed ----> VERB ::::: shed
# his ----> PRON ::::: his
# wrapper ----> NOUN ::::: wrapper
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Peppermint ----> PROPN ::::: Peppermint
# Butler ----> PROPN ::::: Butler
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# did ----> AUX ::::: do
# n't ----> PART ::::: not
# know ----> VERB ::::: know
# he ----> PRON ::::: he
# was ----> AUX ::::: be
# chocolate ----> NOUN ::::: chocolate
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# : ----> PUNCT ::::: :
# Jake ----> PROPN ::::: Jake
# , ----> PUNCT ::::: ,
# truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# dare ----> VERB ::::: dare
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Truth ----> PROPN ::::: Truth
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Mr. ----> PROPN ::::: Mr.
# Cupcake ----> PROPN ::::: Cupcake
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# prefer ----> VERB ::::: prefer
# chocolate ----> NOUN ::::: chocolate
# or ----> CCONJ ::::: or
# fudge ----> NOUN ::::: fudge
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# eat ----> VERB ::::: eat
# chocolate ----> NOUN ::::: chocolate
# or ----> CCONJ ::::: or
# fudge ----> NOUN ::::: fudge
# 'cause ----> SCONJ ::::: 'cause
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# a ----> DET ::::: a
# dog ----> NOUN ::::: dog
# and ----> CCONJ ::::: and
# they ----> PRON ::::: they
# 'd ----> AUX ::::: would
# probably ----> ADV ::::: probably
# kill ----> VERB ::::: kill
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# hmmmmm ----> INTJ ::::: hmmmmm
# probably ----> ADV ::::: probably
# ... ----> PUNCT ::::: ...
# neither ----> PRON ::::: neither
# . ----> PUNCT ::::: .
# Finn ----> PROPN ::::: Finn
# ! ----> PUNCT ::::: !
# Truth ----> NOUN ::::: truth
# or ----> CCONJ ::::: or
# dare ----> VERB ::::: dare
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Dare ----> PROPN ::::: Dare
# ! ----> PUNCT ::::: !
# Haha ----> INTJ ::::: haha
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# dare ----> VERB ::::: dare
# you ----> PRON ::::: you
# ... ----> PUNCT ::::: ...
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# me ----> PRON ::::: I
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# about ----> ADP ::::: about
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# in ----> ADP ::::: in
# your ----> PRON ::::: your
# mind ----> NOUN ::::: mind
# . ----> PUNCT ::::: .
# What ----> PRON ::::: what
# were ----> AUX ::::: be
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# Bubblegum ----> NOUN ::::: bubblegum
# talking ----> VERB ::::: talk
# about ----> ADP ::::: about
# when ----> SCONJ ::::: when
# you ----> PRON ::::: you
# were ----> AUX ::::: be
# alone ----> ADJ ::::: alone
# together ----> ADV ::::: together
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Everybody ----> PRON ::::: everybody
# goes ----> VERB ::::: go
# " ----> PUNCT ::::: "
# Oooh ----> INTJ ::::: oooh
# " ----> PUNCT ::::: "
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Nervously ----> ADV ::::: nervously
# ] ----> X ::::: ]
# Umm ----> INTJ ::::: umm
# , ----> PUNCT ::::: ,
# ahh ----> INTJ ::::: ahh
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# is ----> AUX ::::: be
# , ----> PUNCT ::::: ,
# ahhh ----> INTJ ::::: ahhh
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# visualizes ----> VERB ::::: visualize
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# 's ----> PART ::::: 's
# face ----> NOUN ::::: face
# on ----> ADP ::::: on
# Jake ----> PROPN ::::: Jake
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Hallucination ----> PROPN ::::: Hallucination
# of ----> ADP ::::: of
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# promised ----> VERB ::::: promise
# you ----> PRON ::::: you
# would ----> AUX ::::: would
# n't ----> PART ::::: not
# freakin ----> VERB ::::: freakin
# ' ----> PUNCT ::::: '
# tell ----> VERB ::::: tell
# anyone ----> PRON ::::: anyone
# ! ----> PUNCT ::::: !
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# so ----> ADV ::::: so
# cute ----> ADJ ::::: cute
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Ahhh ----> PROPN ::::: Ahhh
# ... ----> PUNCT ::::: ...
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# is ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
# that ----> SCONJ ::::: that
# I ----> PRON ::::: I
# 'd ----> AUX ::::: would
# rather ----> ADV ::::: rather
# play ----> VERB ::::: play
# Dodge ----> PROPN ::::: Dodge
# Socks ----> PROPN ::::: Socks
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# throws ----> VERB ::::: throw
# a ----> DET ::::: a
# sock ----> NOUN ::::: sock
# at ----> ADP ::::: at
# Jake ----> PROPN ::::: Jake
# , ----> PUNCT ::::: ,
# Princess ----> PROPN ::::: Princess
# Bubblegum ----> PROPN ::::: Bubblegum
# 's ----> PART ::::: 's
# face ----> NOUN ::::: face
# goes ----> VERB ::::: go
# away ----> ADV ::::: away
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# not ----> PART ::::: not
# playing ----> VERB ::::: play
# dodge ----> NOUN ::::: dodge
# socks ----> NOUN ::::: sock
# ' ----> VERB ::::: '
# til ----> SCONJ ::::: til
# you ----> PRON ::::: you
# stop ----> VERB ::::: stop
# dodging ----> VERB ::::: dodge
# my ----> PRON ::::: my
# questions ----> NOUN ::::: question
# . ----> PUNCT ::::: .
# Hey ----> INTJ ::::: hey
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# Sniffs ----> PROPN ::::: Sniffs
# socks ----> VERB ::::: sock
# ] ----> X ::::: ]
# Old ----> ADJ ::::: old
# Mr. ----> PROPN ::::: Mr.
# Cream ----> PROPN ::::: Cream
# Puff ----> PROPN ::::: Puff
# ? ----> PUNCT ::::: ?
# Is ----> AUX ::::: be
# n't ----> PART ::::: not
# he ----> PRON ::::: he
# dead ----> ADJ ::::: dead
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# give ----> VERB ::::: give
# me ----> PRON ::::: I
# my ----> PRON ::::: my
# sock ----> NOUN ::::: sock
# back ----> ADP ::::: back
# ! ----> PUNCT ::::: !
# Dodge ----> PROPN ::::: Dodge
# Socks ----> PROPN ::::: Socks
# was ----> AUX ::::: be
# a ----> DET ::::: a
# bad ----> ADJ ::::: bad
# idea ----> NOUN ::::: idea
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoa ----> INTJ ::::: whoa
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# angrily ----> ADV ::::: angrily
# ] ----> PUNCT ::::: ]
# Look ----> VERB ::::: look
# dude ----> NOUN ::::: dude
# , ----> PUNCT ::::: ,
# just ----> ADV ::::: just
# tell ----> VERB ::::: tell
# me ----> PRON ::::: I
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# up ----> ADV ::::: up
# , ----> PUNCT ::::: ,
# 'cause ----> SCONJ ::::: 'cause
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# crazier ----> ADJ ::::: crazy
# than ----> ADP ::::: than
# a ----> DET ::::: a
# cannonball ----> NOUN ::::: cannonball
# tonight ----> NOUN ::::: tonight
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# looks ----> VERB ::::: look
# out ----> ADP ::::: out
# a ----> DET ::::: a
# window ----> NOUN ::::: window
# behind ----> ADP ::::: behind
# Jake ----> PROPN ::::: Jake
# and ----> CCONJ ::::: and
# sees ----> VERB ::::: see
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# coming ----> VERB ::::: come
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Thinking ----> NOUN ::::: thinking
# ] ----> X ::::: ]
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# goodness ----> NOUN ::::: goodness
# ! ----> PUNCT ::::: !
# Princess ----> PROPN ::::: Princess
# has ----> AUX ::::: have
# n't ----> PART ::::: not
# finished ----> VERB ::::: finish
# the ----> DET ::::: the
# equation ----> NOUN ::::: equation
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# zombies ----> NOUN ::::: zombie
# are ----> AUX ::::: be
# here ----> ADV ::::: here
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# uh ----> INTJ ::::: uh
# , ----> PUNCT ::::: ,
# she ----> PRON ::::: she
# just ----> ADV ::::: just
# want ----> VERB ::::: want
# this ----> DET ::::: this
# slumber ----> NOUN ::::: slumber
# party ----> NOUN ::::: party
# to ----> PART ::::: to
# be ----> AUX ::::: be
# super ----> ADJ ::::: super
# fun ----> NOUN ::::: fun
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# if ----> SCONJ ::::: if
# I ----> PRON ::::: I
# did ----> AUX ::::: do
# have ----> VERB ::::: have
# something ----> PRON ::::: something
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# then ----> ADV ::::: then
# I ----> PRON ::::: I
# would ----> AUX ::::: would
# ...
# Outrageous ----> PROPN ::::: Outrageous
# , ----> PUNCT ::::: ,
# Captain ----> PROPN ::::: Captain
# Majesty ----> PROPN ::::: Majesty
# , ----> PUNCT ::::: ,
# The ----> DET ::::: the
# Flying ----> PROPN ::::: Flying
# Lettuce ----> PROPN ::::: Lettuce
# Brothers ----> PROPN ::::: Brothers
# , ----> PUNCT ::::: ,
# Pete ----> PROPN ::::: Pete
# the ----> DET ::::: the
# Punk ----> PROPN ::::: Punk
# " ----> PUNCT ::::: "
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# gasp ----> X ::::: gasp
# ] ----> X ::::: ]
# Tiiffaanyy ----> NOUN ::::: tiiffaanyy
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# In ----> ADP ::::: in
# an ----> DET ::::: an
# evil ----> ADJ ::::: evil
# tone ----> NOUN ::::: tone
# ] ----> PUNCT ::::: ]
# PERFECT ----> PROPN ::::: PERFECT
# ! ----> PUNCT ::::: !
# Muhuhaha ----> PROPN ::::: Muhuhaha
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Calls ----> VERB ::::: call
# Tiffany ----> PROPN ::::: Tiffany
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Cut ----> NOUN ::::: cut
# to ----> ADP ::::: to
# Lady ----> PROPN ::::: Lady
# and ----> CCONJ ::::: and
# Finn ----> PROPN ::::: Finn
# on ----> ADP ::::: on
# the ----> DET ::::: the
# roof ----> NOUN ::::: roof
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Lady ----> PROPN ::::: Lady
# and ----> CCONJ ::::: and
# Finn ----> PROPN ::::: Finn
# laughing ----> VERB ::::: laugh
# ] ----> PUNCT ::::: ]
# Man ----> INTJ ::::: man
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# wish ----> VERB ::::: wish
# Jake ----> PROPN ::::: Jake
# was ----> AUX ::::: be
# here ----> ADV ::::: here
# having ----> VERB ::::: have
# fun ----> NOUN ::::: fun
# with ----> ADP ::::: with
# us ----> PRON ::::: we
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Stops ----> NOUN ::::: stop
# and ----> CCONJ ::::: and
# hears ----> VERB ::::: hear
# viola ----> PROPN ::::: viola
# music ----> NOUN ::::: music
# ] ----> PUNCT ::::: ]
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# where ----> SCONJ ::::: where
# ’s ----> VERB ::::: ’
# that ----> DET ::::: that
# music ----> NOUN ::::: music
# coming ----> VERB ::::: come
# from ----> ADP ::::: from
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Him ----> PRON ::::: he
# and ----> CCONJ ::::: and
# Tiffany ----> PROPN ::::: Tiffany
# are ----> AUX ::::: be
# sitting ----> VERB ::::: sit
# on ----> ADP ::::: on
# stumps ----> NOUN ::::: stump
# playing ----> VERB ::::: play
# viola ----> PROPN ::::: viola
# ] ----> PUNCT ::::: ]
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# louder ----> ADV ::::: louder
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Sees ----> VERB ::::: see
# Jake ----> PROPN ::::: Jake
# and ----> CCONJ ::::: and
# Tiffany ----> PROPN ::::: Tiffany
# ] ----> PUNCT ::::: ]
# [ ----> X ::::: [
# gasps ----> X ::::: gasps
# ] ----> PUNCT ::::: ]
# Jake ----> PROPN ::::: Jake
# what ----> PRON ::::: what
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# doing ----> VERB ::::: do
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# hey ----> INTJ ::::: hey
# guys ----> NOUN ::::: guy
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# just ----> ADV ::::: just
# sharing ----> VERB ::::: share
# a ----> DET ::::: a
# tender ----> ADJ ::::: tender
# moment ----> NOUN ::::: moment
# with ----> ADP ::::: with
# my ----> PRON ::::: my
# beautiful ----> ADJ ::::: beautiful
# friend ----> NOUN ::::: friend
# Tiffany ----> PROPN ::::: Tiffany
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Stop ----> VERB ::::: stop
# ! ----> PUNCT ::::: !
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# making ----> VERB ::::: make
# Lady ----> PROPN ::::: Lady
# jealous ----> ADJ ::::: jealous
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# I ----> PRON ::::: I
# ’m ----> AUX ::::: ’m
# trying ----> VERB ::::: try
# to ----> PART ::::: to
# make ----> VERB ::::: make
# you ----> PRON ::::: you
# both ----> PRON ::::: both
# jealous ----> ADJ ::::: jealous
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Lady ----> PROPN ::::: Lady
# looks ----> VERB ::::: look
# mad ----> ADJ ::::: mad
# ] ----> X ::::: ]
# Why ----> SCONJ ::::: why
# would ----> AUX ::::: would
# I ----> PRON ::::: I
# be ----> AUX ::::: be
# jealous ----> ADJ ::::: jealous
# of ----> ADP ::::: of
# Tiffany ----> PROPN ::::: Tiffany
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Becaaause ----> PROPN ::::: Becaaause
# , ----> PUNCT ::::: ,
# Tiffany ----> PROPN ::::: Tiffany
# 's ----> PART ::::: 's
# a ----> DET ::::: a
# boy ----> NOUN ::::: boy
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Tiffany ----> PROPN ::::: Tiffany
# spins ----> VERB ::::: spin
# around ----> ADV ::::: around
# to ----> PART ::::: to
# face ----> VERB ::::: face
# the ----> DET ::::: the
# camera ----> NOUN ::::: camera
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Tiffany ----> PROPN ::::: Tiffany
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Laughs ----> VERB ::::: laugh
# evilly ----> ADV ::::: evilly
# ] ----> PUNCT ::::: ]
# Jake ----> PROPN ::::: Jake
# 's ----> PART ::::: 's
# MY ----> PRON ::::: my
# best ----> ADJ ::::: good
# friend ----> NOUN ::::: friend
# now ----> ADV ::::: now
# ! ----> PUNCT ::::: !
# FOREVER ----> ADV ::::: forever
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Looks ----> VERB ::::: look
# extremely ----> ADV ::::: extremely
# startled ----> ADJ ::::: startled
# ] ----> PUNCT ::::: ]
# [ ----> X ::::: [
# gasps ----> X ::::: gasps
# ] ----> X ::::: ]
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# growls ----> VERB ::::: growl
# and ----> CCONJ ::::: and
# leaps ----> VERB ::::: leap
# towards ----> ADP ::::: towards
# Tiffany ----> PROPN ::::: Tiffany
# ] ----> PUNCT ::::: ]
# Yaaaaaaahhh ----> PROPN ::::: Yaaaaaaahhh
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Tackles ----> NOUN ::::: tackle
# Tiffany ----> PROPN ::::: Tiffany
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# view][They ----> PROPN ::::: view][They
# fight ----> VERB ::::: fight
# and ----> CCONJ ::::: and
# Tiffany ----> PROPN ::::: Tiffany
# pulls ----> VERB ::::: pull
# out ----> ADP ::::: out
# a ----> DET ::::: a
# knife ----> NOUN ::::: knife
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# Finn ----> PROPN ::::: Finn
# kicks ----> VERB ::::: kick
# it ----> PRON ::::: it
# away ----> ADV ::::: away
# ] ----> PUNCT ::::: ]
# Home ----> NOUN ::::: home
# wrecker ----> NOUN ::::: wrecker
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# They ----> PRON ::::: they
# continue ----> VERB ::::: continue
# fighting ----> VERB ::::: fight
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# : ----> PUNCT ::::: :
# Jake ----> PROPN ::::: Jake
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# with ----> ADP ::::: with
# you ----> PRON ::::: you
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# sighs ----> X ::::: sighs
# ] ----> PUNCT ::::: ]
# I ----> PRON ::::: I
# guess ----> VERB ::::: guess
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# just ----> ADV ::::: just
# jealous ----> ADJ ::::: jealous
# of ----> ADP ::::: of
# how ----> SCONJ ::::: how
# much ----> ADJ ::::: much
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# Finn ----> PROPN ::::: Finn
# like ----> ADP ::::: like
# each ----> DET ::::: each
# other ----> ADJ ::::: other
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# hanging ----> VERB ::::: hang
# out ----> ADP ::::: out
# with ----> ADP ::::: with
# Finn ----> PROPN ::::: Finn
# because ----> SCONJ ::::: because
# you ----> PRON ::::: you
# wanted ----> VERB ::::: want
# us ----> PRON ::::: we
# to ----> PART ::::: to
# get ----> VERB ::::: get
# to ----> PART ::::: to
# know ----> VERB ::::: know
# each ----> DET ::::: each
# other ----> ADJ ::::: other
# better ----> ADV ::::: well
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# know ----> VERB ::::: know
# . ----> PUNCT ::::: .
# Gaah ----> PROPN ::::: Gaah
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# punches ----> VERB ::::: punch
# Tiffany ----> PROPN ::::: Tiffany
# in ----> ADP ::::: in
# the ----> DET ::::: the
# face ----> NOUN ::::: face
# while ----> SCONJ ::::: while
# on ----> ADP ::::: on
# top ----> NOUN ::::: top
# of ----> ADP ::::: of
# him ----> PRON ::::: he
# ] ----> PUNCT ::::: ]
# Get ----> VERB ::::: get
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# my ----> PRON ::::: my
# life ----> NOUN ::::: life
# Tiffany ----> PROPN ::::: Tiffany
# ! ----> PUNCT ::::: !
# And ----> CCONJ ::::: and
# never ----> ADV ::::: never
# come ----> VERB ::::: come
# back ----> ADV ::::: back
# [ ----> X ::::: [
# Punches ----> VERB ::::: punch
# him ----> PRON ::::: he
# again ----> ADV ::::: again
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Tiffany ----> PROPN ::::: Tiffany
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Kicks ----> VERB ::::: kick
# Finn ----> PROPN ::::: Finn
# off ----> ADP ::::: off
# of ----> ADP ::::: of
# him ----> PRON ::::: he
# ] ----> PUNCT ::::: ]
# No ----> INTJ ::::: no
# ! ----> PUNCT ::::: !
# Jake ----> PROPN ::::: Jake
# will ----> AUX ::::: will
# be ----> AUX ::::: be
# mine ----> PRON ::::: mine
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# sorry ----> ADJ ::::: sorry
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# an ----> DET ::::: an
# idiot ----> ADJ ::::: idiot
# baby ----> NOUN ::::: baby
# . ----> PUNCT ::::: .
# Forgive ----> VERB ::::: forgive
# me ----> PRON ::::: I
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# sweet ----> ADJ ::::: sweet
# potato ----> NOUN ::::: potato
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# love ----> VERB ::::: love
# you ----> PRON ::::: you
# BECAUSE ----> SCONJ ::::: because
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# an ----> DET ::::: an
# idiot ----> NOUN ::::: idiot
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# make ----> VERB ::::: make
# me ----> PRON ::::: I
# feel ----> VERB ::::: feel
# like ----> ADP ::::: like
# a ----> DET ::::: a
# genius ----> NOUN ::::: genius
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Lady ----> PROPN ::::: Lady
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# laugh ----> PROPN ::::: laugh
# ] ----> X ::::: ]
# You ----> PRON ::::: you
# make ----> VERB ::::: make
# me ----> PRON ::::: I
# feel ----> VERB ::::: feel
# like ----> SCONJ ::::: like
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# huggin ----> VERB ::::: huggin
# ' ----> PUNCT ::::: '
# an ----> DET ::::: an
# old ----> ADJ ::::: old
# man ----> NOUN ::::: man
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# time ----> NOUN ::::: time
# to ----> PART ::::: to
# get ----> AUX ::::: get
# rid ----> VERB ::::: rid
# of ----> ADP ::::: of
# this ----> DET ::::: this
# piece ----> NOUN ::::: piece
# of ----> ADP ::::: of
# crud ----> NOUN ::::: crud
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# rips ----> VERB ::::: rip
# translator ----> NOUN ::::: translator
# off ----> ADP ::::: off
# and ----> CCONJ ::::: and
# throws ----> VERB ::::: throw
# it ----> PRON ::::: it
# into ----> ADP ::::: into
# the ----> DET ::::: the
# grass ----> NOUN ::::: grass
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Lady ----> PROPN ::::: Lady
# Rainicorn ----> PROPN ::::: Rainicorn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# giggles ----> X ::::: giggles
# ] ----> PUNCT ::::: ]
# 이게 ----> ADP ::::: 이게
# 더 ----> NOUN ::::: 더
# 좋아 ----> NOUN ::::: 좋아
# ? ----> PUNCT ::::: ?
# ( ----> PUNCT ::::: (
# " ----> PUNCT ::::: "
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# prefer ----> VERB ::::: prefer
# this ----> DET ::::: this
# one ----> NOUN ::::: one
# ? ----> PUNCT ::::: ?
# " ----> PUNCT ::::: "
# ) ----> PUNCT ::::: )
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# Waaay ----> ADV ::::: waaay
# better ----> ADV ::::: well
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# they ----> PRON ::::: they
# hug ----> VERB ::::: hug
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Beat ----> VERB ::::: beat
# it ----> PRON ::::: it
# Tiffany ----> PROPN ::::: Tiffany
# ! ----> PUNCT ::::: !
# Go ----> VERB ::::: go
# on ----> ADP ::::: on
# ! ----> PUNCT ::::: !
# Get ----> VERB ::::: get
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Tiffany ----> PROPN ::::: Tiffany
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 'll ----> AUX ::::: will
# never ----> ADV ::::: never
# defeat ----> VERB ::::: defeat
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# will ----> AUX ::::: will
# ! ----> PUNCT ::::: !
# Be ----> AUX ::::: be
# Jake ----> PROPN ::::: Jake
# 's ----> PART ::::: 's
# best ----> ADJ ::::: good
# friend ----> NOUN ::::: friend
# ! ----> PUNCT ::::: !
# Because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# ! ----> PUNCT ::::: !
# Tiffanyyyy ----> PROPN ::::: Tiffanyyyy
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# spits ----> VERB ::::: spit
# on ----> ADP ::::: on
# his ----> PRON ::::: his
# head ----> NOUN ::::: head
# and ----> CCONJ ::::: and
# he ----> PRON ::::: he
# runs ----> VERB ::::: run
# off ----> ADV ::::: off
# ] ----> PUNCT ::::: ]
# Ahhhhhh ----> PROPN ::::: Ahhhhhh
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Lady ----> PROPN ::::: Lady
# is ----> AUX ::::: be
# wrapped ----> VERB ::::: wrap
# partially ----> ADV ::::: partially
# around ----> ADP ::::: around
# Jake ----> PROPN ::::: Jake
# ] ----> PUNCT ::::: ]
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# sorry ----> ADJ ::::: sorry
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# an ----> DET ::::: an
# idiot ----> NOUN ::::: idiot
# . ----> PUNCT ::::: .
# Forgive ----> VERB ::::: forgive
# me ----> PRON ::::: I
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Shut ----> VERB ::::: shut
# up ----> ADP ::::: up
# man ----> NOUN ::::: man
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# wanna ----> VERB ::::: wanna
# hear ----> VERB ::::: hear
# that ----> DET ::::: that
# stuff ----> NOUN ::::: stuff
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# He ----> PRON ::::: he
# steps ----> VERB ::::: step
# into ----> ADP ::::: into
# the ----> DET ::::: the
# circle ----> NOUN ::::: circle
# made ----> VERB ::::: make
# by ----> ADP ::::: by
# Lady ----> PROPN ::::: Lady
# ] ----> PUNCT ::::: ]
# Lemme ----> PROPN ::::: Lemme
# get ----> VERB ::::: get
# in ----> ADV ::::: in
# there ----> ADV ::::: there
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Let ----> VERB ::::: let
# 's ----> PRON ::::: us
# never ----> ADV ::::: never
# be ----> AUX ::::: be
# stupid ----> ADJ ::::: stupid
# again ----> ADV ::::: again
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Wait ----> VERB ::::: wait
# ! ----> PUNCT ::::: !
# Let ----> AUX ::::: let
# 's ----> PRON ::::: us
# always ----> ADV ::::: always
# be ----> AUX ::::: be
# stupid ----> ADJ ::::: stupid
# ! ----> PUNCT ::::: !
# Forever ----> ADV ::::: forever
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Everyone ----> PRON ::::: everyone
# laughs ----> VERB ::::: laugh
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# episode ----> NOUN ::::: episode
# ends ----> VERB ::::: end
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]

# %%
# Remember, we can request an explanation from spaCy of its tags: 
spacy.explain("DET")
# Out:
# 'determiner'

# %% [markdown]
# ### Okay, let's select something interesting
#  ...and maybe only collect the lemmas.
#
# Let's do this with a **function** call. We can easily switch the kind of word we want to output this way.
# Here we are starting to associate words wtih volumes...we're going to refine that by making a dataframe next.

# %%
def wordCollector(words, unit):
    wordList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append((token.lemma_, unit))
    uniqueLems = set(wordList)
    return uniqueLems

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myWords = wordCollector(spacyRead, name)
            print(myWords)
# Out:
# {('momentous', 'ATE1'), ('right', 'ATE1'), ('first', 'ATE1'), ('incomplete', 'ATE1'), ('dead', 'ATE1'), ('explosive', 'ATE1'), ('ok', 'ATE1'), ('crazy', 'ATE1'), ('delicious', 'ATE1'), ('bad', 'ATE1'), ('wrong', 'ATE1'), ('least', 'ATE1'), ('present', 'ATE1'), ('correct', 'ATE1'), ('deep', 'ATE1'), ('smart', 'ATE1'), ('cute', 'ATE1'), ('simple', 'ATE1'), ('sure', 'ATE1'), ('former', 'ATE1'), ('giant', 'ATE1'), ('main', 'ATE1'), ('well', 'ATE1'), ('royal', 'ATE1'), ('full', 'ATE1'), ('old', 'ATE1'), ('hot', 'ATE1'), ('unaffected', 'ATE1'), ('good', 'ATE1'), ('scared', 'ATE1'), ('easy', 'ATE1'), ('different', 'ATE1'), ('convenient', 'ATE1'), ('blindfolded', 'ATE1'), ('tasty', 'ATE1'), ('sweet', 'ATE1'), ('healthy', 'ATE1'), ('whole', 'ATE1'), ('awake', 'ATE1'), ('tough', 'ATE1'), ('great', 'ATE1'), ('terrible', 'ATE1'), ('adorable', 'ATE1'), ('saucy', 'ATE1'), ('stupid', 'ATE1'), ('last', 'ATE1'), ('big', 'ATE1'), ('super', 'ATE1'), ('more', 'ATE1'), ('alone', 'ATE1'), ('cool', 'ATE1'), ('important', 'ATE1'), ('pretty', 'ATE1'), ('ignorant', 'ATE1'), ('alright', 'ATE1'), ('complicated', 'ATE1'), ('new', 'ATE1'), ('nuts', 'ATE1'), ('permanent', 'ATE1'), ('improbable', 'ATE1'), ('welcome', 'ATE1'), ('young', 'ATE1'), ('large', 'ATE1')}
# {('right', 'ATE10'), ('corny', 'ATE10'), ('squid', 'ATE10'), ('many', 'ATE10'), ('first', 'ATE10'), ('real', 'ATE10'), ('hearted', 'ATE10'), ('fair', 'ATE10'), ('crazy', 'ATE10'), ('disgusting', 'ATE10'), ('raw', 'ATE10'), ('bad', 'ATE10'), ('wrong', 'ATE10'), ('smooth', 'ATE10'), ('least', 'ATE10'), ('sad', 'ATE10'), ('second', 'ATE10'), ('small', 'ATE10'), ('rashy', 'ATE10'), ('own', 'ATE10'), ('quiet', 'ATE10'), ('maddening', 'ATE10'), ('sure', 'ATE10'), ('awesome', 'ATE10'), ('dirty', 'ATE10'), ('well', 'ATE10'), ('old', 'ATE10'), ('half', 'ATE10'), ('serious', 'ATE10'), ('fine', 'ATE10'), ('rough', 'ATE10'), ('good', 'ATE10'), ('different', 'ATE10'), ('slight', 'ATE10'), ('itchy', 'ATE10'), ('ready', 'ATE10'), ('long', 'ATE10'), ('tough', 'ATE10'), ('great', 'ATE10'), ('healthy', 'ATE10'), ('stuck', 'ATE10'), ('terrible', 'ATE10'), ('soooo', 'ATE10'), ('gorgeous', 'ATE10'), ('perfect', 'ATE10'), ('pet', 'ATE10'), ('human', 'ATE10'), ('beautiful', 'ATE10'), ('sorry', 'ATE10'), ('several', 'ATE10'), ('raunchy', 'ATE10'), ('happy', 'ATE10'), ('fantastic', 'ATE10'), ('more', 'ATE10'), ('entire', 'ATE10'), ('ohhhhhhhh', 'ATE10'), ('cool', 'ATE10'), ('other', 'ATE10'), ('little', 'ATE10'), ('okay', 'ATE10'), ('naked', 'ATE10'), ('cold', 'ATE10')}
# {('rash', 'ATE11'), ('alive', 'ATE11'), ('new', 'ATE11'), ('natural', 'ATE11'), ('few', 'ATE11'), ('naked', 'ATE11'), ('magical', 'ATE11'), ('true', 'ATE11'), ('same', 'ATE11'), ('unhappy', 'ATE11'), ('unattractive', 'ATE11'), ('sure', 'ATE11'), ('powerful', 'ATE11'), ('fine', 'ATE11'), ('ancient', 'ATE11'), ('third', 'ATE11'), ('responsible', 'ATE11'), ('embarrassed', 'ATE11'), ('excellent', 'ATE11'), ('left', 'ATE11'), ('normal', 'ATE11'), ('orange', 'ATE11'), ('desperate', 'ATE11'), ('fake', 'ATE11'), ('glorious', 'ATE11'), ('glad', 'ATE11'), ('radical', 'ATE11'), ('full', 'ATE11'), ('Most', 'ATE11'), ('easy', 'ATE11'), ('ready', 'ATE11'), ('disgusted', 'ATE11'), ('hysterical', 'ATE11'), ('star', 'ATE11'), ('annoyed', 'ATE11'), ('lame', 'ATE11'), ('tilted', 'ATE11'), ('nice', 'ATE11'), ('right', 'ATE11'), ('young', 'ATE11'), ('dangerous', 'ATE11'), ('foul', 'ATE11'), ('final', 'ATE11'), ('crazy', 'ATE11'), ('limitless', 'ATE11'), ('animate', 'ATE11'), ('total', 'ATE11'), ('mystical', 'ATE11'), ('magic', 'ATE11'), ('giant', 'ATE11'), ('main', 'ATE11'), ('close', 'ATE11'), ('last', 'ATE11'), ('frustrated', 'ATE11'), ('big', 'ATE11'), ('lifeless', 'ATE11'), ('free', 'ATE11'), ('stupid', 'ATE11'), ('more', 'ATE11'), ('entire', 'ATE11'), ('cool', 'ATE11'), ('ultimate', 'ATE11'), ('newfangled', 'ATE11'), ('dimensional', 'ATE11'), ('other', 'ATE11'), ('okay', 'ATE11'), ('amazed', 'ATE11'), ('evil', 'ATE11'), ('next', 'ATE11'), ('eld', 'ATE11'), ('well', 'ATE11'), ('familiar', 'ATE11'), ('asleep', 'ATE11'), ('old', 'ATE11'), ('gross', 'ATE11'), ('good', 'ATE11'), ('bouncy', 'ATE11'), ('very', 'ATE11'), ('sunken', 'ATE11')}
# {('scary', 'ATE12'), ('wild', 'ATE12'), ('cool', 'ATE12'), ('lucky', 'ATE12'), ('new', 'ATE12'), ('honest', 'ATE12'), ('pretty', 'ATE12'), ('reliable', 'ATE12'), ('exhausted', 'ATE12'), ('little', 'ATE12'), ('warm', 'ATE12'), ('nuts', 'ATE12'), ('right', 'ATE12'), ('goldfish', 'ATE12'), ('true', 'ATE12'), ('dead', 'ATE12'), ('feelin', 'ATE12'), ('wrong', 'ATE12'), ('total', 'ATE12'), ('open', 'ATE12'), ('vaporized', 'ATE12'), ('bla', 'ATE12'), ('satisfied', 'ATE12'), ('wonderful', 'ATE12'), ('ordinary', 'ATE12'), ('awesome', 'ATE12'), ('giant', 'ATE12'), ('well', 'ATE12'), ('hardcore', 'ATE12'), ('full', 'ATE12'), ('old', 'ATE12'), ('ble', 'ATE12'), ('scared', 'ATE12'), ('gross', 'ATE12'), ('convinced', 'ATE12'), ('good', 'ATE12'), ('very', 'ATE12'), ('pathetic', 'ATE12'), ('weak', 'ATE12'), ('ready', 'ATE12'), ('great', 'ATE12'), ('afraid', 'ATE12'), ('fun', 'ATE12'), ('tired', 'ATE12'), ('mysterious', 'ATE12'), ('unprepared', 'ATE12')}
# {('criminal', 'ATE13'), ('poor', 'ATE13'), ('clean', 'ATE13'), ('much', 'ATE13'), ('enough', 'ATE13'), ('-', 'ATE13'), ('wrong', 'ATE13'), ('about', 'ATE13'), ('virgin', 'ATE13'), ('second', 'ATE13'), ('redoodoodiculous', 'ATE13'), ('able', 'ATE13'), ('cute', 'ATE13'), ('pure', 'ATE13'), ('dirty', 'ATE13'), ('hopeless', 'ATE13'), ('giant', 'ATE13'), ('unfit', 'ATE13'), ('aoh', 'ATE13'), ('headed', 'ATE13'), ('asleep', 'ATE13'), ('light', 'ATE13'), ('good', 'ATE13'), ('top', 'ATE13'), ('easy', 'ATE13'), ('different', 'ATE13'), ('crooked', 'ATE13'), ('ready', 'ATE13'), ('whole', 'ATE13'), ('filthy', 'ATE13'), ('impure', 'ATE13'), ('terrible', 'ATE13'), ('great', 'ATE13'), ('slow', 'ATE13'), ('afraid', 'ATE13'), ('fun', 'ATE13'), ('red', 'ATE13'), ('homeless', 'ATE13'), ('sorry', 'ATE13'), ('super', 'ATE13'), ('black', 'ATE13'), ('stupid', 'ATE13'), ('big', 'ATE13'), ('wicked', 'ATE13'), ('alone', 'ATE13'), ('nearby', 'ATE13'), ('squeaky', 'ATE13'), ('hard', 'ATE13'), ('blue', 'ATE13'), ('little', 'ATE13'), ('new', 'ATE13'), ('only', 'ATE13'), ('other', 'ATE13'), ('okay', 'ATE13'), ('welcome', 'ATE13'), ('high', 'ATE13'), ('right', 'ATE13'), ('young', 'ATE13'), ('magical', 'ATE13'), ('naked', 'ATE13'), ('dead', 'ATE13')}
# {('okay', 'ATE14'), ('magical', 'ATE14'), ('fat', 'ATE14'), ('many', 'ATE14'), ('right', 'ATE14'), ('true', 'ATE14'), ('poisonous', 'ATE14'), ('large', 'ATE14'), ('first', 'ATE14'), ('ergh', 'ATE14'), ('desperate', 'ATE14'), ('chubby', 'ATE14'), ('bad', 'ATE14'), ('wrong', 'ATE14'), ('much', 'ATE14'), ('magic', 'ATE14'), ('exhausting', 'ATE14'), ('total', 'ATE14'), ('glad', 'ATE14'), ('evil', 'ATE14'), ('powerless', 'ATE14'), ('deep', 'ATE14'), ('cute', 'ATE14'), ('dyin', 'ATE14'), ('prideful', 'ATE14'), ('giant', 'ATE14'), ('full', 'ATE14'), ('old', 'ATE14'), ('gross', 'ATE14'), ('good', 'ATE14'), ('easy', 'ATE14'), ('whole', 'ATE14'), ('current', 'ATE14'), ('various', 'ATE14'), ('regular', 'ATE14'), ('humble', 'ATE14'), ('great', 'ATE14'), ('cutesy', 'ATE14'), ('weird', 'ATE14'), ('chilly', 'ATE14'), ('clear', 'ATE14'), ('ideal', 'ATE14'), ('subconscious', 'ATE14'), ('tired', 'ATE14'), ('beautiful', 'ATE14'), ('sorry', 'ATE14'), ('ironic', 'ATE14'), ('annoyed', 'ATE14'), ('stupid', 'ATE14'), ('big', 'ATE14'), ('more', 'ATE14'), ('black', 'ATE14'), ('energetic', 'ATE14'), ('kinda', 'ATE14'), ('hard', 'ATE14'), ('industrial', 'ATE14'), ('locked', 'ATE14'), ('other', 'ATE14'), ('cool', 'ATE14'), ('lucky', 'ATE14'), ('alive', 'ATE14'), ('humiliating', 'ATE14'), ('hungry', 'ATE14'), ('alright', 'ATE14'), ('lazy', 'ATE14'), ('little', 'ATE14'), ('only', 'ATE14')}
# {('more', 'ATE15'), ('lucky', 'ATE15'), ('hard', 'ATE15'), ('dumb', 'ATE15'), ('functional', 'ATE15'), ('normal', 'ATE15'), ('little', 'ATE15'), ('unsettling', 'ATE15'), ('troubled', 'ATE15'), ('imaginary', 'ATE15'), ('mortal', 'ATE15'), ('eager', 'ATE15'), ('cold', 'ATE15'), ('young', 'ATE15'), ('right', 'ATE15'), ('angry', 'ATE15'), ('fat', 'ATE15'), ('melty', 'ATE15'), ('sudden', 'ATE15'), ('heavy', 'ATE15'), ('innocent', 'ATE15'), ('private', 'ATE15'), ('female', 'ATE15'), ('-', 'ATE15'), ('about', 'ATE15'), ('deep', 'ATE15'), ('magic', 'ATE15'), ('semi', 'ATE15'), ('small', 'ATE15'), ('low', 'ATE15'), ('hardcore', 'ATE15'), ('well', 'ATE15'), ('personal', 'ATE15'), ('full', 'ATE15'), ('awesome', 'ATE15'), ('asleep', 'ATE15'), ('hot', 'ATE15'), ('good', 'ATE15'), ('different', 'ATE15'), ('loyal', 'ATE15'), ('crybaby', 'ATE15'), ('daring', 'ATE15'), ('long', 'ATE15'), ('very', 'ATE15'), ('awake', 'ATE15'), ('terrible', 'ATE15'), ('mock', 'ATE15'), ('great', 'ATE15'), ('perfect', 'ATE15'), ('funny', 'ATE15'), ('beautiful', 'ATE15'), ('frustrated', 'ATE15'), ('big', 'ATE15'), ('stupid', 'ATE15'), ('free', 'ATE15')}
# {('pre', 'ATE16'), ('glad', 'ATE16'), ('-', 'ATE16'), ('wrong', 'ATE16'), ('bad', 'ATE16'), ('deep', 'ATE16'), ('small', 'ATE16'), ('about', 'ATE16'), ('least', 'ATE16'), ('wuss', 'ATE16'), ('own', 'ATE16'), ('maniacal', 'ATE16'), ('wonderful', 'ATE16'), ('awesome', 'ATE16'), ('sure', 'ATE16'), ('rapid', 'ATE16'), ('hot', 'ATE16'), ('gross', 'ATE16'), ('scared', 'ATE16'), ('good', 'ATE16'), ('pathetic', 'ATE16'), ('war', 'ATE16'), ('panting', 'ATE16'), ('ready', 'ATE16'), ('nasty', 'ATE16'), ('multiple', 'ATE16'), ('great', 'ATE16'), ('afraid', 'ATE16'), ('slow', 'ATE16'), ('underwater', 'ATE16'), ('perfect', 'ATE16'), ('red', 'ATE16'), ('heroic', 'ATE16'), ('dark', 'ATE16'), ('un', 'ATE16'), ('beautiful', 'ATE16'), ('safe', 'ATE16'), ('black', 'ATE16'), ('rusty', 'ATE16'), ('entire', 'ATE16'), ('more', 'ATE16'), ('cool', 'ATE16'), ('few', 'ATE16'), ('normal', 'ATE16'), ('nuts', 'ATE16'), ('pretty', 'ATE16'), ('proud', 'ATE16'), ('ominous', 'ATE16'), ('late', 'ATE16'), ('true', 'ATE16'), ('right', 'ATE16'), ('single', 'ATE16'), ('crazy', 'ATE16'), ('barefoot', 'ATE16'), ('ok', 'ATE16')}
# {('crazy', 'ATE17'), ('up—80', 'ATE17'), ('threatening', 'ATE17'), ('female', 'ATE17'), ('glad', 'ATE17'), ('bad', 'ATE17'), ('wrong', 'ATE17'), ('about', 'ATE17'), ("y'know", 'ATE17'), ('open', 'ATE17'), ('creepy', 'ATE17'), ('spiky', 'ATE17'), ('total', 'ATE17'), ('prepared', 'ATE17'), ('glazed', 'ATE17'), ('giant', 'ATE17'), ('well', 'ATE17'), ('sure', 'ATE17'), ('sized', 'ATE17'), ('old', 'ATE17'), ('hot', 'ATE17'), ('good', 'ATE17'), ('fine', 'ATE17'), ('gross', 'ATE17'), ('different', 'ATE17'), ('serious', 'ATE17'), ('male', 'ATE17'), ('allergic', 'ATE17'), ('double', 'ATE17'), ('ready', 'ATE17'), ('traditional', 'ATE17'), ('sweet', 'ATE17'), ('married', 'ATE17'), ('weird', 'ATE17'), ('comfortable', 'ATE17'), ('beautiful', 'ATE17'), ('huge', 'ATE17'), ('last', 'ATE17'), ('stinky', 'ATE17'), ('lousy', 'ATE17'), ('big', 'ATE17'), ('nearby', 'ATE17'), ('stupid', 'ATE17'), ('free', 'ATE17'), ('black', 'ATE17'), ('more', 'ATE17'), ('lame', 'ATE17'), ('happy', 'ATE17'), ('cool', 'ATE17'), ('lucky', 'ATE17'), ('worth', 'ATE17'), ('bored', 'ATE17'), ('spontaneous', 'ATE17'), ('normal', 'ATE17'), ('pretty', 'ATE17'), ('okay', 'ATE17'), ('nervous', 'ATE17'), ('other', 'ATE17'), ('official', 'ATE17'), ('right', 'ATE17'), ('angry', 'ATE17'), ('large', 'ATE17'), ('same', 'ATE17')}
# {('thine', 'ATE18'), ('silly', 'ATE18'), ('worried', 'ATE18'), ('more', 'ATE18'), ('few', 'ATE18'), ('powdered', 'ATE18'), ('little', 'ATE18'), ('nervous', 'ATE18'), ('secret', 'ATE18'), ('okay', 'ATE18'), ('muffled', 'ATE18'), ('dangerous', 'ATE18'), ('right', 'ATE18'), ('single', 'ATE18'), ('true', 'ATE18'), ('angry', 'ATE18'), ('many', 'ATE18'), ('hideous', 'ATE18'), ('heavy', 'ATE18'), ('skeletal', 'ATE18'), ('sick', 'ATE18'), ('darn', 'ATE18'), ('freaky', 'ATE18'), ('accursed', 'ATE18'), ('approximate', 'ATE18'), ('intelligent', 'ATE18'), ('farth', 'ATE18'), ('key', 'ATE18'), ('*', 'ATE18'), ('evil', 'ATE18'), ('radical', 'ATE18'), ('deep', 'ATE18'), ('small', 'ATE18'), ('about', 'ATE18'), ('low', 'ATE18'), ('exponential', 'ATE18'), ('green', 'ATE18'), ('own', 'ATE18'), ('giant', 'ATE18'), ('royal', 'ATE18'), ('demonic', 'ATE18'), ('awesome', 'ATE18'), ('full', 'ATE18'), ('strange', 'ATE18'), ('old', 'ATE18'), ('well', 'ATE18'), ('further', 'ATE18'), ('magnificent', 'ATE18'), ('frustrating', 'ATE18'), ('gelatinous', 'ATE18'), ('good', 'ATE18'), ('scared', 'ATE18'), ('fine', 'ATE18'), ('different', 'ATE18'), ('pathetic', 'ATE18'), ('ready', 'ATE18'), ('idiot', 'ATE18'), ('long', 'ATE18'), ('sweet', 'ATE18'), ('impossible', 'ATE18'), ('afraid', 'ATE18'), ('awake', 'ATE18'), ('mimic', 'ATE18'), ('huge', 'ATE18'), ('comfortable', 'ATE18'), ('beautiful', 'ATE18'), ('last', 'ATE18'), ('raspy', 'ATE18'), ('big', 'ATE18'), ('black', 'ATE18')}
# {('unknown', 'ATE19'), ('good', 'ATE19'), ('rotten', 'ATE19'), ('medical', 'ATE19'), ('thick', 'ATE19'), ('crooked', 'ATE19'), ('very', 'ATE19'), ('tough', 'ATE19'), ('long', 'ATE19'), ('written', 'ATE19'), ('unnoticed', 'ATE19'), ('penitent', 'ATE19'), ('flawless', 'ATE19'), ('pet', 'ATE19'), ('beautiful', 'ATE19'), ('sorry', 'ATE19'), ('rancid', 'ATE19'), ('nearby', 'ATE19'), ('stupid', 'ATE19'), ('embarrassed', 'ATE19'), ('lame', 'ATE19'), ('pink', 'ATE19'), ('blue', 'ATE19'), ('flush', 'ATE19'), ('bonkers', 'ATE19'), ('rare', 'ATE19'), ('humanoid', 'ATE19'), ('purple', 'ATE19'), ('little', 'ATE19'), ('ugly', 'ATE19'), ('orange', 'ATE19'), ('nuts', 'ATE19'), ('okay', 'ATE19'), ('mad', 'ATE19'), ('nice', 'ATE19'), ('odd', 'ATE19'), ('cold', 'ATE19'), ('true', 'ATE19'), ('bald', 'ATE19'), ('dear', 'ATE19'), ('right', 'ATE19'), ('mobile', 'ATE19'), ('dead', 'ATE19'), ('innocent', 'ATE19'), ('golden', 'ATE19'), ('oval', 'ATE19'), ('ok', 'ATE19'), ('enough', 'ATE19'), ('fair', 'ATE19'), ('sucky', 'ATE19'), ('pre', 'ATE19'), ('poor', 'ATE19'), ('bad', 'ATE19'), ('necessary', 'ATE19'), ('villainous', 'ATE19'), ('-', 'ATE19'), ('distinguished', 'ATE19'), ('open', 'ATE19'), ('evil', 'ATE19'), ('grave', 'ATE19'), ('privileged', 'ATE19'), ('small', 'ATE19'), ('green', 'ATE19'), ('bubblegummy', 'ATE19'), ('creepy', 'ATE19'), ('wet', 'ATE19'), ('royal', 'ATE19'), ('wonderful', 'ATE19'), ('own', 'ATE19'), ('strange', 'ATE19'), ('gooey', 'ATE19'), ('presumptuous', 'ATE19'), ('depressed', 'ATE19')}
# {('terrible', 'ATE2'), ('close', 'ATE2'), ('romantic', 'ATE2'), ('last', 'ATE2'), ('big', 'ATE2'), ('sorry', 'ATE2'), ('plaintive', 'ATE2'), ('lame', 'ATE2'), ('more', 'ATE2'), ('hard', 'ATE2'), ('dumb', 'ATE2'), ('weekly', 'ATE2'), ('baaaaad', 'ATE2'), ('new', 'ATE2'), ('normal', 'ATE2'), ('electronic', 'ATE2'), ('rude', 'ATE2'), ('ominous', 'ATE2'), ('welcome', 'ATE2'), ('mad', 'ATE2'), ('eternal', 'ATE2'), ('nice', 'ATE2'), ('cold', 'ATE2'), ('muffled', 'ATE2'), ('early', 'ATE2'), ('right', 'ATE2'), ('dangerous', 'ATE2'), ('lumpy', 'ATE2'), ('fake', 'ATE2'), ('smooth', 'ATE2'), ('lumpers', 'ATE2'), ('sheer', 'ATE2'), ('gracious', 'ATE2'), ('-', 'ATE2'), ('much', 'ATE2'), ("y'know", 'ATE2'), ('drunk', 'ATE2'), ('notorious', 'ATE2'), ('wannabe', 'ATE2'), ('non', 'ATE2'), ('freakin', 'ATE2'), ('bad', 'ATE2'), ('muscular', 'ATE2'), ('insane', 'ATE2'), ('awesome', 'ATE2'), ('sure', 'ATE2'), ('directionless', 'ATE2'), ('royal', 'ATE2'), ('fine', 'ATE2'), ('hot', 'ATE2'), ('serious', 'ATE2'), ('good', 'ATE2'), ('easy', 'ATE2'), ('up', 'ATE2'), ('horrible', 'ATE2'), ('multiple', 'ATE2'), ('shady', 'ATE2')}
# {('nutty', 'ATE20'), ('clumped', 'ATE20'), ('indistinct', 'ATE20'), ('puzzled', 'ATE20'), ('welcome', 'ATE20'), ('single', 'ATE20'), ('angry', 'ATE20'), ('sick', 'ATE20'), ('darn', 'ATE20'), ('least', 'ATE20'), ('second', 'ATE20'), ('magic', 'ATE20'), ('worthless', 'ATE20'), ('makeshift', 'ATE20'), ('depressed', 'ATE20'), ('full', 'ATE20'), ('hot', 'ATE20'), ('miserable', 'ATE20'), ('close', 'ATE20'), ('surprised', 'ATE20'), ('stinky', 'ATE20'), ('mysterious', 'ATE20'), ('big', 'ATE20'), ('enormous', 'ATE20'), ('original', 'ATE20'), ('more', 'ATE20'), ('happy', 'ATE20'), ('blue', 'ATE20'), ('other', 'ATE20'), ('humanoid', 'ATE20'), ('only', 'ATE20'), ('nice', 'ATE20'), ('right', 'ATE20'), ('frickin', 'ATE20'), ('emotional', 'ATE20'), ('accursed', 'ATE20'), ('mystical', 'ATE20'), ('tiny', 'ATE20'), ('giant', 'ATE20'), ('light', 'ATE20'), ('old', 'ATE20'), ('upset', 'ATE20'), ('great', 'ATE20'), ('regular', 'ATE20'), ('perfect', 'ATE20'), ('afraid', 'ATE20'), ('red', 'ATE20'), ('huge', 'ATE20'), ('homeless', 'ATE20'), ('cool', 'ATE20'), ('little', 'ATE20'), ('secret', 'ATE20'), ('magical', 'ATE20'), ('fat', 'ATE20'), ('tattered', 'ATE20'), ('distraught', 'ATE20'), ('strong', 'ATE20'), ('evil', 'ATE20'), ('next', 'ATE20'), ('deep', 'ATE20'), ('small', 'ATE20'), ('unsure', 'ATE20'), ('headed', 'ATE20'), ('top', 'ATE20'), ('good', 'ATE20'), ('kind', 'ATE20'), ('beige', 'ATE20'), ('comfortable', 'ATE20'), ('embarrassed', 'ATE20'), ('worried', 'ATE20'), ('pink', 'ATE20'), ('fancy', 'ATE20'), ('normal', 'ATE20'), ('worth', 'ATE20'), ('complicated', 'ATE20'), ('orange', 'ATE20'), ('same', 'ATE20'), ('poor', 'ATE20'), ('wrong', 'ATE20'), ('about', 'ATE20'), ('cute', 'ATE20'), ('wide', 'ATE20'), ('low', 'ATE20'), ('green', 'ATE20'), ('rid', 'ATE20'), ('brown', 'ATE20'), ('sure', 'ATE20')}
# {('rough', 'ATE21'), ('musical', 'ATE21'), ('ready', 'ATE21'), ('common', 'ATE21'), ('sweet', 'ATE21'), ('transparent', 'ATE21'), ('regular', 'ATE21'), ('great', 'ATE21'), ('bottom', 'ATE21'), ('perfect', 'ATE21'), ('deadly', 'ATE21'), ('fun', 'ATE21'), ('pungent', 'ATE21'), ('new', 'ATE21'), ('comical', 'ATE21'), ('jowl', 'ATE21'), ('tired', 'ATE21'), ('such', 'ATE21'), ('sorry', 'ATE21'), ('sinister', 'ATE21'), ('super', 'ATE21'), ('stupid', 'ATE21'), ('tragic', 'ATE21'), ('entire', 'ATE21'), ('more', 'ATE21'), ('ninja', 'ATE21'), ('twin', 'ATE21'), ('short', 'ATE21'), ('jerky', 'ATE21'), ('sensitive', 'ATE21'), ('blue', 'ATE21'), ('dumb', 'ATE21'), ('unknown', 'ATE21'), ('calm', 'ATE21'), ('cool', 'ATE21'), ('like', 'ATE21'), ('little', 'ATE21'), ('incapable', 'ATE21'), ('complicated', 'ATE21'), ('other', 'ATE21'), ('okay', 'ATE21'), ('alright', 'ATE21'), ('mad', 'ATE21'), ('quick', 'ATE21'), ('normal', 'ATE21'), ('natural', 'ATE21'), ('loud', 'ATE21'), ('right', 'ATE21'), ('angry', 'ATE21'), ('real', 'ATE21'), ('steady', 'ATE21'), ('feelin', 'ATE21'), ('lookin', 'ATE21'), ('much', 'ATE21'), ('siamese', 'ATE21'), ('bad', 'ATE21'), ('wrong', 'ATE21'), ('obnoxious', 'ATE21'), ('open', 'ATE21'), ('careful', 'ATE21'), ('cute', 'ATE21'), ('ordinary', 'ATE21'), ('tiny', 'ATE21'), ('complete', 'ATE21'), ('mixed', 'ATE21'), ('well', 'ATE21'), ('sure', 'ATE21'), ('giant', 'ATE21'), ('powerful', 'ATE21'), ('old', 'ATE21'), ('fine', 'ATE21'), ('good', 'ATE21'), ('tall', 'ATE21'), ('sticky', 'ATE21'), ('pathetic', 'ATE21'), ('kiddin', 'ATE21')}
# {('gray', 'ATE22'), ('unholy', 'ATE22'), ('horrific', 'ATE22'), ('sorry', 'ATE22'), ('big', 'ATE22'), ('black', 'ATE22'), ('peach', 'ATE22'), ('free', 'ATE22'), ('wild', 'ATE22'), ('blue', 'ATE22'), ('more', 'ATE22'), ('entire', 'ATE22'), ('white', 'ATE22'), ('lucky', 'ATE22'), ('red', 'ATE22'), ('undead', 'ATE22'), ('rear', 'ATE22'), ('excited', 'ATE22'), ('dimple', 'ATE22'), ('cool', 'ATE22'), ('happy', 'ATE22'), ('like', 'ATE22'), ('little', 'ATE22'), ('eeehhh', 'ATE22'), ('other', 'ATE22'), ('sentient', 'ATE22'), ('single', 'ATE22'), ('right', 'ATE22'), ('late', 'ATE22'), ('many', 'ATE22'), ('first', 'ATE22'), ('crimson', 'ATE22'), ('dead', 'ATE22'), ('innocent', 'ATE22'), ('delicious', 'ATE22'), ('poor', 'ATE22'), ('enough', 'ATE22'), ('bad', 'ATE22'), ('wrong', 'ATE22'), ('evil', 'ATE22'), ('second', 'ATE22'), ('next', 'ATE22'), ('radical', 'ATE22'), ('open', 'ATE22'), ('casual', 'ATE22'), ('cute', 'ATE22'), ('hardcore', 'ATE22'), ('favorite', 'ATE22'), ('wonderful', 'ATE22'), ('sure', 'ATE22'), ('bombastic', 'ATE22'), ('light', 'ATE22'), ('old', 'ATE22'), ('good', 'ATE22'), ('yellow', 'ATE22'), ('liquid', 'ATE22'), ('triangular', 'ATE22'), ('ready', 'ATE22'), ('married', 'ATE22'), ('immobile', 'ATE22'), ('adorable', 'ATE22'), ('perfect', 'ATE22'), ('human', 'ATE22'), ('beautiful', 'ATE22')}
# {('gentle', 'ATE23'), ('high', 'ATE23'), ('angry', 'ATE23'), ('late', 'ATE23'), ('true', 'ATE23'), ('young', 'ATE23'), ('stayin', 'ATE23'), ('real', 'ATE23'), ('latter', 'ATE23'), ('purposeless', 'ATE23'), ('kick', 'ATE23'), ('least', 'ATE23'), ('celebratory', 'ATE23'), ('bad', 'ATE23'), ('amazing', 'ATE23'), ('about', 'ATE23'), ('few', 'ATE23'), ('cute', 'ATE23'), ('simple', 'ATE23'), ('former', 'ATE23'), ('normal', 'ATE23'), ('own', 'ATE23'), ('mine', 'ATE23'), ('well', 'ATE23'), ('imaginative', 'ATE23'), ('bombastic', 'ATE23'), ('near', 'ATE23'), ('good', 'ATE23'), ('easy', 'ATE23'), ('weak', 'ATE23'), ('ready', 'ATE23'), ('naked', 'ATE23'), ('continuous', 'ATE23'), ('dainty', 'ATE23'), ('healthy', 'ATE23'), ('shut', 'ATE23'), ('awake', 'ATE23'), ('secret', 'ATE23'), ('mmmm', 'ATE23'), ('regular', 'ATE23'), ('other', 'ATE23'), ('clear', 'ATE23'), ('hyper', 'ATE23'), ('beautiful', 'ATE23'), ('rockin', 'ATE23'), ('dark', 'ATE23'), ('robotic', 'ATE23'), ('mysterious', 'ATE23'), ('big', 'ATE23'), ('sorry', 'ATE23'), ('frustrated', 'ATE23'), ('lame', 'ATE23'), ('happy', 'ATE23'), ('cool', 'ATE23'), ('short', 'ATE23'), ('intense', 'ATE23'), ('invisible', 'ATE23'), ('civilized', 'ATE23'), ('alive', 'ATE23'), ('like', 'ATE23'), ('new', 'ATE23'), ('interesting', 'ATE23'), ('okay', 'ATE23'), ('cosmic', 'ATE23'), ('mad', 'ATE23'), ('imaginary', 'ATE23')}
# {('magical', 'ATE24'), ('straight', 'ATE24'), ('right', 'ATE24'), ('shrunken', 'ATE24'), ('true', 'ATE24'), ('menacing', 'ATE24'), ('first', 'ATE24'), ('sick', 'ATE24'), ('dead', 'ATE24'), ('crazy', 'ATE24'), ('offscreen', 'ATE24'), ('enraged', 'ATE24'), ('bad', 'ATE24'), ('much', 'ATE24'), ('wrong', 'ATE24'), ('total', 'ATE24'), ('gloomy', 'ATE24'), ('glad', 'ATE24'), ('fist', 'ATE24'), ('prepared', 'ATE24'), ('magic', 'ATE24'), ('pained', 'ATE24'), ('own', 'ATE24'), ('More', 'ATE24'), ('proud', 'ATE24'), ('sure', 'ATE24'), ('giant', 'ATE24'), ('recent', 'ATE24'), ('well', 'ATE24'), ('front', 'ATE24'), ('full', 'ATE24'), ('old', 'ATE24'), ('good', 'ATE24'), ('deserted', 'ATE24'), ('giddy', 'ATE24'), ('ready', 'ATE24'), ('long', 'ATE24'), ('sweet', 'ATE24'), ('healthy', 'ATE24'), ('meaningless', 'ATE24'), ('awful', 'ATE24'), ('terrible', 'ATE24'), ('weird', 'ATE24'), ('rockin', 'ATE24'), ('sorry', 'ATE24'), ('underway', 'ATE24'), ('dark', 'ATE24'), ('lousy', 'ATE24'), ('behold', 'ATE24'), ('candy', 'ATE24'), ('lifeless', 'ATE24'), ('pink', 'ATE24'), ('happy', 'ATE24'), ('entire', 'ATE24'), ('more', 'ATE24'), ('blue', 'ATE24'), ('common', 'ATE24'), ('virile', 'ATE24'), ('mean', 'ATE24'), ('brittle', 'ATE24'), ('worth', 'ATE24'), ('other', 'ATE24'), ('sound', 'ATE24'), ('ominous', 'ATE24'), ('new', 'ATE24'), ('only', 'ATE24'), ('loud', 'ATE24'), ('secret', 'ATE24')}
# {('alive', 'ATE25'), ('new', 'ATE25'), ('true', 'ATE25'), ('wrong', 'ATE25'), ('halfway', 'ATE25'), ('pained', 'ATE25'), ('extra', 'ATE25'), ('chunk', 'ATE25'), ('active', 'ATE25'), ('mathematical', 'ATE25'), ('sure', 'ATE25'), ('content', 'ATE25'), ('powerful', 'ATE25'), ('elated', 'ATE25'), ('tough', 'ATE25'), ('clear', 'ATE25'), ('empty', 'ATE25'), ('literal', 'ATE25'), ('nonviolent', 'ATE25'), ('legendary', 'ATE25'), ('left', 'ATE25'), ('rowdy', 'ATE25'), ('adequate', 'ATE25'), ('lumpy', 'ATE25'), ('first', 'ATE25'), ('weeeelcooome', 'ATE25'), ('heavy', 'ATE25'), ('bad', 'ATE25'), ('violent', 'ATE25'), ('More', 'ATE25'), ('quiet', 'ATE25'), ('own', 'ATE25'), ('funky', 'ATE25'), ('easy', 'ATE25'), ('serious', 'ATE25'), ('musical', 'ATE25'), ('bummed', 'ATE25'), ('useless', 'ATE25'), ('hey', 'ATE25'), ('cyborg', 'ATE25'), ('robotic', 'ATE25'), ('hungry', 'ATE25'), ('other', 'ATE25'), ('righteous', 'ATE25'), ('right', 'ATE25'), ('much', 'ATE25'), ('inflatable', 'ATE25'), ('magic', 'ATE25'), ('broken', 'ATE25'), ('tiny', 'ATE25'), ('mini', 'ATE25'), ('hopeless', 'ATE25'), ('complete', 'ATE25'), ('old', 'ATE25'), ('medical', 'ATE25'), ('hot', 'ATE25'), ('paunchy', 'ATE25'), ('horrible', 'ATE25'), ('weird', 'ATE25'), ('huge', 'ATE25'), ('last', 'ATE25'), ('frustrated', 'ATE25'), ('free', 'ATE25'), ('more', 'ATE25'), ('happy', 'ATE25'), ('cool', 'ATE25'), ('little', 'ATE25'), ('smokin', 'ATE25'), ('secret', 'ATE25'), ('terminal', 'ATE25'), ('dead', 'ATE25'), ('exciting', 'ATE25'), ('freakin', 'ATE25'), ('evil', 'ATE25'), ('small', 'ATE25'), ('pointless', 'ATE25'), ('well', 'ATE25'), ('good', 'ATE25'), ('different', 'ATE25'), ('very', 'ATE25'), ('great', 'ATE25'), ('beautiful', 'ATE25'), ('silly', 'ATE25'), ('fancy', 'ATE25')}
# {("wee'd", 'ATE26'), ('old', 'ATE26'), ('awesome', 'ATE26'), ('naughty', 'ATE26'), ('hot', 'ATE26'), ('good', 'ATE26'), ('scared', 'ATE26'), ('different', 'ATE26'), ('kiddin', 'ATE26'), ('very', 'ATE26'), ('horrible', 'ATE26'), ('wee', 'ATE26'), ('perfect', 'ATE26'), ('weird', 'ATE26'), ('cutesy', 'ATE26'), ('huge', 'ATE26'), ('big', 'ATE26'), ('stupid', 'ATE26'), ('several', 'ATE26'), ('worried', 'ATE26'), ('free', 'ATE26'), ('more', 'ATE26'), ('scary', 'ATE26'), ('terrified', 'ATE26'), ('fit', 'ATE26'), ('like', 'ATE26'), ('normal', 'ATE26'), ('little', 'ATE26'), ('nuts', 'ATE26'), ('interesting', 'ATE26'), ('mad', 'ATE26'), ('true', 'ATE26'), ('fat', 'ATE26'), ('monstrous', 'ATE26'), ('sharp', 'ATE26'), ('crazy', 'ATE26'), ('enough', 'ATE26'), ('bad', 'ATE26'), ('-', 'ATE26'), ('radical', 'ATE26'), ('open', 'ATE26'), ('creepy', 'ATE26'), ('spiky', 'ATE26'), ('cute', 'ATE26'), ('ridiculous', 'ATE26'), ('obvious', 'ATE26'), ('distant', 'ATE26'), ('sized', 'ATE26')}
# {('fun', 'ATE3'), ('last', 'ATE3'), ('big', 'ATE3'), ('plastic', 'ATE3'), ('sorry', 'ATE3'), ('quirky', 'ATE3'), ('worried', 'ATE3'), ('lame', 'ATE3'), ('more', 'ATE3'), ('entire', 'ATE3'), ('potential', 'ATE3'), ('star', 'ATE3'), ('free', 'ATE3'), ('hard', 'ATE3'), ('bored', 'ATE3'), ('cool', 'ATE3'), ('possible', 'ATE3'), ('alright', 'ATE3'), ('other', 'ATE3'), ('welcome', 'ATE3'), ('little', 'ATE3'), ('nuts', 'ATE3'), ('sexy', 'ATE3'), ('high', 'ATE3'), ('okay', 'ATE3'), ('young', 'ATE3'), ('naked', 'ATE3'), ('shaggy', 'ATE3'), ('right', 'ATE3'), ('angry', 'ATE3'), ('dear', 'ATE3'), ('first', 'ATE3'), ('same', 'ATE3'), ('middle', 'ATE3'), ('captive', 'ATE3'), ('much', 'ATE3'), ('wrong', 'ATE3'), ('magic', 'ATE3'), ('sad', 'ATE3'), ('small', 'ATE3'), ('favorite', 'ATE3'), ('simple', 'ATE3'), ('sure', 'ATE3'), ('giant', 'ATE3'), ('front', 'ATE3'), ('ticklish', 'ATE3'), ('hot', 'ATE3'), ('fine', 'ATE3'), ('gross', 'ATE3'), ('serious', 'ATE3'), ('good', 'ATE3'), ('holy', 'ATE3'), ('electric', 'ATE3'), ('sweet', 'ATE3')}
# {('crummy', 'ATE4'), ('enough', 'ATE4'), ('delicious', 'ATE4'), ('-', 'ATE4'), ('evil', 'ATE4'), ('magic', 'ATE4'), ('squishy', 'ATE4'), ('total', 'ATE4'), ('careful', 'ATE4'), ('deep', 'ATE4'), ('cute', 'ATE4'), ('own', 'ATE4'), ('satisfied', 'ATE4'), ('well', 'ATE4'), ('awesome', 'ATE4'), ('sure', 'ATE4'), ('precious', 'ATE4'), ('oww', 'ATE4'), ('rare', 'ATE4'), ('old', 'ATE4'), ('fine', 'ATE4'), ('good', 'ATE4'), ('top', 'ATE4'), ('upset', 'ATE4'), ('outer', 'ATE4'), ('weak', 'ATE4'), ('horrible', 'ATE4'), ('terrible', 'ATE4'), ('perfect', 'ATE4'), ('huge', 'ATE4'), ('lonely', 'ATE4'), ('sorry', 'ATE4'), ('big', 'ATE4'), ('super', 'ATE4'), ('stupid', 'ATE4'), ('lame', 'ATE4'), ('many', 'ATE4'), ('bonkers', 'ATE4'), ('cool', 'ATE4'), ('new', 'ATE4'), ('little', 'ATE4'), ('pretty', 'ATE4'), ('okay', 'ATE4'), ('nice', 'ATE4'), ('mad', 'ATE4'), ('shocking', 'ATE4'), ('sexy', 'ATE4'), ('high', 'ATE4'), ('womanly', 'ATE4'), ('holographic', 'ATE4')}
# {('noble', 'ATE5'), ('-', 'ATE5'), ('evil', 'ATE5'), ('small', 'ATE5'), ('sad', 'ATE5'), ('smart', 'ATE5'), ('open', 'ATE5'), ('key', 'ATE5'), ('cute', 'ATE5'), ('giant', 'ATE5'), ('disembodied', 'ATE5'), ('wonderful', 'ATE5'), ('unaligned', 'ATE5'), ('old', 'ATE5'), ('fine', 'ATE5'), ('good', 'ATE5'), ('yellow', 'ATE5'), ('certain', 'ATE5'), ('treacherous', 'ATE5'), ('ready', 'ATE5'), ('long', 'ATE5'), ('sweet', 'ATE5'), ('impossible', 'ATE5'), ('la', 'ATE5'), ('regular', 'ATE5'), ('opposite', 'ATE5'), ('devil', 'ATE5'), ('human', 'ATE5'), ('worthy', 'ATE5'), ('heroic', 'ATE5'), ('weird', 'ATE5'), ('neutral', 'ATE5'), ('red', 'ATE5'), ('last', 'ATE5'), ('safe', 'ATE5'), ('big', 'ATE5'), ('distressed', 'ATE5'), ('black', 'ATE5'), ('sorry', 'ATE5'), ('gray', 'ATE5'), ('mannish', 'ATE5'), ('more', 'ATE5'), ('blue', 'ATE5'), ('alright', 'ATE5'), ('alive', 'ATE5'), ('righteous', 'ATE5'), ('little', 'ATE5'), ('other', 'ATE5'), ('okay', 'ATE5'), ('just', 'ATE5'), ('welcome', 'ATE5'), ('aware', 'ATE5'), ('secret', 'ATE5'), ('high', 'ATE5'), ('young', 'ATE5'), ('magical', 'ATE5'), ('true', 'ATE5'), ('most', 'ATE5'), ('wrongteous', 'ATE5'), ('many', 'ATE5'), ('real', 'ATE5'), ('first', 'ATE5'), ('dead', 'ATE5'), ('final', 'ATE5'), ('menacing', 'ATE5'), ('crazy', 'ATE5'), ('grueling', 'ATE5'), ('ok', 'ATE5'), ('marvelous', 'ATE5'), ('manly', 'ATE5')}
# {('extraordinary', 'ATE6'), ('little', 'ATE6'), ('new', 'ATE6'), ('loose', 'ATE6'), ('doooowwwn', 'ATE6'), ('nuts', 'ATE6'), ('like', 'ATE6'), ('purple', 'ATE6'), ('quick', 'ATE6'), ('cold', 'ATE6'), ('other', 'ATE6'), ('right', 'ATE6'), ('angry', 'ATE6'), ('many', 'ATE6'), ('sick', 'ATE6'), ('dead', 'ATE6'), ('jiggly', 'ATE6'), ('ok', 'ATE6'), ('fair', 'ATE6'), ('crazy', 'ATE6'), ('enraged', 'ATE6'), ('wrong', 'ATE6'), ('bad', 'ATE6'), ('least', 'ATE6'), ('small', 'ATE6'), ('comfy', 'ATE6'), ('able', 'ATE6'), ('own', 'ATE6'), ('favorite', 'ATE6'), ('well', 'ATE6'), ('awesome', 'ATE6'), ('strange', 'ATE6'), ('normal', 'ATE6'), ('globular', 'ATE6'), ('fine', 'ATE6'), ('unknown', 'ATE6'), ('good', 'ATE6'), ('hot', 'ATE6'), ('different', 'ATE6'), ('holy', 'ATE6'), ('weak', 'ATE6'), ('ready', 'ATE6'), ('sweet', 'ATE6'), ('adorable', 'ATE6'), ('tough', 'ATE6'), ('terrible', 'ATE6'), ('various', 'ATE6'), ('weird', 'ATE6'), ('limp', 'ATE6'), ('tired', 'ATE6'), ('safe', 'ATE6'), ('distressed', 'ATE6'), ('several', 'ATE6'), ('wild', 'ATE6'), ('more', 'ATE6'), ('pink', 'ATE6'), ('cool', 'ATE6')}
# {('big', 'ATE7'), ('super', 'ATE7'), ('independent', 'ATE7'), ('sinister', 'ATE7'), ('wicked', 'ATE7'), ('annoyed', 'ATE7'), ('jealous', 'ATE7'), ('alone', 'ATE7'), ('pink', 'ATE7'), ('engaging', 'ATE7'), ('enervated', 'ATE7'), ('alright', 'ATE7'), ('twisty', 'ATE7'), ('new', 'ATE7'), ('little', 'ATE7'), ('normal', 'ATE7'), ('other', 'ATE7'), ('focused', 'ATE7'), ('welcome', 'ATE7'), ('nice', 'ATE7'), ('right', 'ATE7'), ('dead', 'ATE7'), ('less', 'ATE7'), ('consensual', 'ATE7'), ('threatening', 'ATE7'), ('glad', 'ATE7'), ('bad', 'ATE7'), ('wrong', 'ATE7'), ('next', 'ATE7'), ('-', 'ATE7'), ('evil', 'ATE7'), ('villainous', 'ATE7'), ('smart', 'ATE7'), ('low', 'ATE7'), ('total', 'ATE7'), ('deep', 'ATE7'), ('cute', 'ATE7'), ('ridiculous', 'ATE7'), ('naive', 'ATE7'), ('own', 'ATE7'), ('complete', 'ATE7'), ('wonderful', 'ATE7'), ('full', 'ATE7'), ('powerful', 'ATE7'), ('old', 'ATE7'), ('good', 'ATE7'), ('dramatic', 'ATE7'), ('ancient', 'ATE7'), ('serious', 'ATE7'), ('ready', 'ATE7'), ('holy', 'ATE7'), ('weak', 'ATE7'), ('irritated', 'ATE7'), ('suspicious', 'ATE7'), ('plasmodial', 'ATE7'), ('foldy', 'ATE7'), ('great', 'ATE7'), ('current', 'ATE7'), ('balbaflonic', 'ATE7'), ('foolish', 'ATE7'), ('romantic', 'ATE7'), ('funny', 'ATE7'), ('pro', 'ATE7'), ('weird', 'ATE7'), ('fragile', 'ATE7'), ('dark', 'ATE7'), ('posterior', 'ATE7')}
# {('efficient', 'ATE8'), ('moldable', 'ATE8'), ('ready', 'ATE8'), ('horrible', 'ATE8'), ('great', 'ATE8'), ('resilient', 'ATE8'), ('rewarding', 'ATE8'), ('various', 'ATE8'), ('murmur', 'ATE8'), ('red', 'ATE8'), ('fun', 'ATE8'), ('weird', 'ATE8'), ('huge', 'ATE8'), ('fast', 'ATE8'), ('empty', 'ATE8'), ('tired', 'ATE8'), ('enormous', 'ATE8'), ('big', 'ATE8'), ('several', 'ATE8'), ('more', 'ATE8'), ('later', 'ATE8'), ('annoying', 'ATE8'), ('happy', 'ATE8'), ('bottled', 'ATE8'), ('free', 'ATE8'), ('hard', 'ATE8'), ('excited', 'ATE8'), ('normal', 'ATE8'), ('other', 'ATE8'), ('lazy', 'ATE8'), ('ugly', 'ATE8'), ('orange', 'ATE8'), ('buncha', 'ATE8'), ('stinkin', 'ATE8'), ('fat', 'ATE8'), ('attractive', 'ATE8'), ('true', 'ATE8'), ('nice', 'ATE8'), ('right', 'ATE8'), ('adequate', 'ATE8'), ('frickin', 'ATE8'), ('large', 'ATE8'), ('single', 'ATE8'), ('radd', 'ATE8'), ('sharp', 'ATE8'), ('legit', 'ATE8'), ('chubby', 'ATE8'), ('ok', 'ATE8'), ('enough', 'ATE8'), ('unhappy', 'ATE8'), ('shiny', 'ATE8'), ('crazy', 'ATE8'), ('stark', 'ATE8'), ('poor', 'ATE8'), ('clean', 'ATE8'), ('second', 'ATE8'), ('hind', 'ATE8'), ('small', 'ATE8'), ('creepy', 'ATE8'), ('able', 'ATE8'), ('complete', 'ATE8'), ('visible', 'ATE8'), ('awesome', 'ATE8'), ('giant', 'ATE8'), ('full', 'ATE8'), ('old', 'ATE8'), ('hot', 'ATE8'), ('good', 'ATE8'), ('different', 'ATE8')}
# {('silent', 'ATE9'), ('cool', 'ATE9'), ('few', 'ATE9'), ('쟤가', 'ATE9'), ('other', 'ATE9'), ('tender', 'ATE9'), ('universal', 'ATE9'), ('mad', 'ATE9'), ('normal', 'ATE9'), ('little', 'ATE9'), ('alien', 'ATE9'), ('indistinguishable', 'ATE9'), ('okay', 'ATE9'), ('like', 'ATE9'), ('naked', 'ATE9'), ('nice', 'ATE9'), ('magical', 'ATE9'), ('right', 'ATE9'), ('late', 'ATE9'), ('angry', 'ATE9'), ('incredible', 'ATE9'), ('many', 'ATE9'), ('same', 'ATE9'), ('dead', 'ATE9'), ('more', 'ATE9'), ('crazy', 'ATE9'), ('much', 'ATE9'), ('least', 'ATE9'), ('wavy', 'ATE9'), ('timeless', 'ATE9'), ('ooor', 'ATE9'), ('sad', 'ATE9'), ('evil', 'ATE9'), ('next', 'ATE9'), ('small', 'ATE9'), ('back', 'ATE9'), ('able', 'ATE9'), ('green', 'ATE9'), ('rocky', 'ATE9'), ('awesome', 'ATE9'), ('front', 'ATE9'), ('old', 'ATE9'), ('disturbed', 'ATE9'), ('뛰어다닌', 'ATE9'), ('good', 'ATE9'), ('scratchy', 'ATE9'), ('idiot', 'ATE9'), ('sweet', 'ATE9'), ('whole', 'ATE9'), ('hurt', 'ATE9'), ('great', 'ATE9'), ('funn', 'ATE9'), ('deadly', 'ATE9'), ('free', 'ATE9'), ('nerdy', 'ATE9'), ('flat', 'ATE9'), ('grungy', 'ATE9'), ('huge', 'ATE9'), ('harsh', 'ATE9'), ('weird', 'ATE9'), ('startled', 'ATE9'), ('beautiful', 'ATE9'), ('sorry', 'ATE9'), ('stupid', 'ATE9'), ('jealous', 'ATE9'), ('있었을까', 'ATE9'), ('blue', 'ATE9')}

# %% [markdown]
# ### Let's try dataframes to store these relations of word-form to unit
# Dataframes, supporteed by the pandas library in Python, facilitate handling data in spreadsheet / CSV / TSV format.
# We want to output some data to a TSV (tab-separated values file) so we can send it to network visualization software.
#
# We'll need to open a terminal and  **pip install pandas** (or python3.12 -m pip install pandas) to get dataframes working.

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            print(myDataFrame)
# Out:
#          word nodeType  unit
# 0      pretty      ADJ  ATE1
# 1        full      ADJ  ATE1
# 2   different      ADJ  ATE1
# 3        more      ADJ  ATE1
# 4   explosive      ADJ  ATE1
# ..        ...      ...   ...
# 82       full      ADJ  ATE1
# 83      awake      ADJ  ATE1
# 84   adorable      ADJ  ATE1
# 85  delicious      ADJ  ATE1
# 86  delicious      ADJ  ATE1
#
# [87 rows x 3 columns]
#          word nodeType   unit
# 0       squid      ADJ  ATE10
# 1       other      ADJ  ATE10
# 2        many      ADJ  ATE10
# 3         bad      ADJ  ATE10
# 4       human      ADJ  ATE10
# ..        ...      ...    ...
# 98      ready      ADJ  ATE10
# 99      ready      ADJ  ATE10
# 100   several      ADJ  ATE10
# 101     naked      ADJ  ATE10
# 102  gorgeous      ADJ  ATE10
#
# [103 rows x 3 columns]
#          word nodeType   unit
# 0       magic      ADJ  ATE11
# 1        free      ADJ  ATE11
# 2        rash      ADJ  ATE11
# 3      sunken      ADJ  ATE11
# 4    lifeless      ADJ  ATE11
# ..        ...      ...    ...
# 126      good      ADJ  ATE11
# 127      glad      ADJ  ATE11
# 128     naked      ADJ  ATE11
# 129      free      ADJ  ATE11
# 130      full      ADJ  ATE11
#
# [131 rows x 3 columns]
#          word nodeType   unit
# 0   vaporized      ADJ  ATE12
# 1        true      ADJ  ATE12
# 2      honest      ADJ  ATE12
# 3        true      ADJ  ATE12
# 4    reliable      ADJ  ATE12
# ..        ...      ...    ...
# 58      ready      ADJ  ATE12
# 59        fun      ADJ  ATE12
# 60       dead      ADJ  ATE12
# 61   hardcore      ADJ  ATE12
# 62        old      ADJ  ATE12
#
# [63 rows x 3 columns]
#       word nodeType   unit
# 0     slow      ADJ  ATE13
# 1    ready      ADJ  ATE13
# 2     hard      ADJ  ATE13
# 3      aoh      ADJ  ATE13
# 4     hard      ADJ  ATE13
# ..     ...      ...    ...
# 87    good      ADJ  ATE13
# 88  virgin      ADJ  ATE13
# 89  second      ADJ  ATE13
# 90    pure      ADJ  ATE13
# 91   naked      ADJ  ATE13
#
# [92 rows x 3 columns]
#           word nodeType   unit
# 0       locked      ADJ  ATE14
# 1         cool      ADJ  ATE14
# 2          bad      ADJ  ATE14
# 3    poisonous      ADJ  ATE14
# 4        magic      ADJ  ATE14
# ..         ...      ...    ...
# 99         big      ADJ  ATE14
# 100      great      ADJ  ATE14
# 101     cutesy      ADJ  ATE14
# 102       cute      ADJ  ATE14
# 103       glad      ADJ  ATE14
#
# [104 rows x 3 columns]
#          word nodeType   unit
# 0       funny      ADJ  ATE15
# 1       funny      ADJ  ATE15
# 2      mortal      ADJ  ATE15
# 3        hard      ADJ  ATE15
# 4        long      ADJ  ATE15
# ..        ...      ...    ...
# 69      angry      ADJ  ATE15
# 70       full      ADJ  ATE15
# 71  beautiful      ADJ  ATE15
# 72  imaginary      ADJ  ATE15
# 73     little      ADJ  ATE15
#
# [74 rows x 3 columns]
#          word nodeType   unit
# 0        dark      ADJ  ATE16
# 1       gross      ADJ  ATE16
# 2         red      ADJ  ATE16
# 3     ominous      ADJ  ATE16
# 4        slow      ADJ  ATE16
# ..        ...      ...    ...
# 89      great      ADJ  ATE16
# 90      nasty      ADJ  ATE16
# 91  wonderful      ADJ  ATE16
# 92      least      ADJ  ATE16
# 93   maniacal      ADJ  ATE16
#
# [94 rows x 3 columns]
#         word nodeType   unit
# 0     glazed      ADJ  ATE17
# 1       open      ADJ  ATE17
# 2       okay      ADJ  ATE17
# 3      bored      ADJ  ATE17
# 4       good      ADJ  ATE17
# ..       ...      ...    ...
# 90     lousy      ADJ  ATE17
# 91     right      ADJ  ATE17
# 92   married      ADJ  ATE17
# 93  official      ADJ  ATE17
# 94    normal      ADJ  ATE17
#
# [95 rows x 3 columns]
#            word nodeType   unit
# 0         royal      ADJ  ATE18
# 1          last      ADJ  ATE18
# 2     dangerous      ADJ  ATE18
# 3       awesome      ADJ  ATE18
# 4        secret      ADJ  ATE18
# ..          ...      ...    ...
# 85        angry      ADJ  ATE18
# 86         well      ADJ  ATE18
# 87  intelligent      ADJ  ATE18
# 88         darn      ADJ  ATE18
# 89        right      ADJ  ATE18
#
# [90 rows x 3 columns]
#         word nodeType   unit
# 0     nearby      ADJ  ATE19
# 1     purple      ADJ  ATE19
# 2   humanoid      ADJ  ATE19
# 3     orange      ADJ  ATE19
# 4      green      ADJ  ATE19
# ..       ...      ...    ...
# 94      oval      ADJ  ATE19
# 95         -      ADJ  ATE19
# 96      oval      ADJ  ATE19
# 97         -      ADJ  ATE19
# 98      open      ADJ  ATE19
#
# [99 rows x 3 columns]
#        word nodeType  unit
# 0       big      ADJ  ATE2
# 1      more      ADJ  ATE2
# 2      hard      ADJ  ATE2
# 3      easy      ADJ  ATE2
# 4       big      ADJ  ATE2
# ..      ...      ...   ...
# 97     last      ADJ  ATE2
# 98     good      ADJ  ATE2
# 99    lumpy      ADJ  ATE2
# 100    lame      ADJ  ATE2
# 101  normal      ADJ  ATE2
#
# [102 rows x 3 columns]
#             word nodeType   unit
# 0     mysterious      ADJ  ATE20
# 1       tattered      ADJ  ATE20
# 2           poor      ADJ  ATE20
# 3            old      ADJ  ATE20
# 4      surprised      ADJ  ATE20
# ..           ...      ...    ...
# 130     original      ADJ  ATE20
# 131       strong      ADJ  ATE20
# 132  embarrassed      ADJ  ATE20
# 133  complicated      ADJ  ATE20
# 134          old      ADJ  ATE20
#
# [135 rows x 3 columns]
#           word nodeType   unit
# 0         tall      ADJ  ATE21
# 1     ordinary      ADJ  ATE21
# 2       little      ADJ  ATE21
# 3     ordinary      ADJ  ATE21
# 4       little      ADJ  ATE21
# ..         ...      ...    ...
# 109  obnoxious      ADJ  ATE21
# 110      ready      ADJ  ATE21
# 111        new      ADJ  ATE21
# 112      sorry      ADJ  ATE21
# 113      tired      ADJ  ATE21
#
# [114 rows x 3 columns]
#         word nodeType   unit
# 0       many      ADJ  ATE22
# 1        old      ADJ  ATE22
# 2       poor      ADJ  ATE22
# 3        old      ADJ  ATE22
# 4        old      ADJ  ATE22
# ..       ...      ...    ...
# 113  radical      ADJ  ATE22
# 114     free      ADJ  ATE22
# 115     cool      ADJ  ATE22
# 116      big      ADJ  ATE22
# 117    right      ADJ  ATE22
#
# [118 rows x 3 columns]
#      word nodeType   unit
# 0   ready      ADJ  ATE23
# 1   ready      ADJ  ATE23
# 2    cool      ADJ  ATE23
# 3    dark      ADJ  ATE23
# 4     big      ADJ  ATE23
# ..    ...      ...    ...
# 85  naked      ADJ  ATE23
# 86   okay      ADJ  ATE23
# 87   mmmm      ADJ  ATE23
# 88  clear      ADJ  ATE23
# 89   good      ADJ  ATE23
#
# [90 rows x 3 columns]
#          word nodeType   unit
# 0      secret      ADJ  ATE24
# 1    underway      ADJ  ATE24
# 2        loud      ADJ  ATE24
# 3       front      ADJ  ATE24
# 4     brittle      ADJ  ATE24
# ..        ...      ...    ...
# 99   lifeless      ADJ  ATE24
# 100      mean      ADJ  ATE24
# 101  lifeless      ADJ  ATE24
# 102      dead      ADJ  ATE24
# 103      dead      ADJ  ATE24
#
# [104 rows x 3 columns]
#            word nodeType   unit
# 0         great      ADJ  ATE25
# 1          last      ADJ  ATE25
# 2      terminal      ADJ  ATE25
# 3    inflatable      ADJ  ATE25
# 4          mini      ADJ  ATE25
# ..          ...      ...    ...
# 125        very      ADJ  ATE25
# 126     literal      ADJ  ATE25
# 127     freakin      ADJ  ATE25
# 128         old      ADJ  ATE25
# 129         old      ADJ  ATE25
#
# [130 rows x 3 columns]
#         word nodeType   unit
# 0   horrible      ADJ  ATE26
# 1    distant      ADJ  ATE26
# 2    several      ADJ  ATE26
# 3    awesome      ADJ  ATE26
# 4        big      ADJ  ATE26
# ..       ...      ...    ...
# 84       hot      ADJ  ATE26
# 85     spiky      ADJ  ATE26
# 86   naughty      ADJ  ATE26
# 87     spiky      ADJ  ATE26
# 88     spiky      ADJ  ATE26
#
# [89 rows x 3 columns]
#         word nodeType  unit
# 0       high      ADJ  ATE3
# 1      giant      ADJ  ATE3
# 2        big      ADJ  ATE3
# 3       holy      ADJ  ATE3
# 4        big      ADJ  ATE3
# ..       ...      ...   ...
# 76      star      ADJ  ATE3
# 77  ticklish      ADJ  ATE3
# 78   welcome      ADJ  ATE3
# 79     gross      ADJ  ATE3
# 80     sorry      ADJ  ATE3
#
# [81 rows x 3 columns]
#          word nodeType  unit
# 0        good      ADJ  ATE4
# 1         new      ADJ  ATE4
# 2         new      ADJ  ATE4
# 3   delicious      ADJ  ATE4
# 4        good      ADJ  ATE4
# ..        ...      ...   ...
# 75       okay      ADJ  ATE4
# 76       okay      ADJ  ATE4
# 77     stupid      ADJ  ATE4
# 78     stupid      ADJ  ATE4
# 79   shocking      ADJ  ATE4
#
# [80 rows x 3 columns]
#           word nodeType  unit
# 0        crazy      ADJ  ATE5
# 1    wonderful      ADJ  ATE5
# 2    marvelous      ADJ  ATE5
# 3         safe      ADJ  ATE5
# 4       secret      ADJ  ATE5
# ..         ...      ...   ...
# 119    magical      ADJ  ATE5
# 120    mannish      ADJ  ATE5
# 121    mannish      ADJ  ATE5
# 122    mannish      ADJ  ATE5
# 123    mannish      ADJ  ATE5
#
# [124 rows x 3 columns]
#        word nodeType  unit
# 0   unknown      ADJ  ATE6
# 1    little      ADJ  ATE6
# 2    little      ADJ  ATE6
# 3    little      ADJ  ATE6
# 4     small      ADJ  ATE6
# ..      ...      ...   ...
# 83     pink      ADJ  ATE6
# 84  enraged      ADJ  ATE6
# 85      own      ADJ  ATE6
# 86     wild      ADJ  ATE6
# 87   normal      ADJ  ATE6
#
# [88 rows x 3 columns]
#          word nodeType  unit
# 0     foolish      ADJ  ATE7
# 1   posterior      ADJ  ATE7
# 2   posterior      ADJ  ATE7
# 3   posterior      ADJ  ATE7
# 4       other      ADJ  ATE7
# ..        ...      ...   ...
# 92    jealous      ADJ  ATE7
# 93    jealous      ADJ  ATE7
# 94  posterior      ADJ  ATE7
# 95       deep      ADJ  ATE7
# 96     normal      ADJ  ATE7
#
# [97 rows x 3 columns]
#         word nodeType  unit
# 0    several      ADJ  ATE8
# 1       more      ADJ  ATE8
# 2       more      ADJ  ATE8
# 3     chubby      ADJ  ATE8
# 4     enough      ADJ  ATE8
# ..       ...      ...   ...
# 126       ok      ADJ  ATE8
# 127      red      ADJ  ATE8
# 128      red      ADJ  ATE8
# 129   normal      ADJ  ATE8
# 130    stark      ADJ  ATE8
#
# [131 rows x 3 columns]
#         word nodeType  unit
# 0      great      ADJ  ATE9
# 1     normal      ADJ  ATE9
# 2       late      ADJ  ATE9
# 3       next      ADJ  ATE9
# 4    awesome      ADJ  ATE9
# ..       ...      ...   ...
# 105      old      ADJ  ATE9
# 106     good      ADJ  ATE9
# 107    sorry      ADJ  ATE9
# 108   stupid      ADJ  ATE9
# 109   stupid      ADJ  ATE9
#
# [110 rows x 3 columns]

# %% [markdown]
# ## Write the dataframes to an output TSV file
# TSV means **tab-separated-values**. We'll use the tab character as a separator.
# The other popular alternative is the CSV: **comma-separated-values**, which uses the comma as a separator.
# You can use either one for our network data.
#
# I'm going to output some "node attributes" for tne network. In a network visualization, we'll want to be able to quickly distinguish the word nodes from the unit nodes (possibly by shape), and providing a qualifier or "node attribute" in the dataframe will be helpful.
# We can add other kinds of node attributes perhaps as numerical ranges (see below).

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)
# print(fullDataFrame)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a dataframe as a TSV file.')
# Go check your filestash for the file.
# Out:
# I just saved a dataframe as a TSV file.

# %% [markdown]
# ### Something to try...
# * Try developing this to return synsets from WordNet.
# * Add an Ambiguity metric to count the number of synsets it belongs to.
# * Output this as a second "node attribute" qualifier to the Part of Speech. We could use that to color-code the words by ambiguity...

# %%
# This time, with Wordnet data!
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    synsetCounts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            synsets = len(wn.synsets(token.lemma_))
            # We should be able to look up and count those synsets right here!          
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            synsetCounts.append(synsets)
            unitList.append(unit)
                          
    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'synsetCount': synsetCounts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData-2.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a NEW dataframe as a NEW TSV file.')
# Go check your filestash for the file.
# Out:
# I just saved a NEW dataframe as a NEW TSV file.

# %% [markdown]
# ## What will we do with this fancy TSV?
#
# We can analyze it as a **network** of data using network analysis. You could try importing your TSV into kumu.io, but we're going to introduce Cytoscape, which is a very powerful, artful method with lots of visualization options.
#
# To view the data we extracted in this notebook as an SVG export from Cytoscape, see <https://raw.githubusercontent.com/newtfire/textAnalysis-Hub/refs/heads/main/Class-Examples/Python/readFileCollections-examples/network-analysis-via-python/networkData-2.svg>

# %% [markdown]
# ## Your Turn!
# Adapt this notebook to explore one or more of your project files and prepare some network data of your own.
#
# * Output a CSV or TSV of data from your project for import into our network visualization software.
# * [Install Cytoscape](https://cytoscape.org/) on your computer and check to make sure it is working.
#      * Cytoscape now comes bundled with its own Java, so you should be good to go for running it (much like oXygen). If you have trouble, work through the [Troubleshooting](https://cytoscape.org/troubleshooting.html) guide first. Bring questions to class or via Canvas!
#      * After you install Cytoscape, see if you can also install the yFiles Layout Algorithms. Open Cytoscape, go to **Layout → Install yFiles**, which directs you to an App store to download it and apply it to Cytoscape.
